# %% [markdown]
# # Computational Social Science Project #3
#
# **Enter your Name:**Taylor Galdi
#
# *Semester:* Fall 2024

# %% [markdown]
# ## 1. Introduction
#
# ### Load data

# %%
#
# load libraries
# -----------
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelBinarizer

from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import VotingClassifier

# There are a few warnings that will appear that will not affect your analysis. Run this code to ignore. 
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# Make sure to import other libraries that will be necessary for training models!

# %%
#
# read in "Inspections Data 2011-2013" csv data
# -----------
chicago_inspections_2011_to_2013 = pd.read_csv("data/Chicago Inspections 2011-2013.csv", 
                                              low_memory=False)

#
# read in  "Inspections Data 2014_updated" csv data
# -----------
chicago_inspections_2014 = pd.read_csv("data/Chicago Inspections 2014_updated.csv",  # be sure to use the "updated" data here
                                      low_memory=False)

# %%
# look at the inspections data
chicago_inspections_2011_to_2013.head()
# Out:
#    Inspection_ID Inspection_Date                      DBA_Name  \
# 0         269961      2013-01-31                    SEVEN STAR
# 1         507211      2011-10-18                  PANERA BREAD
# 2         507212      2011-10-18      LITTLE QUIAPO RESTAURANT
# 3         507216      2011-10-19  SERGIO'S TAQUERIA PIZZA INC.
# 4         507219      2011-10-20         TARGET STORE # T-2079
#
#                    AKA_Name  License  Facility_Type             Risk  \
# 0                SEVEN STAR    30790  Grocery Store     Risk 3 (Low)
# 1              PANERA BREAD  1475890     Restaurant    Risk 1 (High)
# 2  LITTLE QUIAPO RESTAURANT  1740130     Restaurant    Risk 1 (High)
# 3   SERGIO'S TAQUERIA PIZZA  1447363     Restaurant    Risk 1 (High)
# 4                    TARGET  1679459     Restaurant  Risk 2 (Medium)
#
#                  Address     City State      Zip Inspection_Type Results  \
# 0       3352 N BROADWAY   CHICAGO    IL  60657.0         Canvass    Pass
# 1    6059 N LINCOLN AVE   CHICAGO    IL  60659.0         Canvass    Pass
# 2   6259 N MCCORMICK RD   CHICAGO    IL  60659.0         Canvass    Fail
# 3  3253 W BRYN MAWR AVE   CHICAGO    IL  60659.0         Canvass    Pass
# 4   2112 W PETERSON AVE   CHICAGO    IL  60659.0         Canvass    Fail
#
#     Latitude  Longitude                                  Location  \
# 0  41.943359 -87.644999  (41.943359344775146, -87.64499875300952)
# 1  41.991919 -87.709631   (41.99191947239194, -87.70963133440333)
# 2  41.995632 -87.712707   (41.99563177556418, -87.71270678169132)
# 3  41.982933 -87.710982  (41.982933189164974, -87.71098225381141)
# 4  41.990729 -87.682979   (41.99072921796059, -87.68297945359863)
#
#   Facility_Type_Clean  criticalCount  seriousCount  minorCount  pass_flag  \
# 0               Other              0             0           2          1
# 1          Restaurant              0             0           3          1
# 2          Restaurant              0             2           6          0
# 3          Restaurant              0             0           6          1
# 4          Restaurant              0             2           6          0
#
#    fail_flag  pastFail  pastCritical  pastSerious  pastMinor  timeSinceLast  \
# 0          0         0             0            0          0            2.0
# 1          0         0             0            0          0            2.0
# 2          1         0             0            0          0            2.0
# 3          0         0             0            0          0            2.0
# 4          1         0             0            0          0            2.0
#
#    firstRecord                ID  LICENSE_ID  ACCOUNT_NUMBER  \
# 0            1    30790-20110416   2081412.0         63759.0
# 1            1  1475890-20110416   2081695.0        207283.0
# 2            1  1740130-20110216   2070145.0          3107.0
# 3            1  1447363-20110216   2071895.0        270993.0
# 4            1  1679459-20100216   2009972.0         15538.0
#
#                      LEGAL_NAME        DOING_BUSINESS_AS_NAME  \
# 0            VIRGINIA DELA ROSA                    SEVEN STAR
# 1                   PANERA, LLC                  PANERA BREAD
# 2                ENELITA GARCIA      LITTLE QUIAPO RESTAURANT
# 3  SERGIO'S TAZUERIA PIZZA INC.  SERGIO'S TAQUERIA PIZZA INC.
# 4            TARGET CORPORATION         TARGET STORE # T-2079
#
#                  ADDRESS     CITY STATE  ZIP_CODE  WARD  PRECINCT  \
# 0    3352 N BROADWAY   1  CHICAGO    IL   60657.0  44.0      33.0
# 1  6059 N LINCOLN AVE  C  CHICAGO    IL   60659.0  50.0      23.0
# 2    6259 N MCCORMICK RD  CHICAGO    IL   60659.0  50.0      25.0
# 3   3253 W BRYN MAWR AVE  CHICAGO    IL   60659.0  39.0      48.0
# 4    2112 W PETERSON AVE  CHICAGO    IL   60659.0  40.0      18.0
#
#   WARD_PRECINCT  POLICE_DISTRICT  LICENSE_CODE        LICENSE_DESCRIPTION  \
# 0         44-33             19.0        1006.0  Retail Food Establishment
# 1         50-23             24.0        1006.0  Retail Food Establishment
# 2         50-25             17.0        1006.0  Retail Food Establishment
# 3         39-48             17.0        1006.0  Retail Food Establishment
# 4         40-18             24.0        1006.0  Retail Food Establishment
#
#   BUSINESS_ACTIVITY_ID                 BUSINESS_ACTIVITY  LICENSE_NUMBER  \
# 0                  775  Retail Sales of Perishable Foods         30790.0
# 1                  775  Retail Sales of Perishable Foods       1475890.0
# 2                  775  Retail Sales of Perishable Foods       1740130.0
# 3                  775  Retail Sales of Perishable Foods       1447363.0
# 4                  775  Retail Sales of Perishable Foods       1679459.0
#
#   APPLICATION_TYPE LICENSE_TERM_START_DATE LICENSE_TERM_EXPIRATION_DATE  \
# 0            RENEW              2011-04-16                   2013-04-15
# 1            RENEW              2011-04-16                   2013-04-15
# 2            RENEW              2011-02-16                   2013-02-15
# 3            RENEW              2011-02-16                   2013-02-15
# 4            RENEW              2010-02-16                   2012-02-15
#
#   LICENSE_STATUS   LATITUDE  LONGITUDE     minDate     maxDate  \
# 0            AAI  41.943359 -87.644999  2002-02-16  2015-04-15
# 1            AAI  41.991919 -87.709631  2004-05-05  2019-04-15
# 2            AAI  41.995632 -87.712707  2007-03-22  2017-02-15
# 3            AAI  41.982933 -87.710982  2003-12-31  2019-02-15
# 4            AAI  41.990729 -87.682979  2006-07-07  2018-02-15
#
#    ageAtInspection  consumption_on_premises_incidental_activity  tobacco  \
# 0        10.964384                                            0        1
# 1         7.457534                                            0        0
# 2         4.578082                                            0        0
# 3         7.805479                                            0        0
# 4         5.290411                                            0        0
#
#    package_goods  outdoor_patio  public_place_of_amusement  \
# 0              0              0                          0
# 1              0              0                          0
# 2              0              0                          0
# 3              0              0                          0
# 4              1              0                          0
#
#    limited_business_license  childrens_services_facility_license  tavern  \
# 0                         1                                    0       0
# 1                         0                                    0       0
# 2                         0                                    0       0
# 3                         0                                    0       0
# 4                         1                                    0       0
#
#    regulated_business_license  filling_station  caterers_liquor_license  \
# 0                           0                0                        0
# 1                           0                0                        0
# 2                           0                0                        0
# 3                           0                0                        0
# 4                           0                0                        0
#
#    mobile_food_license  precipIntensity  temperatureMax  windSpeed  humidity  \
# 0                    0         0.014587       53.496667  13.340000  0.900000
# 1                    0         0.001907       59.046667  13.016667  0.550000
# 2                    0         0.001907       59.046667  13.016667  0.550000
# 3                    0         0.002737       56.153333  10.863333  0.616667
# 4                    0         0.009987       52.730000  16.266667  0.690000
#
#    heat_burglary  heat_garbage  heat_sanitation  criticalFound
# 0      26.992376     12.768572        37.748787              0
# 1      13.976557     12.895485        15.412267              0
# 2      12.611239      8.004220         8.320330              0
# 3      35.906383     26.238645        38.186618              0
# 4       9.530785      3.401567         2.126788              0

# %%
# look at the inspections data
chicago_inspections_2011_to_2013.tail()
# Out:
#        Inspection_ID Inspection_Date  \
# 17672        1393258      2013-12-17
# 17673        1395218      2013-12-31
# 17674        1395224      2013-12-31
# 17675        1441493      2012-05-18
# 17676        1493801      2013-02-13
#
#                                        DBA_Name         AKA_Name  License  \
# 17672                           CIAO BELLA CAFE  CIAO BELLA CAFE  2232690
# 17673               Christian Fields Style  Bar              NaN  2002599
# 17674                     W CHICAGO - LAKESHORE        W CHICAGO  2189458
# 17675  ADVOCATE ILLINOIS MASONIC MEDICAL CENTER   COURTYARD CAFE  1142007
# 17676                                   SODEXHO          SODEXHO    20432
#
#       Facility_Type             Risk                    Address     City  \
# 17672    Restaurant    Risk 1 (High)        6800 N SHERIDAN RD   CHICAGO
# 17673    Restaurant  Risk 2 (Medium)  6550 S COTTAGE GROVE AVE   CHICAGO
# 17674    Restaurant    Risk 1 (High)       644 N LAKE SHORE DR   CHICAGO
# 17675    Restaurant    Risk 1 (High)      836 W WELLINGTON AVE   CHICAGO
# 17676    Restaurant    Risk 1 (High)         230 S LA SALLE ST   CHICAGO
#
#       State      Zip Inspection_Type             Results   Latitude  \
# 17672    IL  60626.0         Canvass                Pass  42.005587
# 17673    IL  60637.0         Canvass                Pass  41.775275
# 17674    IL  60611.0         Canvass  Pass w/ Conditions  41.893871
# 17675    IL  60657.0         Canvass                Pass  41.936450
# 17676    IL  60604.0         Canvass                Pass  41.878538
#
#        Longitude                                  Location  \
# 17672 -87.661077   (42.00558686485114, -87.66107732040031)
# 17673 -87.605963     (41.77527503998271, -87.605963353554)
# 17674 -87.615275   (41.89387134779289, -87.61527477728374)
# 17675 -87.650552   (41.93645016758182, -87.65055245204128)
# 17676 -87.632414  (41.878538291685196, -87.63241426118783)
#
#       Facility_Type_Clean  criticalCount  seriousCount  minorCount  pass_flag  \
# 17672          Restaurant              0             0           6          1
# 17673          Restaurant              0             0           4          1
# 17674          Restaurant              3             3           5          0
# 17675          Restaurant              0             0           3          1
# 17676          Restaurant              0             0           4          1
#
#        fail_flag  pastFail  pastCritical  pastSerious  pastMinor  \
# 17672          0         1             0            2          6
# 17673          0         0             0            1          4
# 17674          0         0             0            0          0
# 17675          0         0             0            0          3
# 17676          0         0             0            0          4
#
#        timeSinceLast  firstRecord                ID  LICENSE_ID  \
# 17672       0.452055            0  2232690-20130327   2232690.0
# 17673       1.200000            0  2002599-20130716   2259935.0
# 17674       2.000000            1  2189458-20130213   2189458.0
# 17675       0.000000            0  1142007-20110216   2071165.0
# 17676       0.000000            0    20432-20110216   2071169.0
#
#        ACCOUNT_NUMBER                          LEGAL_NAME  \
# 17672        378808.0               CIAO BELLA CAFE, INC.
# 17673        315535.0               CHRISTIAN FIELDS INC.
# 17674        375962.0              CHSP TRS LAKESHORE LLC
# 17675         63145.0  ADVOCATE NORTH SIDE HEALTH NETWORK
# 17676         63300.0             SODEXO MANAGEMENT, INC.
#
#                          DOING_BUSINESS_AS_NAME                       ADDRESS  \
# 17672                           CIAO BELLA CAFE       6800-6806 N SHERIDAN RD
# 17673                CHRISTIAN FIELDS STYLE BAR  6550 S COTTAGE GROVE AVE 1ST
# 17674                       W CHICAGO-LAKESHORE      644 N LAKE SHORE DR 1-32
# 17675  ADVOCATE ILLINOIS MASONIC MEDICAL CENTER      836 W WELLINGTON AVE # 1
# 17676                                    SODEXO         230 S LA SALLE ST 3RD
#
#           CITY STATE  ZIP_CODE  WARD  PRECINCT WARD_PRECINCT  POLICE_DISTRICT  \
# 17672  CHICAGO    IL   60626.0  49.0      36.0         49-36             24.0
# 17673  CHICAGO    IL   60637.0  20.0      18.0         20-18              3.0
# 17674  CHICAGO    IL   60611.0  42.0      63.0         42-63             18.0
# 17675  CHICAGO    IL   60657.0  44.0      14.0         44-14             19.0
# 17676  CHICAGO    IL   60604.0  42.0       9.0          42-9              1.0
#
#        LICENSE_CODE        LICENSE_DESCRIPTION BUSINESS_ACTIVITY_ID  \
# 17672        1006.0  Retail Food Establishment                  735
# 17673        1006.0  Retail Food Establishment                  775
# 17674        1006.0  Retail Food Establishment                  775
# 17675        1006.0  Retail Food Establishment                  775
# 17676        1006.0  Retail Food Establishment                  775
#
#                                        BUSINESS_ACTIVITY  LICENSE_NUMBER  \
# 17672  Preparation of Food and Dining on Premise With...       2232690.0
# 17673                   Retail Sales of Perishable Foods       2002599.0
# 17674                   Retail Sales of Perishable Foods       2189458.0
# 17675                   Retail Sales of Perishable Foods       1142007.0
# 17676                   Retail Sales of Perishable Foods         20432.0
#
#       APPLICATION_TYPE LICENSE_TERM_START_DATE LICENSE_TERM_EXPIRATION_DATE  \
# 17672            ISSUE              2013-03-27                   2015-04-15
# 17673            RENEW              2013-07-16                   2015-07-15
# 17674            ISSUE              2013-02-13                   2015-02-15
# 17675            RENEW              2011-02-16                   2013-02-15
# 17676            RENEW              2011-02-16                   2013-02-15
#
#       LICENSE_STATUS   LATITUDE  LONGITUDE     minDate     maxDate  \
# 17672            AAI  42.005587 -87.661077  2013-03-27  2015-04-15
# 17673            AAI  41.775275 -87.605963  2009-11-18  2017-07-15
# 17674            AAI  41.893871 -87.615275  2013-02-13  2019-02-15
# 17675            AAI  41.936450 -87.650552  2002-03-20  2019-02-15
# 17676            AAI  41.878538 -87.632414  2002-05-16  2019-02-15
#
#        ageAtInspection  consumption_on_premises_incidental_activity  tobacco  \
# 17672         0.726027                                            0        0
# 17673         4.120548                                            0        0
# 17674         0.879452                                            0        0
# 17675        10.169863                                            0        0
# 17676        10.756164                                            1        0
#
#        package_goods  outdoor_patio  public_place_of_amusement  \
# 17672              0              0                          0
# 17673              0              0                          0
# 17674              0              0                          0
# 17675              0              0                          0
# 17676              0              0                          0
#
#        limited_business_license  childrens_services_facility_license  tavern  \
# 17672                         0                                    0       0
# 17673                         1                                    0       0
# 17674                         0                                    0       0
# 17675                         0                                    0       0
# 17676                         0                                    0       0
#
#        regulated_business_license  filling_station  caterers_liquor_license  \
# 17672                           0                0                        0
# 17673                           0                0                        0
# 17674                           0                0                        0
# 17675                           0                0                        0
# 17676                           0                0                        0
#
#        mobile_food_license  precipIntensity  temperatureMax  windSpeed  \
# 17672                    0         0.002300       25.370000   7.963333
# 17673                    0         0.000100       34.586667   9.820000
# 17674                    0         0.000100       34.586667   9.820000
# 17675                    0         0.000383       72.946667  10.143333
# 17676                    0         0.001900       43.493333  16.720000
#
#        humidity  heat_burglary  heat_garbage  heat_sanitation  criticalFound
# 17672  0.776667      10.537839      1.376266        21.726951              0
# 17673  0.676667      56.680038     19.736283        32.355622              0
# 17674  0.676667      10.937753      0.000002        19.213021              1
# 17675  0.430000      40.972732      4.839867        20.946616              0
# 17676  0.720000      10.973102      5.672629        30.373055              0

# %%
# list column names
chicago_inspections_2011_to_2013.columns
# Out:
# Index(['Inspection_ID', 'Inspection_Date', 'DBA_Name', 'AKA_Name', 'License',
#        'Facility_Type', 'Risk', 'Address', 'City', 'State', 'Zip',
#        'Inspection_Type', 'Results', 'Latitude', 'Longitude', 'Location',
#        'Facility_Type_Clean', 'criticalCount', 'seriousCount', 'minorCount',
#        'pass_flag', 'fail_flag', 'pastFail', 'pastCritical', 'pastSerious',
#        'pastMinor', 'timeSinceLast', 'firstRecord', 'ID', 'LICENSE_ID',
#        'ACCOUNT_NUMBER', 'LEGAL_NAME', 'DOING_BUSINESS_AS_NAME', 'ADDRESS',
#        'CITY', 'STATE', 'ZIP_CODE', 'WARD', 'PRECINCT', 'WARD_PRECINCT',
#        'POLICE_DISTRICT', 'LICENSE_CODE', 'LICENSE_DESCRIPTION',
#        'BUSINESS_ACTIVITY_ID', 'BUSINESS_ACTIVITY', 'LICENSE_NUMBER',
#        'APPLICATION_TYPE', 'LICENSE_TERM_START_DATE',
#        'LICENSE_TERM_EXPIRATION_DATE', 'LICENSE_STATUS', 'LATITUDE',
#        'LONGITUDE', 'minDate', 'maxDate', 'ageAtInspection',
#        'consumption_on_premises_incidental_activity', 'tobacco',
#        'package_goods', 'outdoor_patio', 'public_place_of_amusement',
#        'limited_business_license', 'childrens_services_facility_license',
#        'tavern', 'regulated_business_license', 'filling_station',
#        'caterers_liquor_license', 'mobile_food_license', 'precipIntensity',
#        'temperatureMax', 'windSpeed', 'humidity', 'heat_burglary',
#        'heat_garbage', 'heat_sanitation', 'criticalFound'],
#       dtype='object')

# %%
# drop column names related to geography, identification, and pass/fail flags that perfectly predict the outcome
chicago_inspections_2011_to_2013.drop(columns = ['AKA_Name', 
                                                 'License',
                                                 'Address',
                                                 'City',
                                                 'State',
                                                 'Zip',
                                                 'Latitude',
                                                 'Longitude',
                                                 'Location',
                                                 'ID',
                                                 'LICENSE_ID',
                                                 'LICENSE_TERM_START_DATE',
                                                 'LICENSE_TERM_EXPIRATION_DATE',
                                                 'LICENSE_STATUS',
                                                 'ACCOUNT_NUMBER',
                                                 'LEGAL_NAME',
                                                 'DOING_BUSINESS_AS_NAME',
                                                 'ADDRESS',
                                                 'CITY',
                                                 'STATE',
                                                 'ZIP_CODE',
                                                 'WARD',
                                                 'PRECINCT',
                                                 'LICENSE_CODE',
                                                 'BUSINESS_ACTIVITY_ID',
                                                 'BUSINESS_ACTIVITY',
                                                 'LICENSE_NUMBER',
                                                 'LATITUDE',
                                                 'LONGITUDE',
                                                 'pass_flag',
                                                 'fail_flag'],
                                     inplace = True)

# set index
chicago_inspections_2011_to_2013.set_index(['Inspection_ID', 'DBA_Name'], inplace = True)

# %%
# convert the inspection date to a datetime format
chicago_inspections_2011_to_2013['Inspection_Date'] = pd.to_datetime(chicago_inspections_2011_to_2013['Inspection_Date'])

# %% [markdown]
# ### Visualization

# %% [markdown]
# Let's visualize what inspections look like over time.

# %%
# visualize inspections over time
# -----------
chicago_inspections_2011_to_2013['Inspection_MonthYear'] = chicago_inspections_2011_to_2013['Inspection_Date'].dt.to_period('M')
counts_by_day = chicago_inspections_2011_to_2013.groupby('Inspection_MonthYear').count().rename(columns = {'Facility_Type': 'Count'})['Count'].reset_index()
counts_by_day.set_index(["Inspection_MonthYear"], inplace = True)
counts_by_day.plot(title = "Inspections by Month and Year")
# Out:
# <Axes: title={'center': 'Inspections by Month and Year'}, xlabel='Inspection_MonthYear'>

# %% [markdown]
# Let's visualize what the distribution of results looks like.

# %%
# view inspection results
# -----------
sns.catplot(data = chicago_inspections_2011_to_2013,
           x = "Results",
           kind = "count")

plt.title("Inspection Results")
plt.show()

# %% [markdown]
# What if we separate results by facility type?

# %%
# view inspection results by facility type (restaurant or not)
# -----------
sns.catplot(data = chicago_inspections_2011_to_2013,
            x = "Results",
            kind = "count",
            hue = 'Facility_Type_Clean')

plt.title("Inspection Results by Facility Type")
plt.show();

# %%
# view inspection results by risk category
sns.countplot(data=chicago_inspections_2011_to_2013,
               x="Risk",
               hue="Results")  
plt.title("Inspection Results by Risk Category")
plt.show()

# %% [markdown]
# ## 2. Data Preprocessing and Cleaning

# %%
# drop datetime info
# -----------
chicago_inspections_2011_to_2013 = chicago_inspections_2011_to_2013.dropna().drop(['Inspection_Date',
                                                                                   'minDate',
                                                                                   'maxDate',
                                                                                   'Inspection_MonthYear'],
                                                                                  axis = 1)

# %%
# process target 
# -----------
y = chicago_inspections_2011_to_2013['Results']

# decide if you want to binarize the outcome variable 
# -----------
# comment out the following lines of code if you don't want to binarize the target variable
#y = y.replace({'Pass w/ Conditions': 'Pass'})
#lb_style = LabelBinarizer()
#y = lb_style.fit_transform(y)



# process features
# -----------

# create feature dataset
X = chicago_inspections_2011_to_2013.drop(columns = ['Results', 
                                                     'Facility_Type', 
                                                     'LICENSE_DESCRIPTION', 
                                                     'WARD_PRECINCT'])


# get dummies
X = pd.get_dummies(X)

# %%
# view feature datset
X.head()
# Out:
#                                             criticalCount  seriousCount  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                0             0
# 507211        PANERA BREAD                              0             0
# 507212        LITTLE QUIAPO RESTAURANT                  0             2
# 507216        SERGIO'S TAQUERIA PIZZA INC.              0             0
# 507219        TARGET STORE # T-2079                     0             2
#
#                                             minorCount  pastFail  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                             2         0
# 507211        PANERA BREAD                           3         0
# 507212        LITTLE QUIAPO RESTAURANT               6         0
# 507216        SERGIO'S TAQUERIA PIZZA INC.           6         0
# 507219        TARGET STORE # T-2079                  6         0
#
#                                             pastCritical  pastSerious  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                               0            0
# 507211        PANERA BREAD                             0            0
# 507212        LITTLE QUIAPO RESTAURANT                 0            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.             0            0
# 507219        TARGET STORE # T-2079                    0            0
#
#                                             pastMinor  timeSinceLast  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                            0            2.0
# 507211        PANERA BREAD                          0            2.0
# 507212        LITTLE QUIAPO RESTAURANT              0            2.0
# 507216        SERGIO'S TAQUERIA PIZZA INC.          0            2.0
# 507219        TARGET STORE # T-2079                 0            2.0
#
#                                             firstRecord  POLICE_DISTRICT  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                              1             19.0
# 507211        PANERA BREAD                            1             24.0
# 507212        LITTLE QUIAPO RESTAURANT                1             17.0
# 507216        SERGIO'S TAQUERIA PIZZA INC.            1             17.0
# 507219        TARGET STORE # T-2079                   1             24.0
#
#                                             ageAtInspection  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                          10.964384
# 507211        PANERA BREAD                         7.457534
# 507212        LITTLE QUIAPO RESTAURANT             4.578082
# 507216        SERGIO'S TAQUERIA PIZZA INC.         7.805479
# 507219        TARGET STORE # T-2079                5.290411
#
#                                             consumption_on_premises_incidental_activity  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                              0
# 507211        PANERA BREAD                                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                            0
# 507219        TARGET STORE # T-2079                                                   0
#
#                                             tobacco  package_goods  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                          1              0
# 507211        PANERA BREAD                        0              0
# 507212        LITTLE QUIAPO RESTAURANT            0              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.        0              0
# 507219        TARGET STORE # T-2079               0              1
#
#                                             outdoor_patio  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                0
# 507211        PANERA BREAD                              0
# 507212        LITTLE QUIAPO RESTAURANT                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.              0
# 507219        TARGET STORE # T-2079                     0
#
#                                             public_place_of_amusement  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             limited_business_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                           1
# 507211        PANERA BREAD                                         0
# 507212        LITTLE QUIAPO RESTAURANT                             0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                         0
# 507219        TARGET STORE # T-2079                                1
#
#                                             childrens_services_facility_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                      0
# 507211        PANERA BREAD                                                    0
# 507212        LITTLE QUIAPO RESTAURANT                                        0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                    0
# 507219        TARGET STORE # T-2079                                           0
#
#                                             tavern  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                         0
# 507211        PANERA BREAD                       0
# 507212        LITTLE QUIAPO RESTAURANT           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.       0
# 507219        TARGET STORE # T-2079              0
#
#                                             regulated_business_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             filling_station  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                  0
# 507211        PANERA BREAD                                0
# 507212        LITTLE QUIAPO RESTAURANT                    0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                0
# 507219        TARGET STORE # T-2079                       0
#
#                                             caterers_liquor_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                          0
# 507211        PANERA BREAD                                        0
# 507212        LITTLE QUIAPO RESTAURANT                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                        0
# 507219        TARGET STORE # T-2079                               0
#
#                                             mobile_food_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                      0
# 507211        PANERA BREAD                                    0
# 507212        LITTLE QUIAPO RESTAURANT                        0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                    0
# 507219        TARGET STORE # T-2079                           0
#
#                                             precipIntensity  temperatureMax  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                           0.014587       53.496667
# 507211        PANERA BREAD                         0.001907       59.046667
# 507212        LITTLE QUIAPO RESTAURANT             0.001907       59.046667
# 507216        SERGIO'S TAQUERIA PIZZA INC.         0.002737       56.153333
# 507219        TARGET STORE # T-2079                0.009987       52.730000
#
#                                             windSpeed  humidity  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                    13.340000  0.900000
# 507211        PANERA BREAD                  13.016667  0.550000
# 507212        LITTLE QUIAPO RESTAURANT      13.016667  0.550000
# 507216        SERGIO'S TAQUERIA PIZZA INC.  10.863333  0.616667
# 507219        TARGET STORE # T-2079         16.266667  0.690000
#
#                                             heat_burglary  heat_garbage  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                        26.992376     12.768572
# 507211        PANERA BREAD                      13.976557     12.895485
# 507212        LITTLE QUIAPO RESTAURANT          12.611239      8.004220
# 507216        SERGIO'S TAQUERIA PIZZA INC.      35.906383     26.238645
# 507219        TARGET STORE # T-2079              9.530785      3.401567
#
#                                             heat_sanitation  criticalFound  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                          37.748787              0
# 507211        PANERA BREAD                        15.412267              0
# 507212        LITTLE QUIAPO RESTAURANT             8.320330              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.        38.186618              0
# 507219        TARGET STORE # T-2079                2.126788              0
#
#                                             Risk_Risk 1 (High)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                 False
# 507211        PANERA BREAD                                True
# 507212        LITTLE QUIAPO RESTAURANT                    True
# 507216        SERGIO'S TAQUERIA PIZZA INC.                True
# 507219        TARGET STORE # T-2079                      False
#
#                                             Risk_Risk 2 (Medium)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                   False
# 507211        PANERA BREAD                                 False
# 507212        LITTLE QUIAPO RESTAURANT                     False
# 507216        SERGIO'S TAQUERIA PIZZA INC.                 False
# 507219        TARGET STORE # T-2079                         True
#
#                                             Risk_Risk 3 (Low)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                 True
# 507211        PANERA BREAD                              False
# 507212        LITTLE QUIAPO RESTAURANT                  False
# 507216        SERGIO'S TAQUERIA PIZZA INC.              False
# 507219        TARGET STORE # T-2079                     False
#
#                                             Inspection_Type_Canvass  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                       True
# 507211        PANERA BREAD                                     True
# 507212        LITTLE QUIAPO RESTAURANT                         True
# 507216        SERGIO'S TAQUERIA PIZZA INC.                     True
# 507219        TARGET STORE # T-2079                            True
#
#                                             Facility_Type_Clean_Other  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                         True
# 507211        PANERA BREAD                                      False
# 507212        LITTLE QUIAPO RESTAURANT                          False
# 507216        SERGIO'S TAQUERIA PIZZA INC.                      False
# 507219        TARGET STORE # T-2079                             False
#
#                                             Facility_Type_Clean_Restaurant  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             False
# 507211        PANERA BREAD                                            True
# 507212        LITTLE QUIAPO RESTAURANT                                True
# 507216        SERGIO'S TAQUERIA PIZZA INC.                            True
# 507219        TARGET STORE # T-2079                                   True
#
#                                             APPLICATION_TYPE_C_EXPA  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                      False
# 507211        PANERA BREAD                                    False
# 507212        LITTLE QUIAPO RESTAURANT                        False
# 507216        SERGIO'S TAQUERIA PIZZA INC.                    False
# 507219        TARGET STORE # T-2079                           False
#
#                                             APPLICATION_TYPE_C_LOC  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                     False
# 507211        PANERA BREAD                                   False
# 507212        LITTLE QUIAPO RESTAURANT                       False
# 507216        SERGIO'S TAQUERIA PIZZA INC.                   False
# 507219        TARGET STORE # T-2079                          False
#
#                                             APPLICATION_TYPE_ISSUE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                     False
# 507211        PANERA BREAD                                   False
# 507212        LITTLE QUIAPO RESTAURANT                       False
# 507216        SERGIO'S TAQUERIA PIZZA INC.                   False
# 507219        TARGET STORE # T-2079                          False
#
#                                             APPLICATION_TYPE_RENEW
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                      True
# 507211        PANERA BREAD                                    True
# 507212        LITTLE QUIAPO RESTAURANT                        True
# 507216        SERGIO'S TAQUERIA PIZZA INC.                    True
# 507219        TARGET STORE # T-2079                           True

# %%
# Display the counts of each class
class_distribution = y.value_counts()

# Show the class distribution
print("Original class distribution:\n", class_distribution)
# Out:
# Original class distribution:
#  Results
# Pass                  10259
# Fail                   3087
# Pass w/ Conditions     1965
# Name: count, dtype: int64

# %%
totaldata=15311

# %% [markdown]
# ## 3. Fit Models

# %% [markdown]
# Now choose 3 different machine learning techniques and apply them below. Choose from one of the algorithms we have used in lab (e.g., logistic regression, random forests, `AdaBoost()`, `xgboost()`, `VotingClassifer()`, or `BART`).
#
# Detail the basic logic and assumptions underlying each model, its pros/cons, and why it is a plausible choice for this problem. Also, be sure to do the following:
#
# 1. Import the appropriate library from sklearn
# 2. Set up a hyperparameter grid (check out our previous labs to see how to do this)
# 3. Find the best hyperparameters, and then fit your model (using either train/validation splits or cross-validation)

# %%
# load libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_classification
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# %%
# Set seed
np.random.seed(10)


# training and validation split 
X_train, X_validate, y_train, y_validate = train_test_split(X, 
                                                            y, 
                                                            train_size = .80, 
                                                            test_size = .20, 
                                                            stratify = y)

# %%
# Display the counts of each class
sample_distribution = y_train.value_counts()

# Show the class distribution

print("Class distribution of original dataset:\n", class_distribution)
print("Class distribution of sample:\n", sample_distribution)
# Out:
# Class distribution of original dataset:
#  Results
# Pass                  10259
# Fail                   3087
# Pass w/ Conditions     1965
# Name: count, dtype: int64
# Class distribution of sample:
#  Results
# Pass                  8207
# Fail                  2469
# Pass w/ Conditions    1572
# Name: count, dtype: int64

# %%
#Display ratios
# Class counts
pass_count = sample_distribution.get('Pass', 0)
fail_count = sample_distribution.get('Fail', 0)
pass_w_conditions_count = sample_distribution.get('Pass w/ Conditions', 0)

# Total observations
total_count = pass_count + fail_count + pass_w_conditions_count

# Calculate the ratios
pass_ratio = pass_count / total_count
fail_ratio = fail_count / total_count
pass_w_conditions_ratio = pass_w_conditions_count / total_count

# Print the ratios
print("Class balance before re-sampling:")
print(f"Pass: {pass_ratio:.3f}")
print(f"Fail: {fail_ratio:.3f}")
print(f"Pass w/ Conditions: {pass_w_conditions_ratio:.3f}")
# Out:
# Class balance before re-sampling:
# Pass: 0.670
# Fail: 0.202
# Pass w/ Conditions: 0.128

# %% [markdown]
# So the original ratios are about 0.670/0.202/0.128 for "Pass", "Fail", and "Pass w/Conditions" respectively. When we resample (below) by oversampling our underrepresented classes ("Fail" and "Pass w/ Conditions"), we'll start by changing this to 0.5/0.3/0.2 for "Pass", "Fail", and "Pass w/Conditions" respectively.

# %%
# install imbalance-learn 
# !pip install imbalanced-learn==0.09.1
# Out:
# Requirement already satisfied: imbalanced-learn==0.09.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (0.9.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from imbalanced-learn==0.09.1) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from imbalanced-learn==0.09.1) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from imbalanced-learn==0.09.1) (1.4.2)
# Requirement already satisfied: joblib>=1.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from imbalanced-learn==0.09.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from imbalanced-learn==0.09.1) (2.2.0)

# %%
# call libraries
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %%
# intitate instance of sampler and specify strategy
newpass_count = round (.5 * totaldata)
newfail_count = round (.3 * totaldata)
newpass_w_conditions_count = round (.2 * totaldata)
# Create a dictionary for the sampling strategy (desired target counts)
oversampling_strategy = {
    'Fail': newfail_count,
    'Pass w/ Conditions': newpass_w_conditions_count
}

undersampling_strategy = {
    'Pass': newpass_count,
}

# Apply the RandomOverSampler to increase the minority classes
random_over_sampler = RandomOverSampler(sampling_strategy=oversampling_strategy)

X_train, y_train = random_over_sampler.fit_resample(X_train, y_train)

print("Class distribution after oversampling:", Counter(y_train))

# Then, apply the RandomUnderSampler to reduce the majority class to .5 ratio
random_under_sampler = RandomUnderSampler(sampling_strategy=undersampling_strategy, replacement=False)

X_train, y_train = random_under_sampler.fit_resample(X_train, y_train)

print("Class distribution again after undersampling:", Counter(y_train))
# Out:
# Class distribution after oversampling: Counter({'Pass': 8207, 'Fail': 4593, 'Pass w/ Conditions': 3062})
# Class distribution again after undersampling: Counter({'Pass': 7656, 'Fail': 4593, 'Pass w/ Conditions': 3062})

# %%
#Display new ratios
# Class counts

finalpass_count = Counter(y_train).get('Pass', 0) 
finalfail_count = Counter(y_train).get('Fail', 0) 
finalpass_w_conditions_count = Counter(y_train).get('Pass w/ Conditions', 0)

# Total observations
finaltotal_count = finalpass_count + finalfail_count + finalpass_w_conditions_count

# Calculate the ratios
finalpass_ratio = finalpass_count / finaltotal_count
finalfail_ratio = finalfail_count / finaltotal_count
finalpass_w_conditions_ratio = finalpass_w_conditions_count / finaltotal_count

# Print the ratios
print("Class balance after over and undersampling:")
print(f"Pass: {finalpass_ratio:.3f}")
print(f"Fail: {finalfail_ratio:.3f}")
print(f"Pass w/ Conditions: {finalpass_w_conditions_ratio:.3f}")
# Out:
# Class balance after over and undersampling:
# Pass: 0.500
# Fail: 0.300
# Pass w/ Conditions: 0.200

# %% [markdown]
# ### Model 1 Random Forest

# %%
#initialize a random forest classifier
# ----------
rf_classifier = RandomForestClassifier(
    n_estimators=100,              # number of trees
    criterion='gini',              # splitting criterion
    max_depth=None,                # no limit on depth
    min_samples_split=2,           # min samples for splitting a node
    min_samples_leaf=1,            # min samples for a leaf
    min_weight_fraction_leaf=0.0,  # min weighted fraction of leaf
    max_features=None,             # use all features to split
    max_leaf_nodes=None,           # no limit on leaf nodes
    min_impurity_decrease=1e-07,   # early stopping threshold
    random_state=10,               # set random seed for reproducibility
)

# %%
# Fit the model to training data 
rf_classifier.fit(X_train, y_train)

# Make predictions on the validation set
y_pred = rf_classifier.predict(X_validate)

# %%
# Generate the confusion matrix
rfcf_matrix = confusion_matrix(y_validate, 
                             y_pred,
                             normalize="true")


# Convert to DataFrame
rfdf_cm = pd.DataFrame(rfcf_matrix, 
                     index=["Pass", "Pass w/ Conditions", "Fail"], 
                     columns=["Pass","Pass w/ Conditions",  "Fail"])

# Set figure specifications
plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # For label size

# Plot the heatmap
sns.heatmap(rfdf_cm, 
            annot=True, 
            annot_kws={"size": 16}, 
            fmt=".2f",  # Format the numbers as floats with 2 decimal places
            cmap="Blues",  # Color scheme for the heatmap
            cbar=True,     # Show the color bar
            square=True)   # Keep the heatmap square

# Titles and labels
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# specify cross-validation
# ----------
scores = cross_val_score(rf_classifier, 
                         X, 
                         y.to_numpy(), # Some algorithms will expect you to ravel the target
                         cv=5)

# %%
# calculate the average score across models
# ----------
scores.mean()
# Out:
# 0.9196004310097574

# %% [markdown]
# ### Model 2 Logistic Regression

# %%
# create a model
logit_reg = LogisticRegression(multi_class='ovr', solver='lbfgs', max_iter=1000)

# fit the model
logit_model = logit_reg.fit(X_train, y_train)

# predict on the validation data
y_pred = logit_model.predict(X_validate)
# Out:
# ['Pass' 'Pass w/ Conditions' 'Fail' 'Pass' 'Pass' 'Pass' 'Pass' 'Fail'
#  'Fail' 'Pass']

# %%
print("Classes used by the model:", logit_model.classes_)
# Out:
# Classes used by the model: ['Fail' 'Pass' 'Pass w/ Conditions']

# %%
# Create a confusion matrix
lrcf_matrix = confusion_matrix(y_validate, 
                             y_pred, 
                             normalize="true")

# Convert to DataFrame
lrdf_cm = pd.DataFrame(lrcf_matrix, 
                     index=["Pass", "Pass w/ Conditions", "Fail"], 
                     columns=["Pass", "Pass w/ Conditions", "Fail"])

# Set figure specifications
plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # For label size

# Plot the heatmap
sns.heatmap(lrdf_cm, 
            annot=True, 
            annot_kws={"size": 16}, 
            fmt=".2f",  # Format the numbers as floats with 2 decimal places
            cmap="Blues",  # Color scheme for the heatmap
            cbar=True,     # Show the color bar
            square=True)   # Keep the heatmap square

# Titles and labels
plt.title("Logistic Regression Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# hyperparameter tuning
# ----------

# import libraries
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore')
from sklearn.metrics import accuracy_score

# set parameters
param_grid = {'penalty': ['l1', 'l2', 'elasticnet'],
             'C': np.arange(.1, 1, .1),
             'fit_intercept': [True, False],
             'solver': ['liblinear', 'saga']}


# execute the grid search and fit to training data
logit_grid = GridSearchCV(logit_model, 
                          param_grid, 
                          cv=3)
logit_grid.fit(X_train, 
               y_train)

# choose best performing model
best_index = np.argmax(logit_grid.cv_results_["mean_test_score"])
best_logit_pred = logit_grid.best_estimator_.predict(X_validate)

# print results
print(logit_grid.cv_results_["params"][best_index])
print('Validation Accuracy', accuracy_score(best_logit_pred, y_validate))
# Out:
# {'C': 0.1, 'fit_intercept': True, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Validation Accuracy 0.920992491021874

# %%
# Create a confusion matrix
bestlrcf_matrix = confusion_matrix(y_validate, 
                             best_logit_pred, 
                             normalize = "true")

# Convert to DataFrame
bestlrdf_cm = pd.DataFrame(bestlrcf_matrix, 
                     index=["Pass", "Pass w/ Conditions", "Fail"], 
                     columns=["Pass", "Pass w/ Conditions", "Fail"])

# Set figure specifications
plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # For label size

# Plot the heatmap
sns.heatmap(bestlrdf_cm, 
            annot=True, 
            annot_kws={"size": 16}, 
            fmt=".2f",  # Format the numbers as floats with 2 decimal places
            cmap="Blues",  # Color scheme for the heatmap
            cbar=True,     # Show the color bar
            square=True)   # Keep the heatmap square

# Titles and labels
plt.title("Best Logistic Regression Model Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# ### Model 3 ADABoost

# %%
# initialize an adaptive boosting classifer 
# ----------
ada_classifier = AdaBoostClassifier(n_estimators=100)
ada_classifier.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
# calculate accuracy using cross validation
# ----------
scores = cross_val_score(ada_classifier,  # specify classifier
                         X,               # specify features
                         y.ravel(),       # specify labels
                         cv = 5)          # specify 5-fold cross validation

# %%
# calculate mean score across models 
# ----------
scores.mean()
# Out:
# 0.8759058892369749

# %% [markdown]
# ### Model 4 Voting Classifier

# %%
# Logistic Regression - using liblinear solver
# ----------
log_reg = LogisticRegression(random_state = 10, 
                             solver='liblinear')

# Random Forest
# ----------
rf_classifier = RandomForestClassifier(
                       criterion='gini',              # you can also use 'entropy' for information gain
                       max_depth=None,                # how deep tree nodes can go
                       min_samples_split=2,           # samples needed to split node
                       min_samples_leaf=1,            # samples needed for a leaf
                       min_weight_fraction_leaf=0.0,  # weight of samples needed for a node
                       max_features=None,             # number of features to look for when splitting
                       max_leaf_nodes=None,           # max nodes
                       min_impurity_decrease=1e-07,   # early stopping
                       random_state = 10)             # random seed

# AdaBoost
# ----------
ada_classifier = AdaBoostClassifier(n_estimators=100)


# specify voting classifiers
# ----------
voting_classifier = VotingClassifier(
                        # specify estimators to use
                        estimators = [('lr', log_reg),
                                     ('rf', rf_classifier),
                                     ('ada', ada_classifier)],
                        # specify voting
                        voting = 'hard')

# loop through each model to report accuracy
# ----------
for clf, label in zip([log_reg, 
                       rf_classifier, 
                       ada_classifier, 
                       voting_classifier], ['Logistic Regression', 
                                            'Random Forest', 
                                            'Ada Boost',
                                            'Ensemble']):
         scores = cross_val_score(clf, 
                                  X, 
                                  y.ravel(),
                                  scoring='accuracy', 
                                  cv=5)
         print('Accuracy: %0.2f [%s]' % (scores.mean(), label))
# Out:
# Accuracy: 0.92 [Logistic Regression]
# Accuracy: 0.92 [Random Forest]
# Accuracy: 0.88 [Ada Boost]
# Accuracy: 0.92 [Ensemble]

# %%
# specify a "soft" voting classifer in this iteration
# ----------
voting_classifier = VotingClassifier(
                        # specify estimators to use
                        estimators = [('lr', log_reg),
                                     ('rf', rf_classifier),
                                     ('ada', ada_classifier), 
                                     ],
                        # specify voting 
                        voting = 'soft')

# fit each classifer "c" to the data, predict the probability of the classifer and store as "probas"
probas = [c.fit(X, y.ravel()).predict_proba(X)[:,1] for c in (log_reg, 
                                                              rf_classifier,
                                                              ada_classifier,
                                                              voting_classifier)]

# %%
# create a dataset from the predicted probabilities
# ----------
probs_df = pd.DataFrame.from_records(probas).T # pulls the list of "probas" and stores as dataframe
probs_df.rename(columns = {0: 'logit',
                           1: 'rf',
                           2: 'ada',
                           3: 'ensemble'}, 
                inplace = True)

# view the first few observations
# ----------
probs_df.head(10)
# Out:
#           logit   rf       ada  ensemble
# 0  9.343544e-01  1.0  0.353305  0.762553
# 1  9.179047e-01  1.0  0.351706  0.756537
# 2  3.505169e-07  0.0  0.310976  0.103659
# 3  9.326469e-01  1.0  0.356954  0.763200
# 4  1.600197e-06  0.0  0.308961  0.102987
# 5  8.940825e-03  0.0  0.317307  0.108749
# 6  9.222212e-01  1.0  0.347461  0.756561
# 7  8.856286e-01  1.0  0.347323  0.744317
# 8  9.289662e-01  1.0  0.353117  0.760694
# 9  9.123533e-01  1.0  0.352306  0.754887

# %% [markdown]
# Concern for Kasey, rf looking strange

# %%
# visualize distributions
# ----------
# set figure parameters
fig = plt.figure(figsize=(15, 10))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# logit
ax = fig.add_subplot(2, 3, 1)
sns.histplot(probs_df, x="logit", ax=ax)

# random forest
ax = fig.add_subplot(2, 3, 2)
sns.histplot(probs_df, x="rf", ax=ax)

# adaptive boosting
ax = fig.add_subplot(2, 3, 3)
sns.histplot(probs_df, x="ada", ax=ax)

# ensemble
ax = fig.add_subplot(2, 3, 5)
sns.histplot(probs_df, x="ensemble", ax=ax)

# show plot 
plt.show()

# %% [markdown]
# ### Validation Metrics

# %% [markdown]
# Be sure to explain which of these metrics you would want to prioritize when conducting predictive auditing in this context and why.
#
# **Hint**: Try writing a for loop to use [`cross_val_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html) to check for accuracy, precision, recall and f1 across all of your models.

# %%
import numpy as np
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.datasets import load_iris
from sklearn.metrics import make_scorer, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold, cross_validate



# Use StratifiedKFold to maintain class distribution in each fold
stratified_kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Iterate over classifiers and labels
for clf, label in zip([log_reg, 
                       rf_classifier, 
                       ada_classifier, 
                       voting_classifier], 
                      ["Logistic Regression", 
                       "Random Forest", 
                       "Ada Boost",
                       "Ensemble"]):

    # Perform cross-validation with StratifiedKFold
    scores = cross_validate(clf, X, y.ravel(), 
                            scoring={'accuracy': 'accuracy', 
                                     'precision': 'precision_weighted', 
                                     'recall': 'recall_weighted', 
                                     'f1': 'f1_weighted'}, 
                            cv=stratified_kf)
    
    # Print the average of each metric
    print(f'{label} - '
          f'Accuracy: {scores["test_accuracy"].mean():.2f}, '
          f'Precision: {scores["test_precision"].mean():.2f}, '
          f'Recall: {scores["test_recall"].mean():.2f}, '
          f'F1: {scores["test_f1"].mean():.2f}')
# Out:
# Logistic Regression - Accuracy: 0.92, Precision: 0.92, Recall: 0.92, F1: 0.91
# Random Forest - Accuracy: 0.93, Precision: 0.93, Recall: 0.93, F1: 0.92
# Ada Boost - Accuracy: 0.88, Precision: 0.89, Recall: 0.88, F1: 0.88
# Ensemble - Accuracy: 0.92, Precision: 0.93, Recall: 0.92, F1: 0.92

# %% [markdown]
# Because our goal is to conduct predictive auditing for at-risk establishments, we need to weigh the 'stakes' of our predictions.
#
# Accuracy
# In machine learning, accuracy isn't the only metric that we might care about. Accuracy is an expression of ratio of correct observations relative to incorrect observations. This calculation alone does not tell us much about whether we did a good job predicting all of the other categories that we might be concerned about.
#
# Consider our census dataset. We saw earlier that the target data is not equally distributed - there were far more people with "<=50k" income. As we saw in our confusion matrices, our algorithms tended to predict observations belonging to the "<=50k" category remarkably well, but tended to do much worse with the ">50k" category.
#
# QUESTION: Why do you think this might be the case?
#
# ANSWER: The class imbalance means that an algorithm can tend to do better just by picking the majority class. Accuracy might look good this way, but with a severe enough class imbalance, this score could be misleading.
#
# Precision is a measure of how well calibrated predictions are.
# TP/(TP+FP)
# This formula tell us of the predictions in the positive class we made, how many were correct.
#
# Recall is defined as:
# TP/(TP+FN)
# Of all of the positive class members in the ground truth labels, how many did we successfully predict as positive?
#
# The precision-recall tradeoff can be managed in a few different ways. One popular metric is the F1 score
# F1 is advantageous because the numerator can be penalized by either low precision OR recall. The disadvantage of this approach is that without adjustments, the F1 score prioritizes precision and recall equally. Depending on the application, we might care about one more than the other.

# %% [markdown]
# ## 4. Policy Simulation

# %% [markdown]
# ### Interpretable Machine Learning
#
# Use tools like coefficient plots or feature importance plots to investigate your models. Which features contribute to your predictions? Are there any additional features you wish you could incorporate that you don't have available in this analysis?
#
# **Hint**: Use tools like feature importance plots and coefficient plots.

# %%
X.columns
# Out:
# Index(['criticalCount', 'seriousCount', 'minorCount', 'pastFail',
#        'pastCritical', 'pastSerious', 'pastMinor', 'timeSinceLast',
#        'firstRecord', 'POLICE_DISTRICT', 'ageAtInspection',
#        'consumption_on_premises_incidental_activity', 'tobacco',
#        'package_goods', 'outdoor_patio', 'public_place_of_amusement',
#        'limited_business_license', 'childrens_services_facility_license',
#        'tavern', 'regulated_business_license', 'filling_station',
#        'caterers_liquor_license', 'mobile_food_license', 'precipIntensity',
#        'temperatureMax', 'windSpeed', 'humidity', 'heat_burglary',
#        'heat_garbage', 'heat_sanitation', 'criticalFound',
#        'Risk_Risk 1 (High)', 'Risk_Risk 2 (Medium)', 'Risk_Risk 3 (Low)',
#        'Inspection_Type_Canvass', 'Facility_Type_Clean_Other',
#        'Facility_Type_Clean_Restaurant', 'APPLICATION_TYPE_C_EXPA',
#        'APPLICATION_TYPE_C_LOC', 'APPLICATION_TYPE_ISSUE',
#        'APPLICATION_TYPE_RENEW'],
#       dtype='object')

# %% [markdown]
# ### Model 1 (Random Forest) Features

# %%
# import library
import seaborn as sns

# ----------
rf_classifier.fit(X, y.to_numpy())

# create feature importance dataframe
rffeat_importances = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf_classifier.feature_importances_
})

# plot 
plt.figure(figsize=(10, 6))
sns.barplot(x="Importance", 
            y="Feature", 
            data=rffeat_importances.nlargest(10, 'Importance'))

plt.title("Top 10 Important Features from Random Forest")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Model 2 (Logistic Regression) Features

# %%
# Extract coefficients for each class and transpose the coefficient matrix
coefficients = np.transpose(logit_model.coef_)  

# Flatten the coefficients into a single column, while keeping track of the feature names and classes
logit_data = pd.DataFrame(coefficients, columns=[f'Class_{i}' for i in range(logit_model.coef_.shape[0])],
                          index=X.columns)

# Flatten the DataFrame so that you have a long format, keeping track of which class and feature the coefficient belongs to
flat_logit_data = logit_data.stack().reset_index()
flat_logit_data.columns = ['Feature', 'Class', 'Coefficient']

# Add a column for absolute coefficients to sort by magnitude
flat_logit_data['abs_coef'] = flat_logit_data['Coefficient'].abs()

# Get the top 10 features based on the absolute coefficient value (including the sign)
top_10_features = flat_logit_data.nlargest(10, 'abs_coef')

# Plot
plt.figure(figsize=(12, 8))

# Plot the top 10 features (you can keep the sign by plotting the coefficients directly)
sns.barplot(x='Coefficient', y='Feature', data=top_10_features, orient='h')

# Title and labels
plt.title("Top 10 Features by Absolute Coefficient Value Across All Classes")
plt.xlabel("Coefficient Value")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# ### Model 3 (ADABoost) Features

# %%
# Access the feature importances
importance = ada_classifier.feature_importances_

# Create a DataFrame to display the feature importances with the feature names
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importance
})

# Sort the DataFrame by the importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Select the top 12 features 
top_10_features = feature_importance_df.head(10)

# Print the top 12 feature importances
print(top_10_features)

# Plot the top 15 most important features
plt.figure(figsize=(10, 6))
plt.barh(top_10_features['Feature'], top_10_features['Importance'])
plt.xlabel('Importance')
plt.title('Top 10 Most Important Features from AdaBoost')
plt.gca().invert_yaxis()  # To display the most important features at the top
plt.show()
# Out:
#             Feature  Importance
# 1      seriousCount        0.15
# 24   temperatureMax        0.11
# 28     heat_garbage        0.10
# 9   POLICE_DISTRICT        0.08
# 2        minorCount        0.06
# 27    heat_burglary        0.06
# 29  heat_sanitation        0.06
# 30    criticalFound        0.06
# 25        windSpeed        0.05
# 7     timeSinceLast        0.04

# %% [markdown]
# ### Prioritize Audits

# %% [markdown]
# **Hint**: Look up the [`.predict()`](https://www.kite.com/python/docs/sklearn.linear_model.SGDRegressor.predict), [`.predict_proba()`](https://www.kite.com/python/docs/sklearn.linear_model.LogisticRegression.predict_proba), and [`.sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) methods. Then:
# 1. Choose one of your models (or train a new simplified model or ensemble!) to predict outcomes and probabilities.
# 2. Order your audits by their probability of detecting a "Fail" score
# 3. Plot your distribution of pass/fail among the first 1,000 observations in the dataset
# 4. Simulate random audits on the full chicago_2011_to_2013.csv dataset by picking 1,000 observations at random

# %%
#
# 1. Choose one of your models (or train a new simplified model or ensemble!) to predict outcomes and probabilities.
# -----------

# %%
# create a new logistic regression model
newlogit_reg = LogisticRegression()

# fit the model
newlogit_model = newlogit_reg.fit(X_train, y_train.to_numpy())

# predict on the validation data
newy_pred = newlogit_model.predict(X_validate)

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_validate, newy_pred, normalize="true")

# Convert to DataFrame
bestlrdf_cm = pd.DataFrame(cm, 
                           index=["Pass", "Pass w/ Conditions", "Fail"],  
                           columns=["Pass", "Pass w/ Conditions", "Fail"])  

# Set figure specifications
plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # For label size

# Plot the heatmap using the DataFrame
sns.heatmap(bestlrdf_cm, 
            annot=True, 
            annot_kws={"size": 16}, 
            fmt=".2f",  # Format the numbers as floats with 2 decimal places
            cmap="Blues",  # Color scheme for the heatmap
            cbar=True,     # Show the color bar
            square=True)   # Keep the heatmap square

# Titles and labels
plt.title("New Logistic Regression Model Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
#
# Order audits by their probability of detecting a "Fail" score
# -----------
# Get predicted probabilities for "Fail" class
y_probs = logit_model.predict_proba(X_validate)[:, 0]  # Probabilities for 'Fail' (0th class)

#Extract the 'Inspection_ID' and 'DBA_Name' from the index for X_validate (since they're part of the index now)
inspection_ids = chicago_inspections_2011_to_2013.loc[X_validate.index].index.get_level_values('Inspection_ID')
DBA_names = chicago_inspections_2011_to_2013.loc[X_validate.index].index.get_level_values('DBA_Name')


# Create the DataFrame with Fail_Probability and the extracted Inspection_ID
audit_results = pd.DataFrame({
    'Inspection_ID': inspection_ids,  # Extracted from the index
    'DBA_Name': DBA_names,  # Extracted from the index
    'Fail_Probability': y_probs      # The predicted probability for 'Fail'
})

# Add the 'Results' column from y_validate (which contains the actual 'Pass' or 'Fail')
audit_results['Results'] = y_validate.values

# Sort by Fail Probability in descending order
audit_results_sorted = audit_results.sort_values(by='Fail_Probability', ascending=False)

# Display the top 10 audits with the highest 'Fail' probabilities
top_10_audits = audit_results_sorted.head(10)
print(top_10_audits)
# Out:
#       Inspection_ID                       DBA_Name  Fail_Probability Results
# 1672        1174311  LA NUEVA IMAGEN GROCERY, INC.          0.999968    Fail
# 1148        1360962      THE STRETCH BAR AND GRILL          0.999957    Fail
# 238         1277660                   UKRAINA DELI          0.999943    Fail
# 425         1335907                   DELUXE DINER          0.999932    Fail
# 171          612501           ELLY'S PANCAKE HOUSE          0.999907    Fail
# 812          659600            THE JERK GRILL, LLC          0.999719    Fail
# 2954        1300813                           BITE          0.999707    Fail
# 595         1188494               NEW PUNJAB SWEET          0.999673    Fail
# 1139        1285737        FLAME N HOT CONVENIENCE          0.999656    Fail
# 714         1360378                          SOCCA          0.999448    Fail

# %%
#
# Plot your distribution of pass/fail among the first 1,000 observations in the dataset
# -----------
first_1000 = audit_results.head(1000)

# Count the occurrences of 'Pass' 'Pass w/ conditions' and 'Fail'
results_counts = first_1000['Results'].value_counts()

# Create a bar plot for the count distribution of results
plt.figure(figsize=(8, 6))
sns.barplot(x=results_counts.index, y=results_counts.values, palette="Blues_d")

# Set labels and title
plt.xlabel('Result')
plt.ylabel('Count')
plt.title('Distribution of Pass/Fail in the First 1,000 Observations')

# Show the plot
plt.show()

# %%
#
# 4. Simulate random audits on the full chicago_2011_to_2013.csv dataset by picking 1,000 observations at random
# -----------
# Simulate random audits by selecting 1,000 random rows
random_audits = chicago_inspections_2011_to_2013.sample(n=1000, random_state=42)  # Set random_state for reproducibility

# Display the first few rows of the randomly selected audits
random_audits.head(10)
# Out:
#                                               Facility_Type             Risk  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant         Restaurant    Risk 1 (High)
# 670538        SUBWAY 3634                        Restaurant    Risk 1 (High)
# 598531        MANGIA FRESCA INC.,                Restaurant    Risk 1 (High)
# 1184324       PADDY O FEGAN'S                    Restaurant    Risk 1 (High)
# 1376178       YOLK CAFE                          Restaurant    Risk 1 (High)
# 1202447       LA CONCHA                          Restaurant  Risk 2 (Medium)
# 1271226       JOLA & HETMAN DELI, LTD.        Grocery Store    Risk 1 (High)
# 569826        PALOMAR CHICAGO                    Restaurant    Risk 1 (High)
# 1102280       TACO BURRITO KING I, INC.          Restaurant    Risk 1 (High)
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE     Restaurant    Risk 1 (High)
#
#                                              Inspection_Type  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant             Canvass
# 670538        SUBWAY 3634                            Canvass
# 598531        MANGIA FRESCA INC.,                    Canvass
# 1184324       PADDY O FEGAN'S                        Canvass
# 1376178       YOLK CAFE                              Canvass
# 1202447       LA CONCHA                              Canvass
# 1271226       JOLA & HETMAN DELI, LTD.               Canvass
# 569826        PALOMAR CHICAGO                        Canvass
# 1102280       TACO BURRITO KING I, INC.              Canvass
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE         Canvass
#
#                                                          Results  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                    Pass
# 670538        SUBWAY 3634                                   Fail
# 598531        MANGIA FRESCA INC.,                           Pass
# 1184324       PADDY O FEGAN'S                               Pass
# 1376178       YOLK CAFE                       Pass w/ Conditions
# 1202447       LA CONCHA                                     Pass
# 1271226       JOLA & HETMAN DELI, LTD.                      Pass
# 569826        PALOMAR CHICAGO                               Pass
# 1102280       TACO BURRITO KING I, INC.                     Pass
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                Pass
#
#                                              Facility_Type_Clean  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant              Restaurant
# 670538        SUBWAY 3634                             Restaurant
# 598531        MANGIA FRESCA INC.,                     Restaurant
# 1184324       PADDY O FEGAN'S                         Restaurant
# 1376178       YOLK CAFE                               Restaurant
# 1202447       LA CONCHA                               Restaurant
# 1271226       JOLA & HETMAN DELI, LTD.                     Other
# 569826        PALOMAR CHICAGO                         Restaurant
# 1102280       TACO BURRITO KING I, INC.               Restaurant
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE          Restaurant
#
#                                               criticalCount  seriousCount  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                  0             0
# 670538        SUBWAY 3634                                 1             1
# 598531        MANGIA FRESCA INC.,                         0             0
# 1184324       PADDY O FEGAN'S                             0             0
# 1376178       YOLK CAFE                                   1             1
# 1202447       LA CONCHA                                   0             0
# 1271226       JOLA & HETMAN DELI, LTD.                    0             0
# 569826        PALOMAR CHICAGO                             0             0
# 1102280       TACO BURRITO KING I, INC.                   0             0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE              0             0
#
#                                               minorCount  pastFail  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant               4         0
# 670538        SUBWAY 3634                              4         0
# 598531        MANGIA FRESCA INC.,                      4         0
# 1184324       PADDY O FEGAN'S                          3         0
# 1376178       YOLK CAFE                                1         0
# 1202447       LA CONCHA                                6         1
# 1271226       JOLA & HETMAN DELI, LTD.                 5         0
# 569826        PALOMAR CHICAGO                          3         0
# 1102280       TACO BURRITO KING I, INC.                4         0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE           7         0
#
#                                               pastCritical  pastSerious  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                 0            0
# 670538        SUBWAY 3634                                0            0
# 598531        MANGIA FRESCA INC.,                        0            0
# 1184324       PADDY O FEGAN'S                            0            0
# 1376178       YOLK CAFE                                  0            0
# 1202447       LA CONCHA                                  2            1
# 1271226       JOLA & HETMAN DELI, LTD.                   0            0
# 569826        PALOMAR CHICAGO                            0            0
# 1102280       TACO BURRITO KING I, INC.                  0            0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE             0            0
#
#                                               pastMinor  timeSinceLast  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant              0       2.000000
# 670538        SUBWAY 3634                             0       2.000000
# 598531        MANGIA FRESCA INC.,                     0       2.000000
# 1184324       PADDY O FEGAN'S                         0       2.000000
# 1376178       YOLK CAFE                               1       1.671233
# 1202447       LA CONCHA                               6       1.032877
# 1271226       JOLA & HETMAN DELI, LTD.                0       2.000000
# 569826        PALOMAR CHICAGO                         0       2.000000
# 1102280       TACO BURRITO KING I, INC.               6       0.501370
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE          4       0.583562
#
#                                               firstRecord WARD_PRECINCT  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                1          31-4
# 670538        SUBWAY 3634                               1         49-17
# 598531        MANGIA FRESCA INC.,                       1          11-1
# 1184324       PADDY O FEGAN'S                           1          27-1
# 1376178       YOLK CAFE                                 0         42-41
# 1202447       LA CONCHA                                 0         12-21
# 1271226       JOLA & HETMAN DELI, LTD.                  1         31-37
# 569826        PALOMAR CHICAGO                           1         42-22
# 1102280       TACO BURRITO KING I, INC.                 0         29-37
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE            0         25-16
#
#                                               POLICE_DISTRICT  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                 25.0
# 670538        SUBWAY 3634                                24.0
# 598531        MANGIA FRESCA INC.,                         9.0
# 1184324       PADDY O FEGAN'S                            12.0
# 1376178       YOLK CAFE                                  18.0
# 1202447       LA CONCHA                                   9.0
# 1271226       JOLA & HETMAN DELI, LTD.                   25.0
# 569826        PALOMAR CHICAGO                            18.0
# 1102280       TACO BURRITO KING I, INC.                  16.0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE             12.0
#
#                                                     LICENSE_DESCRIPTION  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant      Retail Food Establishment
# 670538        SUBWAY 3634                     Retail Food Establishment
# 598531        MANGIA FRESCA INC.,             Retail Food Establishment
# 1184324       PADDY O FEGAN'S                 Retail Food Establishment
# 1376178       YOLK CAFE                       Retail Food Establishment
# 1202447       LA CONCHA                       Retail Food Establishment
# 1271226       JOLA & HETMAN DELI, LTD.        Retail Food Establishment
# 569826        PALOMAR CHICAGO                 Retail Food Establishment
# 1102280       TACO BURRITO KING I, INC.       Retail Food Establishment
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE  Retail Food Establishment
#
#                                              APPLICATION_TYPE  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                RENEW
# 670538        SUBWAY 3634                               RENEW
# 598531        MANGIA FRESCA INC.,                       RENEW
# 1184324       PADDY O FEGAN'S                           ISSUE
# 1376178       YOLK CAFE                                 RENEW
# 1202447       LA CONCHA                                 RENEW
# 1271226       JOLA & HETMAN DELI, LTD.                  RENEW
# 569826        PALOMAR CHICAGO                           ISSUE
# 1102280       TACO BURRITO KING I, INC.                 RENEW
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE            RENEW
#
#                                               ageAtInspection  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant             8.123288
# 670538        SUBWAY 3634                            5.558904
# 598531        MANGIA FRESCA INC.,                    3.024658
# 1184324       PADDY O FEGAN'S                        0.827397
# 1376178       YOLK CAFE                              3.380822
# 1202447       LA CONCHA                             11.142466
# 1271226       JOLA & HETMAN DELI, LTD.               6.671233
# 569826        PALOMAR CHICAGO                        1.947945
# 1102280       TACO BURRITO KING I, INC.              6.473973
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE         9.991781
#
#                                               consumption_on_premises_incidental_activity  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                                                1
# 670538        SUBWAY 3634                                                               0
# 598531        MANGIA FRESCA INC.,                                                       0
# 1184324       PADDY O FEGAN'S                                                           0
# 1376178       YOLK CAFE                                                                 0
# 1202447       LA CONCHA                                                                 0
# 1271226       JOLA & HETMAN DELI, LTD.                                                  0
# 569826        PALOMAR CHICAGO                                                           1
# 1102280       TACO BURRITO KING I, INC.                                                 0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                                            0
#
#                                               tobacco  package_goods  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant            1              0
# 670538        SUBWAY 3634                           0              0
# 598531        MANGIA FRESCA INC.,                   0              0
# 1184324       PADDY O FEGAN'S                       0              0
# 1376178       YOLK CAFE                             0              0
# 1202447       LA CONCHA                             0              0
# 1271226       JOLA & HETMAN DELI, LTD.              0              0
# 569826        PALOMAR CHICAGO                       0              0
# 1102280       TACO BURRITO KING I, INC.             0              0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE        0              0
#
#                                               outdoor_patio  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                  0
# 670538        SUBWAY 3634                                 0
# 598531        MANGIA FRESCA INC.,                         0
# 1184324       PADDY O FEGAN'S                             0
# 1376178       YOLK CAFE                                   0
# 1202447       LA CONCHA                                   0
# 1271226       JOLA & HETMAN DELI, LTD.                    0
# 569826        PALOMAR CHICAGO                             1
# 1102280       TACO BURRITO KING I, INC.                   0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE              0
#
#                                               public_place_of_amusement  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                              0
# 670538        SUBWAY 3634                                             0
# 598531        MANGIA FRESCA INC.,                                     0
# 1184324       PADDY O FEGAN'S                                         0
# 1376178       YOLK CAFE                                               0
# 1202447       LA CONCHA                                               0
# 1271226       JOLA & HETMAN DELI, LTD.                                0
# 569826        PALOMAR CHICAGO                                         0
# 1102280       TACO BURRITO KING I, INC.                               0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                          0
#
#                                               limited_business_license  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                             0
# 670538        SUBWAY 3634                                            0
# 598531        MANGIA FRESCA INC.,                                    0
# 1184324       PADDY O FEGAN'S                                        0
# 1376178       YOLK CAFE                                              0
# 1202447       LA CONCHA                                              0
# 1271226       JOLA & HETMAN DELI, LTD.                               0
# 569826        PALOMAR CHICAGO                                        0
# 1102280       TACO BURRITO KING I, INC.                              0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                         0
#
#                                               childrens_services_facility_license  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                                        0
# 670538        SUBWAY 3634                                                       0
# 598531        MANGIA FRESCA INC.,                                               0
# 1184324       PADDY O FEGAN'S                                                   0
# 1376178       YOLK CAFE                                                         0
# 1202447       LA CONCHA                                                         0
# 1271226       JOLA & HETMAN DELI, LTD.                                          0
# 569826        PALOMAR CHICAGO                                                   0
# 1102280       TACO BURRITO KING I, INC.                                         0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                                    0
#
#                                               tavern  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant           0
# 670538        SUBWAY 3634                          0
# 598531        MANGIA FRESCA INC.,                  0
# 1184324       PADDY O FEGAN'S                      0
# 1376178       YOLK CAFE                            0
# 1202447       LA CONCHA                            0
# 1271226       JOLA & HETMAN DELI, LTD.             0
# 569826        PALOMAR CHICAGO                      0
# 1102280       TACO BURRITO KING I, INC.            0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE       0
#
#                                               regulated_business_license  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                               0
# 670538        SUBWAY 3634                                              0
# 598531        MANGIA FRESCA INC.,                                      0
# 1184324       PADDY O FEGAN'S                                          0
# 1376178       YOLK CAFE                                                0
# 1202447       LA CONCHA                                                0
# 1271226       JOLA & HETMAN DELI, LTD.                                 0
# 569826        PALOMAR CHICAGO                                          0
# 1102280       TACO BURRITO KING I, INC.                                0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                           0
#
#                                               filling_station  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                    0
# 670538        SUBWAY 3634                                   0
# 598531        MANGIA FRESCA INC.,                           0
# 1184324       PADDY O FEGAN'S                               0
# 1376178       YOLK CAFE                                     0
# 1202447       LA CONCHA                                     0
# 1271226       JOLA & HETMAN DELI, LTD.                      0
# 569826        PALOMAR CHICAGO                               0
# 1102280       TACO BURRITO KING I, INC.                     0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                0
#
#                                               caterers_liquor_license  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                            0
# 670538        SUBWAY 3634                                           0
# 598531        MANGIA FRESCA INC.,                                   0
# 1184324       PADDY O FEGAN'S                                       0
# 1376178       YOLK CAFE                                             0
# 1202447       LA CONCHA                                             0
# 1271226       JOLA & HETMAN DELI, LTD.                              0
# 569826        PALOMAR CHICAGO                                       1
# 1102280       TACO BURRITO KING I, INC.                             0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                        0
#
#                                               mobile_food_license  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant                        0
# 670538        SUBWAY 3634                                       0
# 598531        MANGIA FRESCA INC.,                               0
# 1184324       PADDY O FEGAN'S                                   0
# 1376178       YOLK CAFE                                         0
# 1202447       LA CONCHA                                         0
# 1271226       JOLA & HETMAN DELI, LTD.                          0
# 569826        PALOMAR CHICAGO                                   0
# 1102280       TACO BURRITO KING I, INC.                         0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE                    0
#
#                                               precipIntensity  temperatureMax  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant             0.017333       85.460000
# 670538        SUBWAY 3634                            0.001813       37.966667
# 598531        MANGIA FRESCA INC.,                    0.000330       37.680000
# 1184324       PADDY O FEGAN'S                        0.000383       74.166667
# 1376178       YOLK CAFE                              0.000400       23.563333
# 1202447       LA CONCHA                              0.001707       64.803333
# 1271226       JOLA & HETMAN DELI, LTD.               0.006697       86.640000
# 569826        PALOMAR CHICAGO                        0.000000       43.833333
# 1102280       TACO BURRITO KING I, INC.              0.001417       80.163333
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE         0.000330       82.510000
#
#                                               windSpeed  humidity  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant       9.113333  0.553333
# 670538        SUBWAY 3634                     10.010000  0.733333
# 598531        MANGIA FRESCA INC.,              9.140000  0.743333
# 1184324       PADDY O FEGAN'S                 10.043333  0.406667
# 1376178       YOLK CAFE                       11.176667  0.730000
# 1202447       LA CONCHA                        8.523333  0.703333
# 1271226       JOLA & HETMAN DELI, LTD.        10.860000  0.490000
# 569826        PALOMAR CHICAGO                 13.390000  0.610000
# 1102280       TACO BURRITO KING I, INC.       12.090000  0.493333
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE   9.503333  0.620000
#
#                                               heat_burglary  heat_garbage  \
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant          20.376028     18.461970
# 670538        SUBWAY 3634                          6.103809     10.314125
# 598531        MANGIA FRESCA INC.,                 10.073717      5.395386
# 1184324       PADDY O FEGAN'S                     15.924885      4.341055
# 1376178       YOLK CAFE                            6.833245      0.000080
# 1202447       LA CONCHA                           22.211570     22.127602
# 1271226       JOLA & HETMAN DELI, LTD.            25.872011     15.386534
# 569826        PALOMAR CHICAGO                      5.243900      0.950179
# 1102280       TACO BURRITO KING I, INC.            8.237816     10.731768
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE       4.996969      7.028221
#
#                                               heat_sanitation  criticalFound
# Inspection_ID DBA_Name
# 1277334       Aquarius Club & Restaurant            33.690196              0
# 670538        SUBWAY 3634                           11.596479              1
# 598531        MANGIA FRESCA INC.,                    4.106813              0
# 1184324       PADDY O FEGAN'S                        7.117970              0
# 1376178       YOLK CAFE                              9.520084              1
# 1202447       LA CONCHA                             13.071734              0
# 1271226       JOLA & HETMAN DELI, LTD.              23.363243              0
# 569826        PALOMAR CHICAGO                       19.574401              0
# 1102280       TACO BURRITO KING I, INC.              8.381702              0
# 1184508       CARMICHAEL'S CHICAGO STEAK HSE        11.970744              0

# %% [markdown]
# ### Predict on 2014 inspection data
#
# Use your favorite model to make predictions based on the features using the "Chicago Inspection 2014_updated.csv" file. Treat this as you would a test dataset. This means you will have to format the features (including removing some features and getting dummies) and the label (binarize and recode) in the same way you did the training data. (Remember the "Results" column is your label). You will then compare your predictions with the actual.

# %%
# data processing
# -----------

# process features
X_test2014 = chicago_inspections_2014[...]

# process target 
y_test2014 = chicago_inspections_2014[...]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Ellipsis
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 5
#       1 # data processing
#       2 # -----------
#       3
#       4 # process features
# ----> 5 X_test2014 = chicago_inspections_2014[...]
#       7 # process target
#       8 y_test2014 = chicago_inspections_2014[...]
#
# File /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: Ellipsis

# %%
# predict and compare 
# -----------

# %%
# evaluate
# -----------

# %% [markdown]
# ## 5. Discussion Questions

# %% [markdown]
# 1. Why do we need metrics beyond accuracy when using machine learning in the social sciences and public policy?

# %% [markdown]
# **YOUR ANSWER HERE**...

# %% [markdown]
# 2. Imagine that establishments learned about the algorithm being used to determine who gets audited and they started adjusting their behavior (and changing certain key features about themselves that were important for the prediction) to avoid detection. How could policymakers address this interplay between algorithmic decisionmaking and real world behavior?

# %% [markdown]
# **YOUR ANSWER HERE**...
