# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# **Enter your Name:**Taylor Galdi
#
# *Semester:* Fall 2024

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %pip install keras
# %pip install tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: keras in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (3.7.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.3.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# 2024-12-12 14:05:13.321718: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanestarget = nhanes_scaled

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)
print(nhanes_scaled.head())
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ033    OHQ770    OHQ845  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -0.646584
# 73576 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -1.539259
# 73579 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -1.539259
# 73581 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -0.646584
# 73584 -0.057306  0.128246  0.080373  ... -0.680203 -2.605509  0.246091
#
#         PAAQUEX    SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x
# SEQN
# 73568 -0.484200  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440
# 73576 -0.484200  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812
# 73579  2.065262 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812
# 73581 -0.484200  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440
# 73584  2.065262  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812
#
# [5 rows x 241 columns]

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %%
# scale data (without scaling the index)
# ----------
scaler = StandardScaler()
X = scaler.fit_transform(nhanes_scaled)

# Convert the scaled data back into a DataFrame with the original column names and index
X = pd.DataFrame(X, columns=nhanes_scaled.columns, index=nhanes_scaled.index)

# Verify the result
print(X.head())
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ033    OHQ770    OHQ845  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -0.646584
# 73576 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -1.539259
# 73579 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -1.539259
# 73581 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -0.646584
# 73584 -0.057306  0.128246  0.080373  ... -0.680203 -2.605509  0.246091
#
#         PAAQUEX    SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x
# SEQN
# 73568 -0.484200  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440
# 73576 -0.484200  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812
# 73579  2.065262 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812
# 73581 -0.484200  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440
# 73584  2.065262  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812
#
# [5 rows x 241 columns]

# %%
# apply PCA
# ----------
pca_all = PCA() # notice we do not specify the number of components if we want to keep them all
principalComponents_nhanes = pca_all.fit_transform(X)

# %% [markdown]
# ### Scree Plot(s) of Explained Variance

# %%
# create scree plot from PCA fit
# ----------
PC_values = np.arange(pca_all.n_components_) + 1
plt.plot(PC_values, pca_all.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot of All Principal Components')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %% [markdown]
# Obviously, this is far too many components. There is an elbow here somewhere between 0-50, so let's just plot the first 20 components to see if we can see where there is a reasonable trade off between number of components and amount of variation explained.

# %%
# Fit PCA model for less components 
pca = PCA(n_components=20)
pca.fit(X)
# Out:
# PCA(n_components=20)

# %%
# PC values are the principal component indices (1, 2, 3,...)
PC_values = np.arange(pca.n_components_) + 1

# Create scree plot
plt.figure(figsize=(10, 6))
plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')

# Title and labels
plt.title('Scree Plot (Explained Variance for First 20 Components)')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.xticks(PC_values)
plt.grid(True)

# %% [markdown]
# ### Barplot of Components

# %%
# Explained variance ratio for each component
explained_variance_ratio = pca.explained_variance_ratio_

# Create a bar plot to show the variance explained by each component
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=list(range(1, len(explained_variance_ratio) + 1)), 
                 y=explained_variance_ratio, 
                 palette='viridis')

# Add annotations for each bar with the value of explained variance
for i, v in enumerate(explained_variance_ratio):
    ax.text(i, v + 0.01, f'{v:.3f}', ha='center', va='bottom', fontsize=10)

# Title and labels
plt.title('Variance Explained by Each Principal Component (First 20)')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.xticks(ticks=range(len(explained_variance_ratio)), labels=[f'PC{i+1}' for i in range(len(explained_variance_ratio))])
plt.grid(True, axis='y')

# Show the plot
plt.show()
# Out:
# /var/folders/51/tvqz_23j083bt8bcsjfhnyk40000gn/T/ipykernel_32801/3564382604.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(range(1, len(explained_variance_ratio) + 1)),

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %% [markdown]
# Based on what we are seeing here and also in the scree plot, I am going to choose 5 components. Because our next step is to apply PCA for only 2 components, I will apply the PCA with 5 components after the following section, before the clustering.

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
# apply PCA
# ----------
pca2 = PCA(n_components=2)
pca2_result = pca2.fit_transform(X)

# %%
# convert into a dataframe and re-assign SQN as index
# ----------
pca2_df = pd.DataFrame(data=pca2_result, 
                       columns=['principal component 1', 'principal component 2'],
                       index=nhanes_scaled.index)

# Now pca2_df should have the SEQN (index) column
print(pca2_df.head())
# Out:
#        principal component 1  principal component 2
# SEQN
# 73568               9.527811              -0.816226
# 73576              -5.838339              -3.692578
# 73579              -0.719453              -2.573194
# 73581               3.533626              -2.576992
# 73584              -6.872094              -4.194234

# %%
#Now we have to do the same for our target 
SQNnhanestarget = nhanestarget.reset_index()

# %%
# Merge the PCA results with the target labels to align the data
merged_df = pca2_df.merge(SQNnhanestarget[['SEQN', 'HSD010','HSD010_binary']], on='SEQN', how='inner')

# Check the merged DataFrame
print(merged_df.head())
# Out:
#     SEQN  principal component 1  principal component 2     HSD010  \
# 0  73568               9.527811              -0.816226  excellent
# 1  73576              -5.838339              -3.692578  excellent
# 2  73579              -0.719453              -2.573194  very good
# 3  73581               3.533626              -2.576992  very good
# 4  73584              -6.872094              -4.194234       good
#
#   HSD010_binary
# 0          good
# 1          good
# 2          good
# 3          good
# 4          good

# %%
#Check the original dataframe to make sure that the SEQN aligns with the target 
print(nhanestarget.head())
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ845   PAAQUEX    SMQ860  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.646584 -0.484200  1.125008
# 73576 -0.057306  0.128246  0.080373  ... -1.539259 -0.484200  1.125008
# 73579 -0.057306  0.128246 -0.189513  ... -1.539259  2.065262 -0.888883
# 73581 -0.057306  0.128246  0.080373  ... -0.646584 -0.484200  1.125008
# 73584 -0.057306  0.128246  0.080373  ...  0.246091  2.065262  1.125008
#
#        SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x     HSD010  \
# SEQN
# 73568     0.0 -2.081666  1.087115  1.463404   0.612440  excellent
# 73576     0.0 -2.081666  1.087115 -0.683338  -1.632812  excellent
# 73579     0.0  0.480384 -0.919866 -0.683338  -1.632812  very good
# 73581     0.0  0.480384 -0.919866 -0.683338   0.612440  very good
# 73584     0.0  0.480384 -0.919866  1.463404  -1.632812       good
#
#        HSD010_binary
# SEQN
# 73568           good
# 73576           good
# 73579           good
# 73581           good
# 73584           good
#
# [5 rows x 243 columns]

# %%
# Update the targets list to include all categories in the HDS10
targets = ['excellent', 'very good', 'good', 'fair', 'poor']
colors = ['r', 'g', 'b', 'y', 'c']

# Plotting
plt.figure(figsize=(10, 10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component 1', fontsize=20)
plt.ylabel('Principal Component 2', fontsize=20)
plt.title("Principal Component Analysis of First 2 Components", fontsize=20)

# Loop over targets and colors to create scatterplot
for target, color in zip(targets, colors):
    # Use the merged DataFrame to filter for the target
    indicesToKeep = merged_df['HSD010'] == target
    print(f"Plotting {target}: {sum(indicesToKeep)} points") 
    if sum(indicesToKeep) > 0:
        # Plot the points for the current category (target)
        plt.scatter(merged_df.loc[indicesToKeep, 'principal component 1'],
                    merged_df.loc[indicesToKeep, 'principal component 2'], 
                    c=color, label=target, s=50)

# Add a legend
plt.legend(targets, prop={'size': 15})
plt.show()
# Out:
# Plotting excellent: 239 points
# Plotting very good: 672 points
# Plotting good: 821 points
# Plotting fair: 273 points
# Plotting poor: 59 points

# %% [markdown]
# Okay, that's a little messy, let's look at the binary version of the target.

# %%
#Update the targets list to include all categories in the HDS10_binary
targets = [ 'good', 'poor']
colors = ['r', 'g']

# Plotting
plt.figure(figsize=(10, 10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component 1', fontsize=20)
plt.ylabel('Principal Component 2', fontsize=20)
plt.title("Principal Component Analysis of First 2 Components", fontsize=20)

# Loop over targets and colors to create scatterplot
for target, color in zip(targets, colors):
    # Use the merged DataFrame to filter for the target
    indicesToKeep = merged_df['HSD010_binary'] == target
    print(f"Plotting {target}: {sum(indicesToKeep)} points")  
    if sum(indicesToKeep) > 0:
        # Plot the points for the current category (target)
        plt.scatter(merged_df.loc[indicesToKeep, 'principal component 1'],
                    merged_df.loc[indicesToKeep, 'principal component 2'], 
                    c=color, label=target, s=50)

# Add a legend
plt.legend(targets, prop={'size': 15})
plt.show()
# Out:
# Plotting good: 1732 points
# Plotting poor: 332 points

# %% [markdown]
# So, unlike the notebook we did in class, this mapping (though now better because the target's binarized), is not really telling us much. Obviously we are doing this as a requirement for the project, but otherwise, I would take this portion out and just stick with my 5 components (which I'm doing directly below).

# %% [markdown]
# ## PCA With Chosen Number of Components (5)

# %%
# apply PCA
# ----------
pca5 = PCA(n_components=5)
pca5_result = pca5.fit_transform(X)

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %%
## Your Answer Here

# %% [markdown]
# ### Cluster nhanes

# %%
# load libraries 
# ----------
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import cdist
from sklearn import metrics

# settings
# %matplotlib inline

# %%
#Scale the data for this section
scaler = StandardScaler()
kmeansscale= scaler.fit_transform(nhanes_scaled)
kmeansscale=pd.DataFrame(kmeansscale, columns=nhanes_scaled.columns)

# %%
# Initialize lists to store inertia values
inertias = []
mapping = {}
K = range(1, 10)

# Fit K-means for different values of k
for k in K:
    kmeanModel = KMeans(n_clusters=k, random_state=42).fit(kmeansscale)
    
    # Get intertia values
    inertias.append(kmeanModel.inertia_)
    
    # Store the mappings for easy access
    mapping[k] = inertias[-1]

print("Inertia values:")
for key, val in mapping.items():
    print(f'{key} : {val}')
# Plotting the graph of k versus Inertia
plt.plot(K, inertias, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('The Elbow Method using Inertia')
plt.grid()
plt.show()
# Out:
# Inertia values:
# 1 : 485040.00000000006
# 2 : 456520.72379338206
# 3 : 430162.74183996714
# 4 : 418161.79075436323
# 5 : 412132.7762390529
# 6 : 407214.9650603783
# 7 : 401453.54964757676
# 8 : 398272.3905769178
# 9 : 395300.421857825

# %% [markdown]
# We extracted and plotted the inertia values for different k (clusters) in order to choose the ideal number of clusters. Based on this graph, I am going to use three clusters, as that seems like the steepest part of the elbow to me. Even with the intertia values, my understanding is that this is sort of a subjective choice (i.e. there's no predetermined formula) but that the choice for number of clusters has to be defensible in a theoretical sense (though for the purposes of this project I don't necessarily have the domain-specific knowledge of theory to back up this decision of cluster selection).

# %%
# set random seed
np.random.seed(10)

# %%
# specify kmeans algorithm
# ----------
kmeans = KMeans(n_clusters=3,
                n_init=10,
                max_iter=300 #default
                ).fit(kmeansscale)

# %%
# print the centers 
print("Centers")
print(kmeans.cluster_centers_)
print()

# print labels
print("Labels")
print(kmeans.labels_)
print()

# print coordinates and labels 
for point, label in zip(kmeansscale, kmeans.labels_):
    print("Coordinates:", point, "Label:", label)
# Out:
# Centers
# [[ 0.00000000e+00  2.33561284e-02  0.00000000e+00 -4.36475400e-02
#   -6.65887976e-02  3.04507032e-02 -1.09315261e-02 -6.73676359e-03
#   -9.75807453e-03  3.02513164e-02 -1.82611931e-02  3.71378052e-02
#    1.11474575e-02 -2.21489357e-01 -4.42065668e-01 -3.71763418e-01
#   -3.62056245e-01 -2.66837227e-01 -2.66369061e-01 -4.22694506e-01
#   -4.23446950e-01 -3.99843137e-01 -3.12623409e-01 -2.93016777e-01
#   -2.46504594e-01 -3.16430421e-01 -2.58987080e-01 -8.57521076e-02
#   -9.62219566e-02 -3.40794168e-01 -3.52453205e-01 -3.07783183e-01
#   -2.52387650e-01 -2.92343811e-01 -1.84945437e-01 -2.75598201e-01
#   -2.65444165e-01 -3.44015770e-01 -2.69948893e-01 -1.11439915e-01
#   -2.16798415e-01 -1.37904982e-01 -3.52815849e-01 -4.12225364e-01
#   -3.51618092e-01 -3.30915481e-01 -3.42196523e-01 -3.14859504e-01
#   -3.77427250e-01 -3.85751954e-01 -3.48827391e-01 -2.15698802e-01
#   -2.92362232e-01 -3.02753556e-01 -3.01795152e-01 -3.24242437e-01
#   -2.09610655e-01 -3.44416220e-01 -4.19718694e-01 -4.13999309e-01
#    4.68873187e-01 -5.72039991e-01 -4.85977555e-01 -7.46174830e-02
#    1.02822783e-01 -2.13563019e-02 -3.11437330e-02 -2.76726355e-02
#    8.85326944e-03 -2.76098659e-01  1.01286942e-01  8.87929075e-01
#   -1.40713594e-02 -5.39949247e-02 -7.36812675e-02 -5.96022060e-01
#   -4.41929502e-02  4.43594664e-02  1.44879455e-01  5.23290536e-01
#    1.15384028e-01 -9.03304710e-01 -3.04885695e-01 -2.65611695e-01
#   -5.88259842e-01 -1.84178813e-01  1.87588922e-01  1.11054800e-01
#   -6.40196955e-01 -5.56465593e-01 -5.45474246e-01 -1.16088734e-01
#   -2.05771393e-02 -1.47659818e-01  4.48457667e-02 -7.84898302e-02
#   -5.43192989e-02  3.74763458e-02  4.39093862e-01  1.13884558e+00
#   -6.18601752e-01  7.16482630e-01 -4.84200125e-01  3.04980358e-01
#    0.00000000e+00 -2.86696515e-01  2.69900864e-01  3.57896298e-01
#    6.12440428e-01]]
#
# Labels
# [1 0 0 ... 0 1 0]
#
# Coordinates: DR1DRSTZ Label: 1
# Coordinates: DR1EXMER Label: 0
# Coordinates: DRABF Label: 0
# Coordinates: DRDINT Label: 1
# Coordinates: DR1DBIH Label: 0
# Coordinates: DR1DAY Label: 1
# Coordinates: DR1LANG Label: 0
# Coordinates: DR1MNRSP Label: 0
# Coordinates: DR1HELPD Label: 0
# Coordinates: DBQ095Z Label: 1
# Coordinates: DRQSPREP Label: 0
# Coordinates: DR1STY Label: 0
# Coordinates: DRQSDIET Label: 1
# Coordinates: DR1TNUMF Label: 0
# Coordinates: DR1TKCAL Label: 0
# Coordinates: DR1TPROT Label: 2
# Coordinates: DR1TCARB Label: 2
# Coordinates: DR1TSUGR Label: 0
# Coordinates: DR1TFIBE Label: 1
# Coordinates: DR1TTFAT Label: 1
# Coordinates: DR1TSFAT Label: 0
# Coordinates: DR1TMFAT Label: 0
# Coordinates: DR1TPFAT Label: 1
# Coordinates: DR1TCHOL Label: 0
# Coordinates: DR1TATOC Label: 0
# Coordinates: DR1TRET Label: 0
# Coordinates: DR1TVARA Label: 0
# Coordinates: DR1TBCAR Label: 1
# Coordinates: DR1TLZ Label: 1
# Coordinates: DR1TVB1 Label: 0
# Coordinates: DR1TVB2 Label: 2
# Coordinates: DR1TNIAC Label: 0
# Coordinates: DR1TVB6 Label: 1
# Coordinates: DR1TFOLA Label: 0
# Coordinates: DR1TFA Label: 0
# Coordinates: DR1TFF Label: 1
# Coordinates: DR1TFDFE Label: 0
# Coordinates: DR1TCHL Label: 0
# Coordinates: DR1TVB12 Label: 0
# Coordinates: DR1TVC Label: 0
# Coordinates: DR1TVD Label: 2
# Coordinates: DR1TVK Label: 0
# Coordinates: DR1TCALC Label: 1
# Coordinates: DR1TPHOS Label: 0
# Coordinates: DR1TMAGN Label: 0
# Coordinates: DR1TIRON Label: 1
# Coordinates: DR1TZINC Label: 0
# Coordinates: DR1TCOPP Label: 0
# Coordinates: DR1TSODI Label: 1
# Coordinates: DR1TPOTA Label: 0
# Coordinates: DR1TSELE Label: 0
# Coordinates: DR1TMOIS Label: 0
# Coordinates: DR1TS040 Label: 1
# Coordinates: DR1TS060 Label: 2
# Coordinates: DR1TS080 Label: 0
# Coordinates: DR1TS100 Label: 0
# Coordinates: DR1TS120 Label: 0
# Coordinates: DR1TS140 Label: 1
# Coordinates: DR1TS160 Label: 0
# Coordinates: DR1TS180 Label: 2
# Coordinates: DR1TM161 Label: 0
# Coordinates: DR1TM181 Label: 1
# Coordinates: DR1TM201 Label: 1
# Coordinates: DR1TP182 Label: 0
# Coordinates: DR1TP183 Label: 0
# Coordinates: DR1TP204 Label: 0
# Coordinates: DR1.300 Label: 1
# Coordinates: DR1TWS Label: 1
# Coordinates: DRD340 Label: 0
# Coordinates: DRD360 Label: 1
# Coordinates: PEASCST1 Label: 0
# Coordinates: PEASCTM1 Label: 1
# Coordinates: BPXPULS Label: 1
# Coordinates: BMDSTATS Label: 0
# Coordinates: BMXWT Label: 0
# Coordinates: BMXHT Label: 1
# Coordinates: BMXBMI Label: 0
# Coordinates: BMXARML Label: 0
# Coordinates: BMXARMC Label: 0
# Coordinates: BMXWAIST Label: 0
# Coordinates: MGDEXSTS Label: 1
# Coordinates: OHDEXSTS Label: 0
# Coordinates: OHDDESTS Label: 0
# Coordinates: OHX01TC Label: 1
# Coordinates: OHX02TC Label: 0
# Coordinates: OHX03TC Label: 0
# Coordinates: OHX04TC Label: 0
# Coordinates: OHX05TC Label: 0
# Coordinates: OHX06TC Label: 0
# Coordinates: OHX07TC Label: 1
# Coordinates: OHX08TC Label: 0
# Coordinates: OHX09TC Label: 1
# Coordinates: OHX10TC Label: 0
# Coordinates: OHX11TC Label: 1
# Coordinates: OHX12TC Label: 0
# Coordinates: OHX13TC Label: 1
# Coordinates: OHX14TC Label: 0
# Coordinates: OHX15TC Label: 0
# Coordinates: OHX16TC Label: 2
# Coordinates: OHX17TC Label: 1
# Coordinates: OHX18TC Label: 0
# Coordinates: OHX19TC Label: 0
# Coordinates: OHX20TC Label: 2
# Coordinates: OHX21TC Label: 1
# Coordinates: OHX22TC Label: 1
# Coordinates: OHX23TC Label: 0
# Coordinates: OHX24TC Label: 0
# Coordinates: OHX25TC Label: 0
# Coordinates: OHX26TC Label: 0
# Coordinates: OHX27TC Label: 0
# Coordinates: OHX28TC Label: 0
# Coordinates: OHX29TC Label: 1
# Coordinates: OHX30TC Label: 0
# Coordinates: OHX31TC Label: 0
# Coordinates: OHX32TC Label: 1
# Coordinates: URXUMA Label: 0
# Coordinates: URXUMS Label: 0
# Coordinates: URXUCR.x Label: 0
# Coordinates: URXCRS Label: 1
# Coordinates: URDACT Label: 0
# Coordinates: LBXWBCSI Label: 0
# Coordinates: LBXLYPCT Label: 1
# Coordinates: LBXMOPCT Label: 0
# Coordinates: LBXNEPCT Label: 0
# Coordinates: LBXEOPCT Label: 1
# Coordinates: LBXBAPCT Label: 0
# Coordinates: LBDLYMNO Label: 0
# Coordinates: LBDMONO Label: 0
# Coordinates: LBDNENO Label: 0
# Coordinates: LBXRBCSI Label: 0
# Coordinates: LBXHGB Label: 1
# Coordinates: LBXHCT Label: 0
# Coordinates: LBXMCVSI Label: 0
# Coordinates: LBXMCHSI Label: 0
# Coordinates: LBXMC Label: 0
# Coordinates: LBXRDW Label: 0
# Coordinates: LBXPLTSI Label: 1
# Coordinates: LBXMPSI Label: 1
# Coordinates: PHQ020 Label: 0
# Coordinates: PHQ030 Label: 0
# Coordinates: PHQ040 Label: 1
# Coordinates: PHQ050 Label: 1
# Coordinates: PHQ060 Label: 1
# Coordinates: PHAFSTMN.x Label: 0
# Coordinates: LBXHA Label: 0
# Coordinates: LBXHBS Label: 1
# Coordinates: URXVOL1 Label: 0
# Coordinates: SDDSRVYR Label: 0
# Coordinates: RIDSTATR Label: 0
# Coordinates: RIAGENDR Label: 1
# Coordinates: RIDAGEYR Label: 0
# Coordinates: RIDRETH1 Label: 0
# Coordinates: RIDRETH3 Label: 0
# Coordinates: RIDEXMON Label: 0
# Coordinates: DMDBORN4 Label: 0
# Coordinates: DMDCITZN Label: 1
# Coordinates: SIALANG Label: 1
# Coordinates: SIAPROXY Label: 0
# Coordinates: SIAINTRP Label: 0
# Coordinates: FIALANG Label: 0
# Coordinates: FIAPROXY Label: 1
# Coordinates: FIAINTRP Label: 1
# Coordinates: DMDHHSIZ Label: 0
# Coordinates: DMDFMSIZ Label: 1
# Coordinates: DMDHRGND Label: 0
# Coordinates: DMDHRAGE Label: 2
# Coordinates: DMDHRBR4 Label: 0
# Coordinates: DMDHREDU Label: 0
# Coordinates: DMDHRMAR Label: 1
# Coordinates: WTINT2YR Label: 0
# Coordinates: WTMEC2YR Label: 0
# Coordinates: SDMVPSU Label: 0
# Coordinates: SDMVSTRA Label: 0
# Coordinates: INDHHIN2 Label: 1
# Coordinates: INDFMIN2 Label: 0
# Coordinates: INDFMPIR Label: 0
# Coordinates: CBD070 Label: 0
# Coordinates: HSQ500 Label: 1
# Coordinates: HSQ510 Label: 1
# Coordinates: HSQ520 Label: 0
# Coordinates: HSAQUEX Label: 0
# Coordinates: DIQ010 Label: 0
# Coordinates: DIQ050 Label: 0
# Coordinates: DLQ010 Label: 1
# Coordinates: DLQ020 Label: 0
# Coordinates: DLQ040 Label: 1
# Coordinates: DLQ050 Label: 1
# Coordinates: DLQ060 Label: 0
# Coordinates: FSD032A Label: 0
# Coordinates: FSD032B Label: 0
# Coordinates: FSD032C Label: 0
# Coordinates: FSDHH Label: 1
# Coordinates: FSDAD Label: 0
# Coordinates: FSD151 Label: 2
# Coordinates: FSQ165 Label: 0
# Coordinates: FSQ162 Label: 0
# Coordinates: HEQ010 Label: 2
# Coordinates: HEQ030 Label: 0
# Coordinates: HIQ011 Label: 0
# Coordinates: HIQ270 Label: 1
# Coordinates: HIQ210 Label: 2
# Coordinates: HOD050 Label: 0
# Coordinates: HOQ065 Label: 0
# Coordinates: HUQ010 Label: 0
# Coordinates: HUQ020 Label: 0
# Coordinates: HUQ030 Label: 1
# Coordinates: HUQ041 Label: 1
# Coordinates: HUQ071 Label: 0
# Coordinates: HUQ090 Label: 1
# Coordinates: IMQ011 Label: 0
# Coordinates: IMQ020 Label: 0
# Coordinates: INQ020 Label: 0
# Coordinates: INQ012 Label: 0
# Coordinates: INQ030 Label: 0
# Coordinates: INQ060 Label: 0
# Coordinates: INQ080 Label: 0
# Coordinates: INQ090 Label: 1
# Coordinates: INQ132 Label: 1
# Coordinates: INQ140 Label: 0
# Coordinates: INQ150 Label: 0
# Coordinates: IND235 Label: 0
# Coordinates: INDFMMPI Label: 0
# Coordinates: INDFMMPC Label: 1
# Coordinates: MCQ010 Label: 0
# Coordinates: MCQ053 Label: 0
# Coordinates: MCQ082 Label: 2
# Coordinates: MCQ086 Label: 0
# Coordinates: MCQ092 Label: 1
# Coordinates: MCQ203 Label: 1
# Coordinates: MCQ300B Label: 0
# Coordinates: OHQ030 Label: 0
# Coordinates: OHQ033 Label: 0
# Coordinates: OHQ770 Label: 0
# Coordinates: OHQ845 Label: 0
# Coordinates: PAAQUEX Label: 0
# Coordinates: SMQ860 Label: 0
# Coordinates: SMQ870 Label: 0
# Coordinates: SMQ872 Label: 0
# Coordinates: SMQ874 Label: 1
# Coordinates: SMQ878 Label: 0
# Coordinates: SMAQUEX.x Label: 0

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
# Store the cluster labels
kmeans_labels = kmeans.labels_

# Recreate the scatter plot with BMI vs Income-to-Poverty Ratio
ax = sns.scatterplot(x="INDFMPIR", y="BMXBMI", 
                     hue=kmeans_labels, 
                     palette="tab10", 
                     data=kmeansscale, 
                     legend="full",
                    alpha=0.7)

# Plot the cluster centers on top of the scatter plot
centers = kmeans.cluster_centers_

# Plotting each cluster center (use a larger size and '+' marker)
ax.scatter(centers[:, 0], centers[:, 1], s=50,  marker='+', c='black', label='cluster centers')

# Set the axis labels and plot title
ax.set(xlabel="Income to Poverty Line Ratio", ylabel="Body Mass Index")
ax.set_title("BMI vs. Income-Poverty Ratio with K-means Clusters")

# Show the plot with the legend
plt.legend()
plt.show()

# %% [markdown]
# So, from what I am seeing here, because the clusters look so messy in this feature space (the cluster centers are close to one another and the clusters are disorganized), it is telling me that 'BMI' and "Income to Poverty Line Ratio' are not necessarily the most significant features that organize our clusters.

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
# set random seed
np.random.seed(10)

# %%
# specify kmeans algorithm
# ----------
kmeanspca = KMeans(n_clusters=3,
                n_init=10,
                max_iter=300 #default
                ).fit(pca5_result)

# %%
# print the centers 
print("Centers")
print(kmeanspca.cluster_centers_)
print()

# print labels
print("Labels")
print(kmeanspca.labels_)
print()

# print coordinates and labels 
for point, label in zip (pca5_result, kmeanspca.labels_):
    print("Coordinates:", point, "Label:", label)
# Out:
# Centers
# [[ 6.0077555   0.28984704  0.14525535  0.12441736 -0.22351159]
#  [-1.94116294 -1.56740341  0.12330032  0.18850956  0.09690713]
#  [-4.13700856 11.44304153 -1.44487075 -1.89248416 -0.04112582]]
#
# Labels
# [0 1 1 ... 1 0 1]
# Coordinates: [-4.11952229 -0.82807602  2.09727197  0.73357544  0.55699024] Label: 1
# Coordinates: [7.81242921 2.20247086 4.3092096  3.40338498 1.98482052] Label: 0
# Coordinates: [ 3.40906477  0.31763568 -2.79809333 -0.35419686 -1.51298349] Label: 0
# Coordinates: [ 3.62609016  0.90831668  6.61979238  0.26996917 -0.30596541] Label: 0
# Coordinates: [ 4.35463934 -2.20205782 -2.91714506 -2.07604003  2.63766275] Label: 0
# Coordinates: [ 3.72808158 -1.9631968  -3.86704254  2.52322477 -0.37712004] Label: 0
# Coordinates: [ 1.43348099  1.35045986  5.87663922  1.58533975 -0.39842412] Label: 1
# Coordinates: [ 0.34739819 -1.78198831  2.7101587  -1.69872243  3.1736726 ] Label: 1
# Coordinates: [-1.91342883 -4.49835969 -0.5247097  -4.07769101 -0.57548558] Label: 1
# Coordinates: [13.58881937  2.79716446  7.95787464 -1.23931262 -1.88646019] Label: 0
# Coordinates: [ 1.00722119 -2.28337843  3.427364   -1.08465344 -0.45828685] Label: 1
# Coordinates: [ 6.72480171  0.02832699  7.5157686  -4.70180235 -9.39266365] Label: 0
# Coordinates: [-4.31991144 -3.48502698  0.36113627 -0.57145236 -0.76538364] Label: 1
# Coordinates: [ 2.64331877 -1.68935726 -0.70263017 -0.53848252 -1.01928501] Label: 0
# Coordinates: [ 1.03790591 -0.11806433  5.55639078  1.62968236  0.97753326] Label: 1
# Coordinates: [ 1.13025336 -0.97043332  3.41537038  1.20664534 -3.6313875 ] Label: 1
# Coordinates: [ 7.14509291 -0.37675024  1.75353938 -0.93970088 -4.67447578] Label: 0
# Coordinates: [ 0.05086915 -0.96729727 -4.44766562 -0.50251528  4.46943809] Label: 1

# %%
# Store the cluster labels
pcalabels = kmeanspca.labels_
pcacenters = kmeanspca.cluster_centers_

# Add pcalabels to the merged_df DataFrame for hue mapping
merged_df['pcalabels'] = pcalabels

# figure settings
plt.figure(figsize=(10, 10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1', fontsize=20)
plt.ylabel('Principal Component - 2', fontsize=20)
plt.title("PCA Clusters Mapped onto First Two Principal Components", fontsize=20)

# Plot the scatterplot with K-means clusters as hue
sns.scatterplot(data=merged_df, 
                x='principal component 1', 
                y='principal component 2', 
                hue='pcalabels',  # Using the labels from the merged_df
                palette='Set2',  # Color palette
                s=100,  # Size of the points
                edgecolor='black',  # Black edges for better visibility
                alpha=0.7)  # Slight transparency

# Plot the cluster centers 
plt.scatter(pcacenters[:, 0], pcacenters[:, 1], s=100, c='black', marker='+', label='Cluster Centers')

# Show the legend
plt.legend(title="Clusters", prop={'size': 15})

# Show the plot
plt.show()

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
# !pip install tensorflow
# !pip install keras
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# Sklearn libraries
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix

# Keras libraries
from tensorflow import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import RMSprop
# Out:
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.0)
# Requirement already satisfied: keras in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (3.7.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.3.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)

# %%
# Convert HSD010_binary back to numeric, mapping 'good' to 0 and 'poor' to 1
NNnhanes_target=nhanestarget
NNnhanes_target['HSD010_binary'] = NNnhanes_target['HSD010_binary'].map({'good': 0, 'poor': 1})
X=NNnhanes_target.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %%
NNnhanes_target.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ845   PAAQUEX    SMQ860  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.646584 -0.484200  1.125008
# 73576 -0.057306  0.128246  0.080373  ... -1.539259 -0.484200  1.125008
# 73579 -0.057306  0.128246 -0.189513  ... -1.539259  2.065262 -0.888883
# 73581 -0.057306  0.128246  0.080373  ... -0.646584 -0.484200  1.125008
# 73584 -0.057306  0.128246  0.080373  ...  0.246091  2.065262  1.125008
#
#        SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x     HSD010  \
# SEQN
# 73568     0.0 -2.081666  1.087115  1.463404   0.612440  excellent
# 73576     0.0 -2.081666  1.087115 -0.683338  -1.632812  excellent
# 73579     0.0  0.480384 -0.919866 -0.683338  -1.632812  very good
# 73581     0.0  0.480384 -0.919866 -0.683338   0.612440  very good
# 73584     0.0  0.480384 -0.919866  1.463404  -1.632812       good
#
#        HSD010_binary
# SEQN
# 73568              0
# 73576              0
# 73579              0
# 73581              0
# 73584              0
#
# [5 rows x 243 columns]

# %%
# partition data
# -----------
y = NNnhanes_target['HSD010_binary'] # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X = X # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 2
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)
num_classes = y_test.shape[1]

# %%
print(y_train[0])
# Out:
# [1. 0.]

# %%
# create neural network model
# -----------
model = Sequential()

num_pixels = X_train.shape[1] 

#input layer
model.add(Dense(num_pixels, input_dim= num_pixels, kernel_initializer= 'normal', activation= 'relu'))

#output layer
model.add(Dense(num_classes, kernel_initializer= 'normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss= 'categorical_crossentropy', optimizer= 'adam', metrics=['accuracy'])

#fit model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Out:
# Epoch 1/10
# /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 - 1s - 156ms/step - accuracy: 0.7267 - loss: 0.5380 - val_accuracy: 0.8411 - val_loss: 0.3896
# Epoch 2/10
# 8/8 - 0s - 15ms/step - accuracy: 0.8637 - loss: 0.3442 - val_accuracy: 0.8527 - val_loss: 0.3588
# Epoch 3/10
# 8/8 - 0s - 15ms/step - accuracy: 0.8727 - loss: 0.3097 - val_accuracy: 0.8566 - val_loss: 0.3507
# Epoch 4/10
# 8/8 - 0s - 16ms/step - accuracy: 0.8863 - loss: 0.2748 - val_accuracy: 0.8547 - val_loss: 0.3489
# Epoch 5/10
# 8/8 - 0s - 15ms/step - accuracy: 0.9050 - loss: 0.2427 - val_accuracy: 0.8624 - val_loss: 0.3377
# Epoch 6/10
# 8/8 - 0s - 15ms/step - accuracy: 0.9141 - loss: 0.2219 - val_accuracy: 0.8585 - val_loss: 0.3351
# Epoch 7/10
# 8/8 - 0s - 15ms/step - accuracy: 0.9231 - loss: 0.2006 - val_accuracy: 0.8585 - val_loss: 0.3400
# Epoch 8/10
# 8/8 - 0s - 15ms/step - accuracy: 0.9348 - loss: 0.1799 - val_accuracy: 0.8585 - val_loss: 0.3390
# Epoch 9/10
# 8/8 - 0s - 19ms/step - accuracy: 0.9425 - loss: 0.1625 - val_accuracy: 0.8643 - val_loss: 0.3459
# Epoch 10/10
# 8/8 - 0s - 15ms/step - accuracy: 0.9509 - loss: 0.1447 - val_accuracy: 0.8624 - val_loss: 0.3502

# %% [markdown]
# ### Neural Network on Principal Components

# %%
# Convert the PCA result to a DataFrame 
pca5_df = pd.DataFrame(data = pca5_result, 
                      columns = ['principal component 1', 
                                 'principal component 2',
                                'principal component 3',
                                'principal component 4',
                                'principal component 5'])

# %%
# partition data
# -----------
y = NNnhanes_target['HSD010_binary'] 
X = pca5_df # using our 5 component PCA as the features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 2
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)
num_classes = y_test.shape[1]

# %%
# create neural network model
# -----------
model = Sequential()

num_pixels = X_train.shape[1] 

#input layer
model.add(Dense(num_pixels, input_dim= num_pixels, kernel_initializer= 'normal', activation= 'relu'))

#output layer
model.add(Dense(num_classes, kernel_initializer= 'normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss= 'categorical_crossentropy', optimizer= 'adam', metrics=['accuracy'])

#fit model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Out:
# Epoch 1/10
# /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 - 1s - 133ms/step - accuracy: 0.8191 - loss: 0.6856 - val_accuracy: 0.8488 - val_loss: 0.6792
# Epoch 2/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8366 - loss: 0.6766 - val_accuracy: 0.8488 - val_loss: 0.6691
# Epoch 3/10
# 8/8 - 0s - 18ms/step - accuracy: 0.8359 - loss: 0.6664 - val_accuracy: 0.8488 - val_loss: 0.6581
# Epoch 4/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6551 - val_accuracy: 0.8488 - val_loss: 0.6460
# Epoch 5/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6423 - val_accuracy: 0.8488 - val_loss: 0.6326
# Epoch 6/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6280 - val_accuracy: 0.8488 - val_loss: 0.6176
# Epoch 7/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6121 - val_accuracy: 0.8527 - val_loss: 0.6014
# Epoch 8/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8404 - loss: 0.5948 - val_accuracy: 0.8527 - val_loss: 0.5842
# Epoch 9/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8411 - loss: 0.5769 - val_accuracy: 0.8508 - val_loss: 0.5665
# Epoch 10/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8443 - loss: 0.5584 - val_accuracy: 0.8508 - val_loss: 0.5484

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
# Add cluster labels to the PCA DataFrame (as an additional feature)
pca5_df['cluster_label'] = pcalabels
print(pca5_df.head())
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               9.527811              -0.816224              -1.867064
# 1              -5.838339              -3.692575               3.805753
# 2              -0.719454              -2.573200               0.907906
# 3               3.533627              -2.576985              -3.249155
# 4              -6.872094              -4.194240               0.886828
#
#    principal component 4  principal component 5  cluster_label
# 0              -2.110332              -3.931393              0
# 1              -1.029508               0.398023              1
# 2              -4.755886              -1.796390              1
# 3              -0.404766               4.000688              0
# 4              -0.849231              -0.523278              1

# %%
# partition data
# -----------
y = NNnhanes_target['HSD010_binary'] 
X = pca5_df # using our 5 component PCA and cluster membership as the features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 2
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)
num_classes = y_test.shape[1]

# %%
# create neural network model
# -----------
model = Sequential()

num_pixels = X_train.shape[1] 

#input layer
model.add(Dense(num_pixels, input_dim= num_pixels, kernel_initializer= 'normal', activation= 'relu'))

#output layer
model.add(Dense(num_classes, kernel_initializer= 'normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss= 'categorical_crossentropy', optimizer= 'adam', metrics=['accuracy'])

#fit model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Out:
# Epoch 1/10
# /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 - 1s - 135ms/step - accuracy: 0.5652 - loss: 0.6933 - val_accuracy: 0.7674 - val_loss: 0.6882
# Epoch 2/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8224 - loss: 0.6835 - val_accuracy: 0.8411 - val_loss: 0.6782
# Epoch 3/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8424 - loss: 0.6741 - val_accuracy: 0.8488 - val_loss: 0.6682
# Epoch 4/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8366 - loss: 0.6642 - val_accuracy: 0.8488 - val_loss: 0.6574
# Epoch 5/10
# 8/8 - 0s - 15ms/step - accuracy: 0.8359 - loss: 0.6535 - val_accuracy: 0.8488 - val_loss: 0.6454
# Epoch 6/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6411 - val_accuracy: 0.8488 - val_loss: 0.6318
# Epoch 7/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6270 - val_accuracy: 0.8488 - val_loss: 0.6166
# Epoch 8/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6110 - val_accuracy: 0.8488 - val_loss: 0.5996
# Epoch 9/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.5933 - val_accuracy: 0.8488 - val_loss: 0.5810
# Epoch 10/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.5738 - val_accuracy: 0.8488 - val_loss: 0.5609

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"
