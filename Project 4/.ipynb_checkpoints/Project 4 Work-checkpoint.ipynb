# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# **Enter your Name:**Taylor Galdi
#
# *Semester:* Fall 2024

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %pip install keras
# %pip install tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: keras in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (3.7.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.3.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# 2024-12-10 18:09:45.740667: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanestarget = nhanes_scaled

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)
print(nhanes_scaled.head())
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ033    OHQ770    OHQ845  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -0.646584
# 73576 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -1.539259
# 73579 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -1.539259
# 73581 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -0.646584
# 73584 -0.057306  0.128246  0.080373  ... -0.680203 -2.605509  0.246091
#
#         PAAQUEX    SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x
# SEQN
# 73568 -0.484200  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440
# 73576 -0.484200  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812
# 73579  2.065262 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812
# 73581 -0.484200  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440
# 73584  2.065262  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812
#
# [5 rows x 241 columns]

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %%
# scale data (without scaling the index)
# ----------
scaler = StandardScaler()
X = scaler.fit_transform(nhanes_scaled)

# Convert the scaled data back into a DataFrame with the original column names and index
X = pd.DataFrame(X, columns=nhanes_scaled.columns, index=nhanes_scaled.index)

# Verify the result
print(X.head())
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ033    OHQ770    OHQ845  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -0.646584
# 73576 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -1.539259
# 73579 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -1.539259
# 73581 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -0.646584
# 73584 -0.057306  0.128246  0.080373  ... -0.680203 -2.605509  0.246091
#
#         PAAQUEX    SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x
# SEQN
# 73568 -0.484200  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440
# 73576 -0.484200  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812
# 73579  2.065262 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812
# 73581 -0.484200  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440
# 73584  2.065262  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812
#
# [5 rows x 241 columns]

# %%
# apply PCA
# ----------
pca_all = PCA() # notice we do not specify the number of components if we want to keep them all
principalComponents_nhanes = pca_all.fit_transform(X)

# %% [markdown]
# ### Scree Plot(s) of Explained Variance

# %%
# create scree plot from PCA fit
# ----------
PC_values = np.arange(pca_all.n_components_) + 1
plt.plot(PC_values, pca_all.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot of All Principal Components')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %% [markdown]
# Obviously, this is far too many components. There is an elbow here somewhere between 0-50, so let's just plot the first 20 components to see if we can see where there is a reasonable trade off between number of components and amount of variation explained.

# %%
# Fit PCA model for less components 
pca = PCA(n_components=20)
pca.fit(X)
# Out:
# PCA(n_components=20)

# %%
# PC values are the principal component indices (1, 2, 3,...)
PC_values = np.arange(pca.n_components_) + 1

# Create scree plot
plt.figure(figsize=(10, 6))
plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')

# Title and labels
plt.title('Scree Plot (Explained Variance for First 20 Components)')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.xticks(PC_values)
plt.grid(True)

# %% [markdown]
# ### Barplot of Components

# %%
# Explained variance ratio for each component
explained_variance_ratio = pca.explained_variance_ratio_

# Create a bar plot to show the variance explained by each component
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=list(range(1, len(explained_variance_ratio) + 1)), 
                 y=explained_variance_ratio, 
                 palette='viridis')

# Add annotations for each bar with the value of explained variance
for i, v in enumerate(explained_variance_ratio):
    ax.text(i, v + 0.01, f'{v:.3f}', ha='center', va='bottom', fontsize=10)

# Title and labels
plt.title('Variance Explained by Each Principal Component (First 20)')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.xticks(ticks=range(len(explained_variance_ratio)), labels=[f'PC{i+1}' for i in range(len(explained_variance_ratio))])
plt.grid(True, axis='y')

# Show the plot
plt.show()
# Out:
# /var/folders/51/tvqz_23j083bt8bcsjfhnyk40000gn/T/ipykernel_83491/3564382604.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=list(range(1, len(explained_variance_ratio) + 1)),

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %% [markdown]
# Based on what we are seeing here and also in the scree plot, I am going to choose 5 components. Because our next step is to apply PCA for only 2 components, I will apply the PCA with 5 components after the following section, before the clustering.

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
# apply PCA
# ----------
pca2 = PCA(n_components=2)
pca2_result = pca2.fit_transform(X)

# %%
# convert into a dataframe and re-assign SQN as index
# ----------
pca2_df = pd.DataFrame(data=pca2_result, 
                       columns=['principal component 1', 'principal component 2'],
                       index=nhanes_scaled.index)

# Now pca2_df should have the SEQN (index) column
print(pca2_df.head())
# Out:
#        principal component 1  principal component 2
# SEQN
# 73568               9.527811              -0.816225
# 73576              -5.838340              -3.692574
# 73579              -0.719454              -2.573200
# 73581               3.533626              -2.576984
# 73584              -6.872093              -4.194240

# %%
#Now we have to do the same for our target 
SQNnhanestarget = nhanestarget.reset_index()

# %%
# Merge the PCA results with the target labels to align the data
merged_df = pca2_df.merge(SQNnhanestarget[['SEQN', 'HSD010','HSD010_binary']], on='SEQN', how='inner')

# Check the merged DataFrame
print(merged_df.head())
# Out:
#     SEQN  principal component 1  principal component 2     HSD010  \
# 0  73568               9.527811              -0.816225  excellent
# 1  73576              -5.838340              -3.692574  excellent
# 2  73579              -0.719454              -2.573200  very good
# 3  73581               3.533626              -2.576984  very good
# 4  73584              -6.872093              -4.194240       good
#
#   HSD010_binary
# 0          good
# 1          good
# 2          good
# 3          good
# 4          good

# %%
#Check the original dataframe to make sure that the SEQN aligns with the target 
print(nhanestarget.head())
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ845   PAAQUEX    SMQ860  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.646584 -0.484200  1.125008
# 73576 -0.057306  0.128246  0.080373  ... -1.539259 -0.484200  1.125008
# 73579 -0.057306  0.128246 -0.189513  ... -1.539259  2.065262 -0.888883
# 73581 -0.057306  0.128246  0.080373  ... -0.646584 -0.484200  1.125008
# 73584 -0.057306  0.128246  0.080373  ...  0.246091  2.065262  1.125008
#
#        SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x     HSD010  \
# SEQN
# 73568     0.0 -2.081666  1.087115  1.463404   0.612440  excellent
# 73576     0.0 -2.081666  1.087115 -0.683338  -1.632812  excellent
# 73579     0.0  0.480384 -0.919866 -0.683338  -1.632812  very good
# 73581     0.0  0.480384 -0.919866 -0.683338   0.612440  very good
# 73584     0.0  0.480384 -0.919866  1.463404  -1.632812       good
#
#        HSD010_binary
# SEQN
# 73568           good
# 73576           good
# 73579           good
# 73581           good
# 73584           good
#
# [5 rows x 243 columns]

# %%
# Update the targets list to include all categories in the HDS10
targets = ['excellent', 'very good', 'good', 'fair', 'poor']
colors = ['r', 'g', 'b', 'y', 'c']

# Plotting
plt.figure(figsize=(10, 10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component 1', fontsize=20)
plt.ylabel('Principal Component 2', fontsize=20)
plt.title("Principal Component Analysis of First 2 Components", fontsize=20)

# Loop over targets and colors to create scatterplot
for target, color in zip(targets, colors):
    # Use the merged DataFrame to filter for the target
    indicesToKeep = merged_df['HSD010'] == target
    print(f"Plotting {target}: {sum(indicesToKeep)} points") 
    if sum(indicesToKeep) > 0:
        # Plot the points for the current category (target)
        plt.scatter(merged_df.loc[indicesToKeep, 'principal component 1'],
                    merged_df.loc[indicesToKeep, 'principal component 2'], 
                    c=color, label=target, s=50)

# Add a legend
plt.legend(targets, prop={'size': 15})
plt.show()
# Out:
# Plotting excellent: 239 points
# Plotting very good: 672 points
# Plotting good: 821 points
# Plotting fair: 273 points
# Plotting poor: 59 points

# %% [markdown]
# Okay, that's a little messy, let's look at the binary version of the target.

# %%
#Update the targets list to include all categories in the HDS10_binary
targets = [ 'good', 'poor']
colors = ['r', 'g']

# Plotting
plt.figure(figsize=(10, 10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component 1', fontsize=20)
plt.ylabel('Principal Component 2', fontsize=20)
plt.title("Principal Component Analysis of First 2 Components", fontsize=20)

# Loop over targets and colors to create scatterplot
for target, color in zip(targets, colors):
    # Use the merged DataFrame to filter for the target
    indicesToKeep = merged_df['HSD010_binary'] == target
    print(f"Plotting {target}: {sum(indicesToKeep)} points")  
    if sum(indicesToKeep) > 0:
        # Plot the points for the current category (target)
        plt.scatter(merged_df.loc[indicesToKeep, 'principal component 1'],
                    merged_df.loc[indicesToKeep, 'principal component 2'], 
                    c=color, label=target, s=50)

# Add a legend
plt.legend(targets, prop={'size': 15})
plt.show()
# Out:
# Plotting good: 1732 points
# Plotting poor: 332 points

# %% [markdown]
# ## PCA With Chosen Number of Components (5)

# %%
# apply PCA
# ----------
pca5 = PCA(n_components=5)
pca5_result = pca5.fit_transform(X)

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %%
## Your Answer Here

# %% [markdown]
# ### Cluster nhanes

# %%
# load libraries 
# ----------
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import cdist
from sklearn import metrics

# settings
# %matplotlib inline

# %%
#Scale the data for this section
scaler = StandardScaler()
kmeansscale= scaler.fit_transform(nhanes_scaled)
kmeansscale=pd.DataFrame(kmeansscale, columns=nhanes_scaled.columns)

# %%
# Initialize lists to store inertia values
inertias = []
mapping = {}
K = range(1, 10)

# Fit K-means for different values of k
for k in K:
    kmeanModel = KMeans(n_clusters=k, random_state=42).fit(kmeansscale)
    
    # Get intertia values
    inertias.append(kmeanModel.inertia_)
    
    # Store the mappings for easy access
    mapping[k] = inertias[-1]

print("Inertia values:")
for key, val in mapping.items():
    print(f'{key} : {val}')
# Plotting the graph of k versus Inertia
plt.plot(K, inertias, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('The Elbow Method using Inertia')
plt.grid()
plt.show()
# Out:
# Inertia values:
# 1 : 485040.0
# 2 : 456520.723793382
# 3 : 430162.7418399672
# 4 : 418161.7907543633
# 5 : 412132.7762390529
# 6 : 407214.9650603783
# 7 : 401453.54964757676
# 8 : 398272.39057691785
# 9 : 395300.421857825

# %% [markdown]
# Based on this, I am going to use three clusters, as that seems like the steepest part of the elbow to me. Even with the intertia values, my understanding is that this is sort of a subjective choice (i.e. there's no predetermined formula) but that the choice for number of clusters has to be defensible in a theoretical sense (though for the purposes of this project I don't necessarily have the domain-specific knowledge of theory to back up this decision of cluster selection).

# %%
# set random seed
np.random.seed(10)

# %%
# specify kmeans algorithm
# ----------
kmeans = KMeans(n_clusters=3,
                n_init=10,
                max_iter=300 #default
                ).fit(kmeansscale)

# %%
# print the centers 
print("Centers")
print(kmeans.cluster_centers_)
print()

# print labels
print("Labels")
print(kmeans.labels_)
print()

# print coordinates and labels 
for point, label in zip(kmeansscale, kmeans.labels_):
    print("Coordinates:", point, "Label:", label)
# Out:
# Centers
# [[ 0.00000000e+00  2.33561284e-02  0.00000000e+00 -4.36475400e-02
#   -6.65887976e-02  3.04507032e-02 -1.09315261e-02 -6.73676359e-03
#   -9.75807453e-03  3.02513164e-02 -1.82611931e-02  3.71378052e-02
#    1.11474575e-02 -2.21489357e-01 -4.42065668e-01 -3.71763418e-01
#   -3.62056245e-01 -2.66837227e-01 -2.66369061e-01 -4.22694506e-01
#   -4.23446950e-01 -3.99843137e-01 -3.12623409e-01 -2.93016777e-01
#   -2.46504594e-01 -3.16430421e-01 -2.58987080e-01 -8.57521076e-02
#   -9.62219566e-02 -3.40794168e-01 -3.52453205e-01 -3.07783183e-01
#   -2.52387650e-01 -2.92343811e-01 -1.84945437e-01 -2.75598201e-01
#   -2.65444165e-01 -3.44015770e-01 -2.69948893e-01 -1.11439915e-01
#   -2.16798415e-01 -1.37904982e-01 -3.52815849e-01 -4.12225364e-01
#   -3.51618092e-01 -3.30915481e-01 -3.42196523e-01 -3.14859504e-01
#   -3.77427250e-01 -3.85751954e-01 -3.48827391e-01 -2.15698802e-01
#   -2.92362232e-01 -3.02753556e-01 -3.01795152e-01 -3.24242437e-01
#   -2.09610655e-01 -3.44416220e-01 -4.19718694e-01 -4.13999309e-01
#   -3.26388749e-01 -3.88341971e-01 -2.75477738e-01 -3.05537224e-01
#   -2.81221345e-01 -2.52836687e-01  5.78547275e-02  6.09593639e-02
#    1.07794412e-02  4.76834892e-02 -2.20166068e-02 -5.07645207e-02
#   -7.94019564e-03  2.06458006e-02 -9.91661077e-02 -1.80821850e-01
#   -3.26641542e-02 -1.52092071e-01 -7.77020078e-02 -7.88290951e-02
#   -2.53705381e-02 -2.57965314e-02  1.02182624e-03 -2.86239428e-02
#   -1.39780245e-01 -1.60812381e-01 -1.80614859e-01 -1.80627173e-01
#   -2.15890777e-01 -2.40265827e-01 -2.42853983e-01 -2.52175924e-01
#   -2.52152861e-01 -2.27460006e-01 -1.70782005e-01 -1.83465055e-01
#   -1.60539600e-01 -1.44180774e-01 -1.48707502e-02 -1.43640784e-02
#   -1.53427343e-01 -1.53386787e-01 -1.69502952e-01 -1.35021314e-01
#   -1.98485227e-01 -2.13383755e-01 -2.06994227e-01 -2.03349098e-01
#   -2.18837179e-01 -2.05192775e-01 -1.54136688e-01 -1.95824896e-01
#   -1.41340392e-01 -1.46902326e-01 -1.37335450e-02 -3.44112007e-02
#   -3.44112007e-02 -1.85919068e-02 -1.85919068e-02 -2.84642873e-02
#   -1.86598505e-02  6.40521563e-02 -2.10461396e-02 -4.65622356e-02
#   -1.90394242e-02 -3.70812118e-02  3.23203953e-02 -3.42696083e-02
#   -2.83189412e-02 -5.70706241e-02 -1.13342014e-01 -1.12463325e-01
#   -7.32459479e-02 -7.31634628e-02 -3.59799191e-02  1.44906407e-02
#    8.52521482e-02  1.04914075e-02  1.97760750e-02 -1.54254790e-02
#   -1.09626900e-03  4.80555567e-03  3.98572076e-03 -8.09110078e-03
#   -4.44778069e-02 -3.89168751e-02 -3.97850854e-03  0.00000000e+00
#    0.00000000e+00  1.71708810e-01 -1.40072559e-01  1.17691473e-02
#    1.50970755e-02  7.65992558e-03  8.18325833e-03  5.67842423e-03
#    2.24146721e-02 -1.00125066e-01 -1.21343073e-02  1.75293224e-02
#   -1.21505183e-02 -1.75884036e-02  4.06121153e-03  1.08689367e-02
#   -5.27930779e-03 -6.64781447e-02  1.89840316e-02  8.72519018e-03
#    1.68475555e-02 -4.33399190e-02 -4.34109535e-02 -3.26867690e-02
#   -6.33692335e-03  1.96736261e-02  2.19727191e-02  7.54105580e-03
#   -8.20882052e-04 -2.56360711e-03 -6.97057267e-03 -4.86779090e-03
#    0.00000000e+00  3.70587190e-02  3.87512105e-02  5.35293771e-02
#    5.40260361e-02  3.52547452e-02  7.38303025e-02  2.87349906e-02
#    1.12398904e-02  3.04291069e-02  2.59330752e-02 -1.79564622e-02
#   -1.89764271e-02  3.78563881e-02  1.18861594e-02  1.29108443e-02
#   -3.22770767e-03  1.05217169e-02  1.71875940e-02  5.15514434e-03
#   -7.85405687e-03 -1.27524901e-02 -1.00585061e-02 -5.15992968e-02
#   -6.81270639e-04 -1.20981110e-02 -2.39788138e-02  2.81228303e-02
#   -1.45045131e-02 -1.82224829e-04 -6.03302206e-03 -4.34454291e-02
#    9.92479700e-03  5.17984316e-02  3.63640003e-02  2.75236398e-02
#    2.95593224e-02 -1.87519149e-02  1.34561848e-03 -6.30425545e-03
#    1.32796884e-02  8.14678111e-03  2.99543962e-03  2.57586985e-02
#   -3.69768187e-02 -6.32854055e-03 -1.78951350e-02 -2.49831403e-03
#    2.23272626e-02 -8.33310381e-03 -2.76327298e-02 -1.00352292e-01
#    3.76713012e-02 -4.92299236e-02  1.06201574e-01  3.32669895e-02
#    0.00000000e+00  1.61332125e-02 -2.35153768e-02 -1.18757766e-02
#   -1.05027411e-01]
#  [ 0.00000000e+00 -3.94721956e-02  0.00000000e+00  6.07301785e-02
#    1.44173438e-01 -1.22173468e-02 -3.17977472e-02 -8.22218213e-03
#    2.65840827e-02 -5.63945523e-02  6.41073802e-02 -3.89950568e-02
#    2.11142550e-02  5.37377681e-01  1.09352211e+00  9.34446528e-01
#    8.78731991e-01  6.12055571e-01  6.87024168e-01  1.05492117e+00
#    1.03906998e+00  1.00168757e+00  8.00396846e-01  7.13175687e-01
#    6.39286067e-01  7.83805101e-01  6.57077681e-01  2.36860451e-01
#    2.37693609e-01  8.58087320e-01  8.61863920e-01  7.71785619e-01
#    6.48527838e-01  7.52196654e-01  4.86090581e-01  6.95371833e-01
#    6.86604110e-01  8.34224663e-01  6.82518171e-01  3.32482339e-01
#    5.45455884e-01  3.55322957e-01  9.02935315e-01  1.04741900e+00
#    8.86872327e-01  8.28130520e-01  8.59399686e-01  7.98489856e-01
#    9.42775565e-01  9.48871005e-01  8.71216402e-01  4.62912461e-01
#    7.22722755e-01  7.48860474e-01  7.32238626e-01  8.01573094e-01
#    4.95185681e-01  8.48925752e-01  1.03710029e+00  1.01074656e+00
#    8.00197626e-01  9.79524665e-01  6.72866278e-01  7.83315722e-01
#    7.22688363e-01  6.20843564e-01 -1.89931113e-01 -8.78786431e-02
#   -9.70753320e-02 -8.50898182e-02 -2.20166068e-02  4.03780767e-02
#   -3.25892858e-02 -1.60902246e-02  1.77714339e-01  4.49121869e-01
#   -7.12569093e-04  3.25948616e-01  1.30523917e-01  4.54592426e-02
#   -4.30803323e-02 -5.29833884e-02  6.30482698e-03 -2.32395398e-02
#   -2.29866671e-01 -2.03352650e-01 -2.24183123e-01 -1.68489972e-01
#   -2.35048100e-01 -2.34509350e-01 -2.38667607e-01 -2.30477111e-01
#   -2.12524208e-01 -2.27222029e-01 -1.65816182e-01 -1.86060243e-01
#   -2.06981605e-01 -2.20336093e-01 -5.63444258e-02 -5.57757301e-02
#   -1.76377946e-01 -1.66468283e-01 -1.91318494e-01 -1.68725318e-01
#   -1.92812795e-01 -2.17645304e-01 -2.10612032e-01 -2.17666077e-01
#   -2.01139679e-01 -1.88879357e-01 -1.61909778e-01 -1.91305183e-01
#   -2.00291576e-01 -1.97358251e-01 -5.94253941e-02 -5.77998943e-02
#   -5.77998943e-02  9.90113775e-02  9.90113775e-02 -7.62864693e-02
#   -3.53985390e-02 -4.60997099e-02  4.48259238e-02  1.38594142e-02
#    6.74348045e-02  4.01959198e-02 -7.16024308e-02  1.30283361e-02
#   -2.33249115e-02  2.21247775e-01  2.75934431e-01  2.68968888e-01
#    4.25731762e-02  7.20049303e-02  1.02379711e-01 -1.08993409e-01
#   -1.52293287e-01 -3.64350972e-02 -1.99440247e-02  3.50275195e-02
#   -2.46660524e-02  1.89758437e-02 -2.16360400e-02  2.16716979e-02
#    7.19623141e-02 -7.25173107e-03  8.15124898e-02  0.00000000e+00
#    0.00000000e+00 -4.12112167e-01 -5.84237883e-02 -2.93813135e-02
#   -3.21089939e-02 -1.35527409e-02 -4.86862541e-02 -2.66181067e-02
#   -5.78937054e-02  1.04313957e-01  3.82319154e-02 -5.32660727e-02
#    2.20166068e-02  2.54383562e-02  2.00222814e-02  2.92004781e-02
#   -2.97113188e-02 -1.16083211e-01 -3.01679925e-02  1.83476987e-01
#   -4.47486407e-02  1.62085027e-01  1.62338177e-01  8.61964473e-02
#   -2.15976032e-02  1.50265198e-01  1.52989851e-01  1.61829569e-01
#   -4.24563621e-04  2.54629880e-02  7.89678666e-02  2.73019327e-04
#    0.00000000e+00  6.29131776e-02  1.73897744e-02  2.33237083e-03
#    1.03790857e-01  4.13683475e-02  1.37721570e-01  6.73451778e-02
#    1.16374802e-01  8.36612273e-02  8.23059962e-02 -1.00718733e-01
#   -9.35858451e-02  7.96855065e-02  1.15255132e-01 -8.30741310e-03
#   -2.27134984e-02 -1.83904428e-02 -3.11437330e-02 -3.94181985e-03
#    1.58155196e-02  1.11233312e-01 -6.23828239e-03 -1.40488696e-01
#    5.74251670e-03  4.42815520e-02  7.79481376e-02  1.09580811e-01
#    4.70391978e-02 -1.26378692e-02 -2.85201935e-02 -5.22171054e-02
#   -5.72647490e-02  1.44550216e-01  4.50051259e-03  1.36696861e-02
#    1.03925035e-01  9.82326432e-02 -5.84074471e-02 -1.79215025e-02
#    1.57409005e-01  1.44787540e-01  1.53633623e-01 -2.62297185e-02
#    9.27963864e-02  5.83353589e-02  2.87677011e-02  2.89780587e-02
#   -3.63737854e-02  8.50878009e-03 -6.45099547e-02 -1.00032918e-01
#    9.38336190e-02 -9.55499134e-02 -1.06502068e-01 -1.67860345e-01
#    0.00000000e+00  4.65981400e-02 -2.43350849e-02 -7.75553772e-02
#    6.59769059e-02]
#  [ 0.00000000e+00 -5.19935082e-02  0.00000000e+00  1.41420461e-01
#    4.08189295e-02 -2.01031136e-01  1.95019476e-01  8.15681008e-02
#   -1.25445255e-02 -4.94523331e-02 -7.22245376e-02 -1.63371759e-01
#   -1.60466473e-01 -6.05526980e-02 -1.92093997e-01 -2.11891228e-01
#   -1.00037323e-01  4.70539131e-02 -2.11208698e-01 -2.15309035e-01
#   -1.55498409e-01 -2.16559758e-01 -2.27759744e-01 -8.77742609e-02
#   -2.07329879e-01 -1.41107982e-01 -1.68324721e-01 -1.21254925e-01
#   -4.07010421e-02 -1.99277051e-01 -1.19245993e-01 -1.69166539e-01
#   -1.91854548e-01 -2.25618173e-01 -1.77460646e-01 -1.66049230e-01
#   -2.17148446e-01 -9.26012598e-02 -1.67399856e-01 -2.41331729e-01
#   -1.25338893e-01 -1.08110721e-01 -2.55803856e-01 -2.73214588e-01
#   -2.10805666e-01 -1.76242005e-01 -1.92564353e-01 -2.03476696e-01
#   -1.95062894e-01 -1.49459647e-01 -1.79875865e-01  1.46155936e-01
#   -1.25401394e-01 -1.31387182e-01 -8.25853210e-02 -1.39218582e-01
#   -1.19048515e-02 -1.39325326e-01 -1.78502997e-01 -1.34576173e-01
#   -1.17455195e-01 -2.32908167e-01 -9.05975349e-02 -2.26200640e-01
#   -2.14011458e-01 -9.42844752e-02  1.84096727e-01 -1.87118343e-01
#    2.43742852e-01 -9.08569685e-02  2.50092833e-01  2.67200258e-01
#    1.73883744e-01 -1.09794955e-01  1.86388582e-01 -8.47846654e-02
#    2.62558993e-01  1.04608321e-01  1.75668321e-01  4.73456922e-01
#    3.48319546e-01  3.85335138e-01 -2.95441066e-02  3.06866246e-01
#    1.89366544e+00  1.97114622e+00  2.19957840e+00  2.01058655e+00
#    2.51740722e+00  2.70970270e+00  2.74443311e+00  2.79086528e+00
#    2.72972773e+00  2.58297424e+00  1.92310085e+00  2.09284240e+00
#    1.98129484e+00  1.89635326e+00  3.09732858e-01  3.03766846e-01
#    1.82074648e+00  1.78677810e+00  1.99950008e+00  1.64817726e+00
#    2.23539046e+00  2.43835498e+00  2.36358889e+00  2.35850878e+00
#    2.42574638e+00  2.27545501e+00  1.77727329e+00  2.20908473e+00
#    1.80567691e+00  1.84001330e+00  3.11136606e-01  4.70296029e-01
#    4.70296029e-01 -1.88097096e-01 -1.88097096e-01  4.85700181e-01
#    2.68793849e-01 -3.53597799e-01  1.54195619e-02  3.23769374e-01
#   -7.73239514e-02  1.58843863e-01 -1.42966916e-02  2.28691692e-01
#    3.04727046e-01 -2.96668016e-01 -3.41912790e-02 -1.75397466e-02
#    4.38791137e-01  3.38207245e-01 -6.10539149e-02  2.54650961e-01
#   -1.61886605e-01  4.01504679e-02 -8.97839386e-02  3.92385364e-03
#    9.24771826e-02 -1.02698757e-01  4.17163238e-02 -9.14184841e-03
#    1.09897312e-01  3.34557936e-01 -2.45066858e-01  0.00000000e+00
#    0.00000000e+00  3.17058731e-02  1.31390893e+00  6.02538204e-03
#   -1.12174304e-02 -1.49898019e-02  1.00127979e-01  4.51506722e-02
#    1.80492039e-02  4.43235470e-01 -3.31668703e-02  4.12446971e-02
#    2.20166068e-02  5.37067595e-02 -1.00323622e-01 -1.85702736e-01
#    1.42920941e-01  9.23563552e-01 -4.87635343e-02 -6.92430866e-01
#    1.77558712e-02 -2.05150407e-01 -2.05444181e-01 -3.23352269e-02
#    1.23796102e-01 -6.66864010e-01 -6.94424922e-01 -6.09502813e-01
#    7.97904612e-03 -6.60354297e-02 -2.12598316e-01  3.78404787e-02
#    0.00000000e+00 -5.08741725e-01 -3.67659354e-01 -4.34230693e-01
#   -7.82658946e-01 -4.21225534e-01 -1.05558343e+00 -4.57498523e-01
#   -4.84632138e-01 -5.26386994e-01 -4.85978981e-01  4.84967762e-01
#    4.68873187e-01 -5.72039991e-01 -4.85977555e-01 -7.46174830e-02
#    1.02822783e-01 -2.13563019e-02 -3.11437330e-02 -2.76726355e-02
#    8.85326944e-03 -2.76098659e-01  1.01286942e-01  8.87929075e-01
#   -1.40713594e-02 -5.39949247e-02 -7.36812675e-02 -5.96022060e-01
#   -4.41929502e-02  4.43594664e-02  1.44879455e-01  5.23290536e-01
#    1.15384028e-01 -9.03304710e-01 -3.04885695e-01 -2.65611695e-01
#   -5.88259842e-01 -1.84178813e-01  1.87588922e-01  1.11054800e-01
#   -6.40196955e-01 -5.56465593e-01 -5.45474246e-01 -1.16088734e-01
#   -2.05771393e-02 -1.47659818e-01  4.48457667e-02 -7.84898302e-02
#   -5.43192989e-02  3.74763458e-02  4.39093862e-01  1.13884558e+00
#   -6.18601752e-01  7.16482630e-01 -4.84200125e-01  3.04980358e-01
#    0.00000000e+00 -2.86696515e-01  2.69900864e-01  3.57896298e-01
#    6.12440428e-01]]
#
# Labels
# [1 0 0 ... 0 1 0]
#
# Coordinates: DR1DRSTZ Label: 1
# Coordinates: DR1EXMER Label: 0
# Coordinates: DRABF Label: 0
# Coordinates: DRDINT Label: 1
# Coordinates: DR1DBIH Label: 0
# Coordinates: DR1DAY Label: 1
# Coordinates: DR1LANG Label: 0
# Coordinates: DR1MNRSP Label: 0
# Coordinates: DR1HELPD Label: 0
# Coordinates: DBQ095Z Label: 1
# Coordinates: DRQSPREP Label: 0
# Coordinates: DR1STY Label: 0
# Coordinates: DRQSDIET Label: 1
# Coordinates: DR1TNUMF Label: 0
# Coordinates: DR1TKCAL Label: 0
# Coordinates: DR1TPROT Label: 2
# Coordinates: DR1TCARB Label: 2
# Coordinates: DR1TSUGR Label: 0
# Coordinates: DR1TFIBE Label: 1
# Coordinates: DR1TTFAT Label: 1
# Coordinates: DR1TSFAT Label: 0
# Coordinates: DR1TMFAT Label: 0
# Coordinates: DR1TPFAT Label: 1
# Coordinates: DR1TCHOL Label: 0
# Coordinates: DR1TATOC Label: 0
# Coordinates: DR1TRET Label: 0
# Coordinates: DR1TVARA Label: 0
# Coordinates: DR1TBCAR Label: 1
# Coordinates: DR1TLZ Label: 1
# Coordinates: DR1TVB1 Label: 0
# Coordinates: DR1TVB2 Label: 2
# Coordinates: DR1TNIAC Label: 0
# Coordinates: DR1TVB6 Label: 1
# Coordinates: DR1TFOLA Label: 0
# Coordinates: DR1TFA Label: 0
# Coordinates: DR1TFF Label: 1
# Coordinates: DR1TFDFE Label: 0
# Coordinates: DR1TCHL Label: 0
# Coordinates: DR1TVB12 Label: 0
# Coordinates: DR1TVC Label: 0
# Coordinates: DR1TVD Label: 2
# Coordinates: DR1TVK Label: 0
# Coordinates: DR1TCALC Label: 1
# Coordinates: DR1TPHOS Label: 0
# Coordinates: DR1TMAGN Label: 0
# Coordinates: DR1TIRON Label: 1
# Coordinates: DR1TZINC Label: 0
# Coordinates: DR1TCOPP Label: 0
# Coordinates: DR1TSODI Label: 1
# Coordinates: DR1TPOTA Label: 0
# Coordinates: DR1TSELE Label: 0
# Coordinates: DR1TMOIS Label: 0
# Coordinates: DR1TS040 Label: 1
# Coordinates: DR1TS060 Label: 2
# Coordinates: DR1TS080 Label: 0
# Coordinates: DR1TS100 Label: 0
# Coordinates: DR1TS120 Label: 0
# Coordinates: DR1TS140 Label: 1
# Coordinates: DR1TS160 Label: 0
# Coordinates: DR1TS180 Label: 2
# Coordinates: DR1TM161 Label: 0
# Coordinates: DR1TM181 Label: 1
# Coordinates: DR1TM201 Label: 1
# Coordinates: DR1TP182 Label: 0
# Coordinates: DR1TP183 Label: 0
# Coordinates: DR1TP204 Label: 0
# Coordinates: DR1.300 Label: 1
# Coordinates: DR1TWS Label: 1
# Coordinates: DRD340 Label: 0
# Coordinates: DRD360 Label: 1
# Coordinates: PEASCST1 Label: 0
# Coordinates: PEASCTM1 Label: 1
# Coordinates: BPXPULS Label: 1
# Coordinates: BMDSTATS Label: 0
# Coordinates: BMXWT Label: 0
# Coordinates: BMXHT Label: 1
# Coordinates: BMXBMI Label: 0
# Coordinates: BMXARML Label: 0
# Coordinates: BMXARMC Label: 0
# Coordinates: BMXWAIST Label: 0
# Coordinates: MGDEXSTS Label: 1
# Coordinates: OHDEXSTS Label: 0
# Coordinates: OHDDESTS Label: 0
# Coordinates: OHX01TC Label: 1
# Coordinates: OHX02TC Label: 0
# Coordinates: OHX03TC Label: 0
# Coordinates: OHX04TC Label: 0
# Coordinates: OHX05TC Label: 0
# Coordinates: OHX06TC Label: 0
# Coordinates: OHX07TC Label: 1
# Coordinates: OHX08TC Label: 0
# Coordinates: OHX09TC Label: 1
# Coordinates: OHX10TC Label: 0
# Coordinates: OHX11TC Label: 1
# Coordinates: OHX12TC Label: 0
# Coordinates: OHX13TC Label: 1
# Coordinates: OHX14TC Label: 0
# Coordinates: OHX15TC Label: 0
# Coordinates: OHX16TC Label: 2
# Coordinates: OHX17TC Label: 1
# Coordinates: OHX18TC Label: 0
# Coordinates: OHX19TC Label: 0
# Coordinates: OHX20TC Label: 2
# Coordinates: OHX21TC Label: 1
# Coordinates: OHX22TC Label: 1
# Coordinates: OHX23TC Label: 0
# Coordinates: OHX24TC Label: 0
# Coordinates: OHX25TC Label: 0
# Coordinates: OHX26TC Label: 0
# Coordinates: OHX27TC Label: 0
# Coordinates: OHX28TC Label: 0
# Coordinates: OHX29TC Label: 1
# Coordinates: OHX30TC Label: 0
# Coordinates: OHX31TC Label: 0
# Coordinates: OHX32TC Label: 1
# Coordinates: URXUMA Label: 0
# Coordinates: URXUMS Label: 0
# Coordinates: URXUCR.x Label: 0
# Coordinates: URXCRS Label: 1
# Coordinates: URDACT Label: 0
# Coordinates: LBXWBCSI Label: 0
# Coordinates: LBXLYPCT Label: 1
# Coordinates: LBXMOPCT Label: 0
# Coordinates: LBXNEPCT Label: 0
# Coordinates: LBXEOPCT Label: 1
# Coordinates: LBXBAPCT Label: 0
# Coordinates: LBDLYMNO Label: 0
# Coordinates: LBDMONO Label: 0
# Coordinates: LBDNENO Label: 0
# Coordinates: LBXRBCSI Label: 0
# Coordinates: LBXHGB Label: 1
# Coordinates: LBXHCT Label: 0
# Coordinates: LBXMCVSI Label: 0
# Coordinates: LBXMCHSI Label: 0
# Coordinates: LBXMC Label: 0
# Coordinates: LBXRDW Label: 0
# Coordinates: LBXPLTSI Label: 1
# Coordinates: LBXMPSI Label: 1
# Coordinates: PHQ020 Label: 0
# Coordinates: PHQ030 Label: 0
# Coordinates: PHQ040 Label: 1
# Coordinates: PHQ050 Label: 1
# Coordinates: PHQ060 Label: 1
# Coordinates: PHAFSTMN.x Label: 0
# Coordinates: LBXHA Label: 0
# Coordinates: LBXHBS Label: 1
# Coordinates: URXVOL1 Label: 0
# Coordinates: SDDSRVYR Label: 0
# Coordinates: RIDSTATR Label: 0
# Coordinates: RIAGENDR Label: 1
# Coordinates: RIDAGEYR Label: 0
# Coordinates: RIDRETH1 Label: 0
# Coordinates: RIDRETH3 Label: 0
# Coordinates: RIDEXMON Label: 0
# Coordinates: DMDBORN4 Label: 0
# Coordinates: DMDCITZN Label: 1
# Coordinates: SIALANG Label: 1
# Coordinates: SIAPROXY Label: 0
# Coordinates: SIAINTRP Label: 0
# Coordinates: FIALANG Label: 0
# Coordinates: FIAPROXY Label: 1
# Coordinates: FIAINTRP Label: 1
# Coordinates: DMDHHSIZ Label: 0
# Coordinates: DMDFMSIZ Label: 1
# Coordinates: DMDHRGND Label: 0
# Coordinates: DMDHRAGE Label: 2
# Coordinates: DMDHRBR4 Label: 0
# Coordinates: DMDHREDU Label: 0
# Coordinates: DMDHRMAR Label: 1
# Coordinates: WTINT2YR Label: 0
# Coordinates: WTMEC2YR Label: 0
# Coordinates: SDMVPSU Label: 0
# Coordinates: SDMVSTRA Label: 0
# Coordinates: INDHHIN2 Label: 1
# Coordinates: INDFMIN2 Label: 0
# Coordinates: INDFMPIR Label: 0
# Coordinates: CBD070 Label: 0
# Coordinates: HSQ500 Label: 1
# Coordinates: HSQ510 Label: 1
# Coordinates: HSQ520 Label: 0
# Coordinates: HSAQUEX Label: 0
# Coordinates: DIQ010 Label: 0
# Coordinates: DIQ050 Label: 0
# Coordinates: DLQ010 Label: 1
# Coordinates: DLQ020 Label: 0
# Coordinates: DLQ040 Label: 1
# Coordinates: DLQ050 Label: 1
# Coordinates: DLQ060 Label: 0
# Coordinates: FSD032A Label: 0
# Coordinates: FSD032B Label: 0
# Coordinates: FSD032C Label: 0
# Coordinates: FSDHH Label: 1
# Coordinates: FSDAD Label: 0
# Coordinates: FSD151 Label: 2
# Coordinates: FSQ165 Label: 0
# Coordinates: FSQ162 Label: 0
# Coordinates: HEQ010 Label: 2
# Coordinates: HEQ030 Label: 0
# Coordinates: HIQ011 Label: 0
# Coordinates: HIQ270 Label: 1
# Coordinates: HIQ210 Label: 2
# Coordinates: HOD050 Label: 0
# Coordinates: HOQ065 Label: 0
# Coordinates: HUQ010 Label: 0
# Coordinates: HUQ020 Label: 0
# Coordinates: HUQ030 Label: 1
# Coordinates: HUQ041 Label: 1
# Coordinates: HUQ071 Label: 0
# Coordinates: HUQ090 Label: 1
# Coordinates: IMQ011 Label: 0
# Coordinates: IMQ020 Label: 0
# Coordinates: INQ020 Label: 0
# Coordinates: INQ012 Label: 0
# Coordinates: INQ030 Label: 0
# Coordinates: INQ060 Label: 0
# Coordinates: INQ080 Label: 0
# Coordinates: INQ090 Label: 1
# Coordinates: INQ132 Label: 1
# Coordinates: INQ140 Label: 0
# Coordinates: INQ150 Label: 0
# Coordinates: IND235 Label: 0
# Coordinates: INDFMMPI Label: 0
# Coordinates: INDFMMPC Label: 1
# Coordinates: MCQ010 Label: 0
# Coordinates: MCQ053 Label: 0
# Coordinates: MCQ082 Label: 2
# Coordinates: MCQ086 Label: 0
# Coordinates: MCQ092 Label: 1
# Coordinates: MCQ203 Label: 1
# Coordinates: MCQ300B Label: 0
# Coordinates: OHQ030 Label: 0
# Coordinates: OHQ033 Label: 0
# Coordinates: OHQ770 Label: 0
# Coordinates: OHQ845 Label: 0
# Coordinates: PAAQUEX Label: 0
# Coordinates: SMQ860 Label: 0
# Coordinates: SMQ870 Label: 0
# Coordinates: SMQ872 Label: 0
# Coordinates: SMQ874 Label: 1
# Coordinates: SMQ878 Label: 0
# Coordinates: SMAQUEX.x Label: 0

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
# Store the cluster labels
kmeans_labels = kmeans.labels_

# Recreate the scatter plot with BMI vs Income-to-Poverty Ratio
ax = sns.scatterplot(x="INDFMPIR", y="BMXBMI", 
                     hue=kmeans_labels, 
                     palette="tab10", 
                     data=kmeansscale, 
                     legend="full",
                    alpha=0.7)

# Plot the cluster centers on top of the scatter plot
centers = kmeans.cluster_centers_

# Plotting each cluster center (use a larger size and '+' marker)
ax.scatter(centers[:, 0], centers[:, 1], s=50,  marker='+', c='black', label='cluster centers')

# Set the axis labels and plot title
ax.set(xlabel="Income to Poverty Line Ratio", ylabel="Body Mass Index")
ax.set_title("BMI vs. Income-Poverty Ratio with K-means Clusters")

# Show the plot with the legend
plt.legend()
plt.show()

# %% [markdown]
# So, from what I am seeing here, because the clusters look so messy in this feature space (the cluster centers are close and the clusters are disorganized), it is telling me that the 3 clusters (which we picked using the elbow method) are not necessarily the best features for selecting clusters.

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
# set random seed
np.random.seed(10)

# %%
# specify kmeans algorithm
# ----------
kmeanspca = KMeans(n_clusters=3,
                n_init=10,
                max_iter=300 #default
                ).fit(pca5_result)

# %%
# print the centers 
print("Centers")
print(kmeanspca.cluster_centers_)
print()

# print labels
print("Labels")
print(kmeanspca.labels_)
print()

# print coordinates and labels 
for point, label in zip (pca5_result, kmeanspca.labels_):
    print("Coordinates:", point, "Label:", label)
# Out:
# Centers
# [[ 6.00775549  0.28984704  0.14525424  0.12444951 -0.22310831]
#  [-1.94116294 -1.56740342  0.12330025  0.18849414  0.09672323]
#  [-4.13700856 11.44304163 -1.44486661 -1.89246652 -0.04098009]]
#
# Labels
# [0 1 1 ... 1 0 1]
#
# Coordinates: [ 9.52781112 -0.81622358 -1.86704077 -2.11022145 -3.9299219 ] Label: 0
# Coordinates: [-5.83833854 -3.69257214  3.8057478  -1.02960988  0.38874844] Label: 1
# Coordinates: [-0.71945407 -2.57320031  0.90792549 -4.75637298 -1.80251984] Label: 1
# Coordinates: [ 3.53362678 -2.57698203 -3.24913977 -0.4058505   3.99822952] Label: 0
# Coordinates: [-6.87209426 -4.194241    0.88683213 -0.84922525 -0.52740346] Label: 1
# Coordinates: [ 9.65823746 -0.75390445 -3.81757348  1.95758869  9.89271052] Label: 0
# Coordinates: [-5.72170998 -3.65244882  0.1482493   1.47969966 -1.9210678 ] Label: 1
# Coordinates: [-0.39330953  5.37427384 -2.94890397  0.47730138 -1.47759855] Label: 2
# Coordinates: [-1.06767820e-03 -2.38648359e+00 -3.17692962e+00  1.13693430e+00
#   1.06526074e+00] Label: 1
# Coordinates: [ 4.16862643 -2.17178424 -0.87419392 -4.01295592 -2.34833522] Label: 0
# Coordinates: [ 0.56694447  4.2709855  -3.78895908  0.51025849  0.45030053] Label: 1
# Coordinates: [-1.1317142  -0.74248458  0.32212829  2.97073293  6.17898003] Label: 1
# Coordinates: [ 2.60166211 -1.51295521 -2.38123789  1.64505042 -2.30388184] Label: 0
# Coordinates: [-6.06369767e+00  4.65641811e-03  4.63539345e+00  3.23481618e+00
#  -1.41327486e+00] Label: 1
# Coordinates: [-2.88565456 -3.3904534  -3.31951554  0.71394403 -0.92005746] Label: 1
# Coordinates: [-5.38178243 14.36524175 -2.24765667 -4.47353538 -1.5508236 ] Label: 2
# Coordinates: [-9.63721371 11.66008322 -5.59531775 -3.8103911  -1.09146513] Label: 2
# Coordinates: [ 0.13174466 -1.89336924 -2.88452122  1.57517634 -0.04974911] Label: 1
# Coordinates: [11.64274592  1.88991341  1.51206973  1.86362123 -3.53525132] Label: 0
# Coordinates: [ 9.09416948  0.57244063 -3.62454385  1.39235768 -0.70232604] Label: 0
# Coordinates: [ 0.55655497 -1.97286829 -3.04022284  5.09730214  0.1258746 ] Label: 1
# Coordinates: [-3.50200895 -1.75309448  1.09730601  1.15549896  0.52630748] Label: 1
# Coordinates: [ 4.08377271  0.63252413 -2.63636987  2.10804951  2.07352011] Label: 0
# Coordinates: [-0.09976048 -2.60921128  1.83393767 -2.47132353 -2.20131001] Label: 1
# Coordinates: [-1.79033196 -3.43948153 -5.10642586 -0.30164062  2.55774706] Label: 1
# Coordinates: [-2.39132005 -2.65256143  2.87920479 -2.91997987 -0.79019951] Label: 1
# Coordinates: [-3.78498845 -1.77828098 -4.12185183 -0.168457    2.73080621] Label: 1
# Coordinates: [39.67832364  9.57240931  3.79143682  3.99696831 11.87568604] Label: 0
# Coordinates: [ 6.89357303  0.79948609 -4.18240945 -0.88798093  3.08495937] Label: 0
# Coordinates: [-0.44179208  4.51541379 -1.8015722   5.23723196 -3.47335497] Label: 1
# Coordinates: [ 1.98435645 15.58643458 -1.75407592 -2.06352582  0.88008556] Label: 2
# Coordinates: [ 1.14982867  2.92465207 -4.5159401  -0.86734989  0.38493109] Label: 1
# Coordinates: [ 8.99620519 -0.88115622 -1.22602553 -1.3773956  -5.706579  ] Label: 0
# Coordinates: [-4.05876793 -0.42947709 -2.17515513  3.2434383   0.26538476] Label: 1
# Coordinates: [-5.14052668  1.8300246  -0.59593336  3.17219051  0.67297668] Label: 1
# Coordinates: [ 7.56652167  0.17900143 -1.6483132   2.88968006  1.93125754] Label: 0
# Coordinates: [ 0.55021192  2.74473433  0.28149895 -1.12164037 -0.45620561] Label: 1
# Coordinates: [ 1.24561609 -3.13927966 -1.74499866 -1.5506373  -1.09519406] Label: 1
# Coordinates: [-1.56001842  0.33346291 -1.8695923   2.7148629   0.26060202] Label: 1
# Coordinates: [-3.96140156 -5.25720431  0.03426483 -4.83230681  0.70270387] Label: 1
# Coordinates: [-3.10185684  5.60707172 -3.77252487 -2.18022905  0.98133761] Label: 2
# Coordinates: [-7.52277548  2.54661972  3.77756462  3.62368695  0.91593394] Label: 1
# Coordinates: [ 2.20637458 -1.06906782 -1.55149812  4.0383407  -0.75273362] Label: 0
# Coordinates: [-0.19531221  3.33918152  4.03247991  3.26330547 -2.18970908] Label: 1
# Coordinates: [ 0.07863559 -1.7637096   3.71237287 -0.96886352  0.59664236] Label: 1
# Coordinates: [ 4.56145568 -1.35354939 -2.63712041  2.46524595  2.58477654] Label: 0
# Coordinates: [ 1.78658726 -3.54090295 -1.23118332 -2.36237108 -1.97606292] Label: 1
# Coordinates: [ 1.58082882 -0.69543387  3.71332454 -1.1829523  -0.06778037] Label: 1
# Coordinates: [ 2.29529044 -1.15987976 -3.81940249  2.70275105 -3.45335199] Label: 0
# Coordinates: [-4.57965384 -2.31041242 -2.91549425 -1.22635615 -0.00609528] Label: 1
# Coordinates: [-7.11981849 -3.4664477   5.67588127 -2.91230224  1.21495178] Label: 1
# Coordinates: [-2.37164923 -0.77573992  3.52117764  1.8370852  -1.00255737] Label: 1
# Coordinates: [ 2.08219865  3.49924579 -4.93743125  0.4791263  -4.49157151] Label: 0
# Coordinates: [-10.50919086  15.5928888   -0.2171443    2.39636991  -0.78032643] Label: 2
# Coordinates: [-1.05916605 -2.74606154 -2.48359809  0.45041205  4.86681413] Label: 1
# Coordinates: [-5.31333466  2.95648784 -5.05854235  1.00249969  0.38702813] Label: 1
# Coordinates: [ 0.67768055 -2.84413474 -3.94003865 -0.59839194 -3.99398713] Label: 1
# Coordinates: [ 2.39693233  0.30663719  1.16018235  2.18408293 -1.89901998] Label: 0
# Coordinates: [-3.95530539 -1.133367    6.17168912 -4.1867875   1.83179103] Label: 1
# Coordinates: [-5.97484024 14.83474355 -1.26443569 -2.67895254 -0.99752808] Label: 2
# Coordinates: [-0.09452613 -2.87935237 -1.04323462 -1.57590142 -0.90844339] Label: 1
# Coordinates: [ 2.64945263 -3.18088815 -0.61328425 -3.66080042 -2.56672368] Label: 0
# Coordinates: [ 3.35289976 -0.41296523 -0.33849984  2.68923789 -0.21858455] Label: 0
# Coordinates: [-5.39527448  2.26122522 -2.84312679  2.78312309 -0.63455001] Label: 1
# Coordinates: [ 1.34794773 -0.22151863  0.61865758 -0.98077279  4.29809687] Label: 1
# Coordinates: [-4.42716877 -2.79999679  2.09473981  2.68765529 -0.41585344] Label: 1
# Coordinates: [ 3.93827466 -2.73093612 -1.99055275 -2.94761515 -3.61028432] Label: 0
# Coordinates: [ 8.91022039 -2.26919884  0.46459472 -5.81898999 -0.11964556] Label: 0
# Coordinates: [-0.2276514   0.39286136  1.68080606  2.04607764  1.53982667] Label: 1
# Coordinates: [ 2.8123937   0.87673158 -0.58036258  2.40655811  1.2143655 ] Label: 0
# Coordinates: [-0.41498543  5.15033416 -0.83116922 -1.84343602 -0.03694052] Label: 1
# Coordinates: [10.87071797  3.52585972  2.01109538  2.54996762  0.83974575] Label: 0
# Coordinates: [ 6.88199737  1.43686107  1.8412382   1.50615351 -0.24147335] Label: 0
# Coordinates: [-1.30821378 -0.23756186 -0.76200357  2.12948316 -1.87549454] Label: 1
# Coordinates: [-1.00781359 -2.26326127  1.02852383  0.27456138  0.69842571] Label: 1
# Coordinates: [ 3.24560505 -1.27776957 -1.91053563  1.14814373 -1.9079517 ] Label: 0
# Coordinates: [-2.54239687 -1.77828943  2.1289726   1.3794911  -1.17186939] Label: 1
# Coordinates: [-2.7513958  -2.54477436 -5.69998427  3.12565313 -1.17309334] Label: 1
# Coordinates: [ 1.09578514 -0.52601752  3.54399189  3.47518785 -0.12532011] Label: 1
# Coordinates: [-0.02835652 -4.52704491 -1.79352533 -3.96871498 -1.94699235] Label: 1
# Coordinates: [18.37393418  4.78637771 -1.94335982  6.08877281  3.93926407] Label: 0
# Coordinates: [-2.32286035 -1.62304873  4.83773626 -0.94453225  1.47026164] Label: 1
# Coordinates: [-2.47703227 -2.53039245  2.77165886  0.27553982 -1.80460876] Label: 1
# Coordinates: [5.88597099 3.30233512 3.20562007 3.30289254 1.69617835] Label: 0
# Coordinates: [-3.49549811 -2.90358257  1.48691873 -1.06618952 -0.86634244] Label: 1
# Coordinates: [-0.60856966 -3.31101384 -2.5931232  -0.10304399 -1.06410622] Label: 1
# Coordinates: [-2.34780352  2.93121978 -1.00525081  0.58182573  1.1053242 ] Label: 1
# Coordinates: [-0.83890291 -3.22507845 -0.16596126 -1.37740694  0.78485422] Label: 1
# Coordinates: [-0.13124969 -2.96161531  1.60325462 -2.93601946 -0.90832339] Label: 1
# Coordinates: [ 5.0949112  -0.99905763 -1.49137498  2.02410015  3.03913421] Label: 0
# Coordinates: [-3.87877298 -3.79056812  4.05366666 -2.82693497  0.82756239] Label: 1
# Coordinates: [ 6.37530017  0.80690443 -0.22548161  2.9246532   3.15769548] Label: 0
# Coordinates: [-2.70446329 -2.65558452 -3.79363864 -1.93704928  0.80029401] Label: 1
# Coordinates: [11.9057694   1.2353293   0.23389307  0.12511534 -1.17371439] Label: 0
# Coordinates: [ 1.85376    -1.24277414  0.00605946  0.73043484  2.12560846] Label: 1
# Coordinates: [ 5.36888684 -1.24656311  1.79477432 -2.35577171  4.30341677] Label: 0
# Coordinates: [-3.80079289 -1.15313237 -0.19214125 -0.66602374  0.67372496] Label: 1
# Coordinates: [-3.18748555 -1.72490507  7.38252917 -1.52627503 -0.05184723] Label: 1
# Coordinates: [-9.48380211 12.31093582 -2.12620813 -2.13933032 -1.56909507] Label: 2
# Coordinates: [ 9.76189397  0.83463617 -4.77363715  2.07181664  4.06686446] Label: 0
# Coordinates: [ 1.1558062  -2.18977096 -4.25005356  0.91407253 -1.08654567] Label: 1
# Coordinates: [-4.8800504  -3.7860985  -0.55706721 -0.2832781  -0.4538252 ] Label: 1
# Coordinates: [-6.03862991 11.79801646  3.1847549  -0.21586707  1.86400133] Label: 2
# Coordinates: [ 5.40816279 -0.99115289 -1.12861587  0.33343176 -3.56427535] Label: 0
# Coordinates: [ 3.60479858 -0.66084152 -3.31756852 -1.50107089  0.60917413] Label: 0
# Coordinates: [-5.81775342 -2.79527649 -1.39537908 -1.89802958  0.37196074] Label: 1
# Coordinates: [-0.6526976  -1.17212783  0.93555307 -0.14093979 -0.86637651] Label: 1
# Coordinates: [-5.03251846 -3.3266736   5.11446731 -4.35725645  0.28363668] Label: 1
# Coordinates: [-4.64415694 -2.09401907  1.846854    1.41166043 -1.4710023 ] Label: 1
# Coordinates: [-3.30445538 -1.47081267  1.32259719  2.88018537  1.09699009] Label: 1
# Coordinates: [-2.09847484 -0.70415417  1.65988375  3.27393367  0.15322097] Label: 1
# Coordinates: [26.60553223  6.30552418  2.38710524  1.54546253  4.44853613] Label: 0
# Coordinates: [-2.97375741  0.20244561  6.12789847  1.68718316  0.44846703] Label: 1
# Coordinates: [-2.68575691  4.70065301 -2.89060967  3.43382454  0.3186223 ] Label: 1
# Coordinates: [ 1.34524344  1.34660515  4.42474883  0.20638783 -2.0902863 ] Label: 1
# Coordinates: [ 1.85504809 -1.17489779  0.20864497  1.46375393 -1.45670439] Label: 1
# Coordinates: [-3.08206482  0.27250709 -1.68756707  1.74102931  2.67792972] Label: 1
# Coordinates: [-8.3394129  -4.50702395  2.47400658 -2.95873464 -0.04415087] Label: 1
# Coordinates: [ 6.8239404  -1.17374369 -3.64854245 -0.07982448 -3.8964846 ] Label: 0
# Coordinates: [-3.76209696  1.02440644 -1.86381212  2.60807489  0.64636729] Label: 1
# Coordinates: [-2.23534271 -1.09624337  6.6029858  -1.14566052  0.15760288] Label: 1
# Coordinates: [ 2.04727162 -0.9266152   2.13079    -0.67264763 -3.55348127] Label: 0
# Coordinates: [-5.5712664  -4.82044284 -1.48763768 -2.25587654  0.06429115] Label: 1
# Coordinates: [-1.80221521 -3.00306632 -3.55605643  1.23075629  2.27091909] Label: 1
# Coordinates: [10.72767871 -0.82707099 -1.55361699 -2.21846931  3.22617643] Label: 0
# Coordinates: [-1.58078492 -2.03075302 -4.02080539  1.13924558 -3.66497372] Label: 1
# Coordinates: [ 1.25679392 -3.61067437 -3.11002341 -2.16563709 -1.57696435] Label: 1
# Coordinates: [ 0.22959369 -2.0486255  -2.05578769  1.26893031  3.08476464] Label: 1
# Coordinates: [ 1.03347294 -2.62302499 -4.05967809  0.34440601  3.63276078] Label: 1
# Coordinates: [-1.81105953 -3.65018792 -4.43506436 -0.1713855  -0.90269641] Label: 1
# Coordinates: [ 2.86166307 -2.82622657 -0.85058817 -2.91482646 -1.80768556] Label: 0
# Coordinates: [-5.48778112  0.32041676  0.49439387  1.7622846  -1.35960729] Label: 1
# Coordinates: [-3.02610378 -2.24665269  1.37997165 -0.74973163  2.75642533] Label: 1
# Coordinates: [-1.76176348  4.3702053  -3.48212812  2.06515794 -0.59198549] Label: 1
# Coordinates: [-0.61539918  3.59512829  1.24551093 -0.22447692  2.66419932] Label: 1
# Coordinates: [-4.91370024 -2.50623204  5.62038446 -0.59586789  2.22263629] Label: 1
# Coordinates: [10.1247492  -0.48279551  1.74099183 -3.10480784 -0.26344061] Label: 0
# Coordinates: [11.11312101  0.46297975  2.80295051 -2.24528748 -0.5809819 ] Label: 0
# Coordinates: [ 0.40878625 -1.86453734  0.74383868 -0.31497031 -1.70642423] Label: 1
# Coordinates: [-1.40144828 -1.64773245 -1.88237581  3.54294566 -1.79090438] Label: 1
# Coordinates: [ 7.56784928  0.21620768 -2.96971492  3.14655599 -3.85886195] Label: 0
# Coordinates: [ 2.8641298  -1.56830093 -3.4083583   4.46067601  1.58616113] Label: 0
# Coordinates: [ 4.00787711  4.67105128 -2.04515664  3.22592301 -0.21627218] Label: 0
# Coordinates: [ 1.34581088 -2.87105891 -3.46420843 -0.13235628  3.31013202] Label: 1
# Coordinates: [-2.4222198  -0.34486016  5.51480974  0.48636927  0.24483097] Label: 1
# Coordinates: [ 5.05108063 -1.6671598  -1.82542311 -0.13310383  1.50158767] Label: 0
# Coordinates: [-4.13233548 -4.12563481 -3.03153309 -0.41639251 -1.22799263] Label: 1
# Coordinates: [ 0.3982025  -1.61278975  1.79684443  0.80084108 -2.68203878] Label: 1
# Coordinates: [-3.6568858  -1.92773598 -0.10029507  3.83496825 -3.38730253] Label: 1
# Coordinates: [ 3.77402089 -1.22969594 -3.50945459  2.85322242 -5.43357312] Label: 0
# Coordinates: [-1.39646867 -2.13533121 -3.89656425  0.83507498  0.13739286] Label: 1
# Coordinates: [ 2.79241412 -4.59941495 -0.91259982 -4.93726948  0.1636166 ] Label: 1
# Coordinates: [-1.4484814   1.7151156  -2.23862207 -0.57687048  2.07345416] Label: 1
# Coordinates: [-3.08776603 -3.01109666 -3.44245629  1.04101802  1.88491617] Label: 1
# Coordinates: [-1.57410346 -1.92195516  3.96742833 -2.76571828 -0.34643249] Label: 1
# Coordinates: [ 3.20722076 -0.16810846  2.95183531  0.28424295  0.42003502] Label: 0
# Coordinates: [ 7.77486619 -0.05773429 -1.09409531 -0.81314533 -5.28148861] Label: 0
# Coordinates: [-7.34943165 -1.2384296  -0.82416393  2.61844125 -1.53432437] Label: 1
# Coordinates: [-0.4322833   1.53455087 -1.28793343  0.97229707  3.14116566] Label: 1
# Coordinates: [-1.87332428 -3.41656322 -1.51375163 -0.35432094 -2.46908074] Label: 1
# Coordinates: [ 5.479124   -1.43518666 -0.99500634  0.32150152 -1.30639532] Label: 0
# Coordinates: [ 3.60995566 -0.28039072  1.37665565  1.40664093  0.67018038] Label: 0
# Coordinates: [-2.65330194 -3.58848147 -2.63269757 -0.45164883 -0.3153426 ] Label: 1
# Coordinates: [4.62411011 2.64610344 3.38147754 3.13518384 2.03740231] Label: 0
# Coordinates: [-7.88126574 -1.63065007  4.70340394  1.36626742 -0.02129818] Label: 1
# Coordinates: [ 2.92102354 12.56643686  0.64356819 -2.6011439  -0.23989132] Label: 2
# Coordinates: [-4.200017   -2.20216569 -1.4160782   4.17381338 -2.10204802] Label: 1
# Coordinates: [-5.58821225 -0.92731823  1.70042331  4.55184014  0.63378492] Label: 1
# Coordinates: [ 5.12445875 -1.64620018 -2.27335997 -0.04763418 -0.57033209] Label: 0
# Coordinates: [-0.04109699 -1.85717703  0.8907355   0.51838235  2.84416198] Label: 1
# Coordinates: [ 1.28860674  1.56343644 -2.44115066  0.3776701   5.07003692] Label: 1
# Coordinates: [-1.70809119 -2.47058054 -4.13665306  3.08362102  0.3155148 ] Label: 1
# Coordinates: [-2.17924512 -3.40952118 -2.77236271  2.28416458  0.51597187] Label: 1
# Coordinates: [ 2.73608263 -0.400465   -2.47156474  0.20550815  1.55537998] Label: 0
# Coordinates: [-0.99306016 -3.96485958 -2.12868905 -2.82153063 -3.0443675 ] Label: 1
# Coordinates: [-5.05507626 -3.7627388   1.71648604 -2.11186546  0.34474114] Label: 1
# Coordinates: [-7.24818125  1.44774827 -2.38210287  1.59647742 -0.7763821 ] Label: 1
# Coordinates: [ 3.42201116  1.00893327 -2.99022269  2.73983114 -2.80521911] Label: 0
# Coordinates: [3.49837015 2.77613035 5.51999885 4.24073557 5.06919608] Label: 0
# Coordinates: [ 0.14589379 -0.80447436  3.18645512  1.47860269 -0.62716892] Label: 1
# Coordinates: [-0.91361125  1.31426966 -0.14164352  0.94638593  0.15255499] Label: 1
# Coordinates: [0.51953002 2.86793833 0.46071238 4.94651372 0.51341195] Label: 1
# Coordinates: [-1.35323997 -1.77878202  1.41530813 -0.74902344 -0.77265613] Label: 1
# Coordinates: [ 5.07732803 -1.36155308 -0.78893986 -0.70523014 -3.60577564] Label: 0
# Coordinates: [-5.62056288 -1.68659531  4.28052028  0.96384386 -0.55278487] Label: 1
# Coordinates: [ 4.70395393  5.28753811 -0.76234719  2.82838047 -1.04257307] Label: 0
# Coordinates: [ 3.61955154  1.79006177  1.19599637 -0.48888855  1.25704273] Label: 0
# Coordinates: [ 2.06242851 -0.93117165 -0.3551512  -2.48600323  2.45379549] Label: 1
# Coordinates: [-5.5304794  -1.85631068  0.1586143  -1.11148066 -0.27608893] Label: 1
# Coordinates: [-6.01039041  0.73963093  0.57308705  0.13804274  3.79899678] Label: 1
# Coordinates: [-3.11933968 -2.1849565   6.55417904 -2.49120925  0.96731176] Label: 1
# Coordinates: [6.09989822 1.05547816 4.20599729 2.53589042 2.46151368] Label: 0
# Coordinates: [-4.75203784 -0.80676375 -0.839647    1.8332916  -0.41369512] Label: 1
# Coordinates: [-9.14697186 14.43981686 -6.50259795  0.34029579 -0.59528866] Label: 2
# Coordinates: [-3.98376115e+00 -3.57872419e+00 -5.53467110e-01 -2.07027441e-03
#  -2.09812239e+00] Label: 1
# Coordinates: [-2.51663958 -4.00826625  0.01614427 -5.35117019 -1.29691934] Label: 1
# Coordinates: [ 0.52455056  9.81424404 -0.77972239 -1.96173763  0.45652874] Label: 2
# Coordinates: [-5.44074284 -3.94829049  1.54952381 -3.00437599 -0.42330211] Label: 1
# Coordinates: [-1.83727717 -0.91075812  3.09091537 -0.30652609 -2.13285574] Label: 1
# Coordinates: [ 2.28522149  0.37732402  3.34967503 -0.68543881 -2.23974747] Label: 0
# Coordinates: [-0.50197982 10.14260555  3.03068522  3.43148509  0.2740849 ] Label: 2
# Coordinates: [-2.44512774 -1.71763891 -3.963894    1.73355653 -1.9456639 ] Label: 1
# Coordinates: [ 1.65484808 -2.50159661 -2.15068084  0.62133107 -0.86970402] Label: 1
# Coordinates: [-1.2966785  -1.02037836 -2.8482321  -2.41068504  1.78526519] Label: 1
# Coordinates: [ 0.47727713 -2.40276642 -3.327447   -1.16189131  1.59845785] Label: 1
# Coordinates: [11.05162157  0.93047979  1.0119555  -3.65656625 -4.52048265] Label: 0
# Coordinates: [ 3.99482242 -0.04920704  3.67242338  1.47688151 -1.43831045] Label: 0
# Coordinates: [ 0.42882089 -3.52015099 -3.14295284 -1.19980606  7.09559828] Label: 1
# Coordinates: [ 3.99833846 -0.98747243  5.26686317 -2.08792265 -0.25307456] Label: 0
# Coordinates: [ 0.04173973 -1.95868993  4.51034369 -1.28760813  3.75175042] Label: 1
# Coordinates: [-7.94045313  0.83464083 -3.15570516  1.33585585 -1.14187857] Label: 1
# Coordinates: [-0.17049319 -2.74357814  2.38131019 -1.18949458  0.49800455] Label: 1
# Coordinates: [-6.55418492 -4.19348618 -2.43341527  1.15535267 -1.13012724] Label: 1
# Coordinates: [ 0.70493067 -0.9188707   1.64782948 -2.1972372   1.79455811] Label: 1
# Coordinates: [-1.94699531 -0.64817873 -1.0323967  -0.55806691  2.19897453] Label: 1
# Coordinates: [-1.65723238 -4.29742425 -2.25565386 -3.049217   -0.0673527 ] Label: 1
# Coordinates: [ 7.95975766  0.75208286 -0.95180614  2.30541788  2.31511137] Label: 0
# Coordinates: [ 4.58454422 -0.70356563 -2.2219708   0.12588391  0.78025975] Label: 0
# Coordinates: [-2.92223728 -0.54437413  0.45019812  1.64023534 -2.26312981] Label: 1
# Coordinates: [-3.07945769  1.49895709  4.95703172  4.61123387 -0.58302343] Label: 1
# Coordinates: [-2.42160176  1.63247341  3.35420923  4.63694735  3.27057698] Label: 1
# Coordinates: [-2.80551876 -1.40711362  4.80885793 -1.41053289 -0.64410948] Label: 1
# Coordinates: [ 5.35018008  4.73735874  4.25246803  4.75269506 -2.23523252] Label: 0
# Coordinates: [-0.68252238  0.53547765 -3.64630189  1.54658397  1.22643648] Label: 1
# Coordinates: [ 1.29077318 -2.17788448 -1.35018312  0.14196546  1.71015132] Label: 1
# Coordinates: [-3.24310225  5.79475596 -1.56133788 -0.3517051   0.35992027] Label: 2
# Coordinates: [ 1.24375759 -1.00099628  3.53903008 -3.28769451  0.34293943] Label: 1
# Coordinates: [ 7.77532786  1.36017166  0.20938175  1.13647126 -1.66246807] Label: 0
# Coordinates: [ 4.6095353  -2.40421336 -6.07919539  1.56681128  3.96870244] Label: 0
# Coordinates: [-3.68292181  2.97716583 -2.24728824  2.71876116 -0.70870725] Label: 1
# Coordinates: [ 1.71022069 -2.83481538  0.64927056 -3.22137886 -1.09392419] Label: 1
# Coordinates: [-1.36416323 -0.41993248 -0.6992059  -0.23126009  2.99587473] Label: 1
# Coordinates: [ 0.81923828 -0.16317834  0.36169954  1.84323509  1.94339737] Label: 1
# Coordinates: [-3.44032483  3.39557917 -1.21247466 -0.23620209 -1.0752816 ] Label: 1
# Coordinates: [-3.86710154 -4.01845111  0.16196373 -2.45726348 -2.12555429] Label: 1
# Coordinates: [-5.19531233 -2.86952686  0.54580167 -0.06557161  0.99064683] Label: 1
# Coordinates: [ 0.63096439 -1.61687589 -6.05205983  3.60768635 -0.99215871] Label: 1
# Coordinates: [-4.98677599  4.48337961 -2.4143869   1.90745085  1.70765125] Label: 1
# Coordinates: [ 2.57320596 -0.54755726 -4.13172104  2.16728208  0.89314781] Label: 0
# Coordinates: [ 1.83507001 -1.75979475  4.98387768 -2.95869591 -0.66330638] Label: 1
# Coordinates: [-4.22885652 -5.49212124 -0.71968062 -4.68608443 -2.15129368] Label: 1
# Coordinates: [-5.46107772 -1.54608841  3.27844021  4.77670446  0.17741358] Label: 1
# Coordinates: [ 0.71745422  0.29504381 -2.88644991  4.37080896 -4.58965335] Label: 1
# Coordinates: [-0.16863319 -2.88444051  2.96018074 -2.72253424  0.0940363 ] Label: 1
# Coordinates: [ 2.53887058 -0.49236767  4.68806373 -2.28809529  1.99154032] Label: 0
# Coordinates: [-5.28536095 -3.2106991  -2.94565302  0.12581096  0.29975826] Label: 1
# Coordinates: [ 8.680711    4.73623773  0.60855775  0.93379282 -1.8426676 ] Label: 0
# Coordinates: [ 3.542416   -1.30485324  4.08826799 -1.90996923 -1.24683529] Label: 0
# Coordinates: [-9.31118415 11.93445691 -1.75788064 -5.52142691  0.73743525] Label: 2
# Coordinates: [-4.19518355 -0.97960976  7.95772126  1.31747019  0.23212933] Label: 1
# Coordinates: [ 2.89555515 -2.52069446 -2.115353   -1.50878707 -3.96063648] Label: 0
# Coordinates: [ 0.94903463 -1.00425171 -5.15943693 -0.12435803 -4.06040357] Label: 1
# Coordinates: [-2.69642794 -3.51062366 -1.65483281 -0.12712282 -2.3092816 ] Label: 1
# Coordinates: [-1.82559661 -2.83941539  1.0479152   0.29040237 -0.30466805] Label: 1
# Coordinates: [ 1.42468444 -2.4428308   3.66895647 -4.16249937 -0.92723476] Label: 1
# Coordinates: [ 1.57003512 -2.46951505 -1.49138893 -0.31826766  1.15846639] Label: 1
# Coordinates: [ 3.33226455  9.41784499  2.41145294  0.57254622 -1.05083399] Label: 2
# Coordinates: [-1.34491046 -2.61452854 -0.51356481  0.14882401  1.79963954] Label: 1
# Coordinates: [-9.76784854 14.30156698  0.47776464 -4.34385222 -0.45685275] Label: 2
# Coordinates: [ 5.07157344  1.13103064  3.56514343  2.81535159 -2.68751428] Label: 0
# Coordinates: [-1.41963021 -1.65774999 -3.64806793 -0.30116363 -0.87040949] Label: 1
# Coordinates: [ 0.83364347 -1.9694886  -3.38345536  0.55210997 -0.25249859] Label: 1
# Coordinates: [-1.48403874 -0.77639089  7.23111804 -1.6778687  -1.23115408] Label: 1
# Coordinates: [-2.68995437  3.24554639  1.10069713  2.23983494  0.24680865] Label: 1
# Coordinates: [-8.08742559 -2.54747928  5.04898939  0.93085065 -0.02994102] Label: 1
# Coordinates: [ 0.42859198 -2.26404908  3.94780426 -3.62188514 -2.41309239] Label: 1
# Coordinates: [ 4.54980222  0.80460084 -1.41436261  0.84373527  1.20761109] Label: 0
# Coordinates: [-4.18853873 -2.55038679  0.59934829  4.00016542 -1.17375442] Label: 1
# Coordinates: [-5.90080936 -3.81500968  3.04432534 -0.76530601 -0.41548536] Label: 1
# Coordinates: [-2.80515982  0.24153447  3.69358596  6.68287376 -2.07215409] Label: 1
# Coordinates: [-5.38598749 -3.50359503  2.47609035 -0.32268686 -0.50360763] Label: 1
# Coordinates: [ 2.63126196 -0.16442068  0.13259522  1.91740027  1.0895617 ] Label: 0
# Coordinates: [ 1.96814282 -1.96788464  3.83152527 -2.64218016 -0.48710034] Label: 1
# Coordinates: [-2.03308257 -5.13793272 -0.56501222 -4.43096957 -0.5966703 ] Label: 1
# Coordinates: [-5.42498854 12.87230679 -2.85312654 -6.44520687  3.24004014] Label: 2
# Coordinates: [-5.64848271  0.78301367 -1.12540532  0.58464213  0.11490831] Label: 1
# Coordinates: [11.92569753  1.3696502   2.87351702 -0.67248509 -3.47457487] Label: 0
# Coordinates: [ 0.99624572 -2.56503515 -0.60541192 -1.04193313 -0.91262135] Label: 1
# Coordinates: [ 0.77659644 -2.16852693 -1.5798449  -0.31847537 -0.43240934] Label: 1
# Coordinates: [-4.11905267 -4.46107485 -1.17788208 -3.77082584  0.32964955] Label: 1
# Coordinates: [-6.51945155 11.03179148 -0.05846251 -1.59622192  1.92316222] Label: 2
# Coordinates: [-0.17018125 -1.8696151   1.04066222 -0.46509358 -1.8017835 ] Label: 1
# Coordinates: [ 2.07247284 -3.03480793 -3.07153366  0.36900327  1.45108243] Label: 1
# Coordinates: [ 6.54784068 -0.51335455 -3.63324357  4.36282996  2.98853724] Label: 0
# Coordinates: [-3.70093945 -4.69955547 -3.65384751 -2.7930637   0.96970553] Label: 1
# Coordinates: [-0.63141501 -1.76801353  3.94608777 -1.40440014  0.24524621] Label: 1
# Coordinates: [-6.53345655 -2.0459087   2.17435328 -2.91254429 -0.71491025] Label: 1
# Coordinates: [-6.69995683  3.47633492  1.25149963  3.85790729 -2.42074946] Label: 1
# Coordinates: [4.17368845 1.80389562 4.26391198 1.01752739 1.56080398] Label: 0
# Coordinates: [ 0.02198634  1.16730363 -0.5001599   0.17900379 -0.56546448] Label: 1
# Coordinates: [ 4.511791   -0.42800276 -0.74717046  0.6709016  -6.36783825] Label: 0
# Coordinates: [-2.10303241 -1.79014416  4.31807863 -0.82531421 -1.52210277] Label: 1
# Coordinates: [ 3.20735538 -1.24387336 -0.86365873 -3.05087791 -1.91694824] Label: 0
# Coordinates: [ 2.43328738 -1.81706243 -1.15883981 -0.20945291 -1.44761149] Label: 0
# Coordinates: [-5.95492513 -3.41060586  4.13704356 -2.14161835 -0.64129229] Label: 1
# Coordinates: [-0.24285027 -1.23661764  4.60996809 -1.00216905  2.28878758] Label: 1
# Coordinates: [-1.71593912  0.12601672 -2.15867443  1.66490359  0.0438341 ] Label: 1
# Coordinates: [-2.91603743 -3.37478393  3.16459951 -3.45052034  2.15611592] Label: 1
# Coordinates: [ 7.27213834  0.39670222  4.67204521 -0.85825408 -1.40551883] Label: 0
# Coordinates: [-1.60971014  0.81016795  0.75437425  0.97752424  0.48029845] Label: 1
# Coordinates: [-2.12294557 -2.34363695  2.31782046 -2.66375298 -2.08609397] Label: 1
# Coordinates: [-4.15804107 -5.2320349  -1.65902569 -4.12041471  0.36038546] Label: 1
# Coordinates: [ 9.79077885 -0.51725458 -2.21854317 -2.07987225 -2.95344221] Label: 0
# Coordinates: [ 2.15465628 -2.49636513 -3.83254709 -0.42586714  2.89062537] Label: 1
# Coordinates: [-1.07622269 -1.63315224  0.76662591 -4.31033621 -0.06077235] Label: 1
# Coordinates: [ 4.64516993 13.40074643  4.30621826 -3.25678271 -7.15723179] Label: 2
# Coordinates: [ 6.98466511 -0.32613738 -3.58728634  1.14466802 -7.17435402] Label: 0
# Coordinates: [ 3.27581568 -0.82161428 -3.63640074  1.02983728  4.72538527] Label: 0
# Coordinates: [-5.64917172  2.935765   -1.91480988 -0.47070894 -0.05374095] Label: 1
# Coordinates: [10.7854799  -0.21072912  2.78433984 -5.04846621 -1.39275187] Label: 0
# Coordinates: [ 4.44793504  1.01368858  3.68949913  4.94926833 -3.6330671 ] Label: 0
# Coordinates: [-0.24882199 -2.46668362 -2.8269971  -0.74377443 -1.38478208] Label: 1
# Coordinates: [-4.87229741 -3.42597245  2.02841158 -4.75293433  0.43227693] Label: 1
# Coordinates: [-3.56479728 -0.93143907  2.80192036  2.53337553  0.79318202] Label: 1
# Coordinates: [ 2.54800712  0.47227002  3.11056667 -0.26704968  1.25588266] Label: 0
# Coordinates: [-4.38321269 -3.8699328   0.09957444 -1.76065335 -1.18021044] Label: 1
# Coordinates: [-7.1672656  -0.29290597  2.34820973  3.8795546  -0.22956707] Label: 1
# Coordinates: [-6.09860642 -3.36056943  0.9539789   1.47758475  2.23035955] Label: 1
# Coordinates: [-4.31151663 -5.61845808 -0.34962881 -5.12700531 -1.60408489] Label: 1
# Coordinates: [ 4.75625908 -0.63638623 -1.2150292   2.47393298  1.05826031] Label: 0
# Coordinates: [-1.58669329  0.53077401 -4.30492537  0.95368443  2.74971792] Label: 1
# Coordinates: [ 0.6581525  -1.7228489   5.49466152 -2.21672094  0.64522554] Label: 1
# Coordinates: [-1.02896557  4.93762479 -1.15583801  3.49653127 -1.02936356] Label: 1
# Coordinates: [ 0.32411862 -2.55575763 -2.85610222 -0.22416347 -1.2466075 ] Label: 1
# Coordinates: [-4.37360892 -3.5135938  -1.9079741  -2.27634775 -0.32703725] Label: 1
# Coordinates: [ 4.10601     0.06562471  2.28888313  1.63259655 -0.0739425 ] Label: 0
# Coordinates: [ 2.34241634 -0.98796993 -4.65722714 -0.77495852  4.38600425] Label: 0
# Coordinates: [-0.9551879   3.75885964  0.36602146  2.68940232 -0.57188046] Label: 1
# Coordinates: [-4.01081325 -0.07929565 -6.32117142  3.38519396 -0.61244717] Label: 1
# Coordinates: [ 0.47455558 -3.11166988 -2.51244545 -1.45633425  2.45342161] Label: 1
# Coordinates: [ 5.99993859 -0.35443001 -1.7201526  -0.32062059 -3.99652789] Label: 0
# Coordinates: [-1.37050781 -1.35968149  6.52134767 -1.23251038  1.18584247] Label: 1
# Coordinates: [-1.74645187 -2.90415806 -0.79047095  2.20471386  0.26577457] Label: 1
# Coordinates: [ 2.47290748  0.826629   -0.1119183   0.78392232 -0.58865289] Label: 0
# Coordinates: [-7.5687998  -4.12687994 -1.81712546 -4.65636787 -0.57095903] Label: 1
# Coordinates: [ 0.70711981 -2.51180172 -1.24153728 -0.35803099 -1.52521366] Label: 1
# Coordinates: [ 4.35362499 -0.12899665  4.48391106 -0.0576345   3.20655049] Label: 0
# Coordinates: [ 5.12663214 -2.04539328 -2.26643161 -0.66242448  0.61536765] Label: 0
# Coordinates: [ 0.17381772 -3.69025809 -3.06102109 -2.12626219  2.09258893] Label: 1
# Coordinates: [-0.47586661 -2.63175876 -2.406379   -0.20829367  0.96329178] Label: 1
# Coordinates: [-6.08846095 -3.32689855  1.72375363 -3.89968179  0.35267443] Label: 1
# Coordinates: [-7.82270466  2.04097857 -1.7072183   3.18451818 -0.45598536] Label: 1
# Coordinates: [13.39763291  2.86410285  3.88935206  1.04745197  4.28522637] Label: 0
# Coordinates: [-8.29038446  0.03338131 -2.77465539  1.36075735  0.30088451] Label: 1
# Coordinates: [-4.57530426e+00 -2.34367145e+00  1.21391200e+00  3.29063292e-03
#  -4.72194706e-02] Label: 1
# Coordinates: [-3.65495845  0.20881862  3.36949001  1.70785312  1.8155933 ] Label: 1
# Coordinates: [ 5.39982128  0.03369043 -0.60645384  3.67372763  0.89404075] Label: 0
# Coordinates: [-3.53599821 -1.89845784  4.05028824  0.43928492  2.6435277 ] Label: 1
# Coordinates: [-4.69837073 -2.00620384  2.98754343 -1.07981619  0.33134157] Label: 1
# Coordinates: [ 1.06248633 -1.0099302  -3.19035369  0.47463945 -3.72690204] Label: 1
# Coordinates: [-1.76739133 -3.39189493  1.60147862 -3.6191075  -0.44557993] Label: 1
# Coordinates: [ 4.71376589 -0.30271624 -0.64805249  1.21435611  4.02934518] Label: 0
# Coordinates: [ 5.94229339 -0.44341673 -2.84797382 -1.04856502 -7.98059159] Label: 0
# Coordinates: [-1.37666499 14.22832815 -0.66444568  3.96370406 -1.80465914] Label: 2
# Coordinates: [ 1.24919281 -3.06854978 -5.2206435  -1.06650405  0.77896342] Label: 1
# Coordinates: [-6.23800263  1.90997766 -3.96700987 -2.29747451  3.6643154 ] Label: 1
# Coordinates: [ 4.04429374 -0.96579325 -4.69578499  0.93103924 -2.96126773] Label: 0
# Coordinates: [ 1.10837427  9.57658294  2.10246092  0.94892231 -1.20526656] Label: 2
# Coordinates: [-2.68436225  0.30512199  2.40097764  4.23477205  0.07519547] Label: 1
# Coordinates: [ 2.27810532 -0.75457695  0.29240077  6.35450729  0.09583819] Label: 0
# Coordinates: [ 1.50407345 -0.77626871 -2.46812893  3.66799294 -1.36765416] Label: 1
# Coordinates: [ 5.36312849 -0.55456976  0.56465257 -2.22028721 -7.30239621] Label: 0
# Coordinates: [ 0.41369277 -1.59242431 -2.17739139 -1.69360077  1.05197683] Label: 1
# Coordinates: [ 1.18169689  1.99620217  4.47962825  1.74254953 -3.88871343] Label: 1
# Coordinates: [-12.58790582   9.45804648  -3.2801873    2.80091306  -1.37937704] Label: 2
# Coordinates: [ 0.36770059  3.50035291 -2.96661003 -0.28866509 -2.51407085] Label: 1
# Coordinates: [-6.38753289 13.93456869 -1.17270846 -2.80195887 -2.08867855] Label: 2
# Coordinates: [ 1.96369068  0.46936254  5.82300772 -0.33286122 -2.48453368] Label: 0
# Coordinates: [-1.53336558 -3.9259168  -2.4417273  -1.91887293  0.52508914] Label: 1
# Coordinates: [ 1.46938936 -2.26014283 -3.61166796  2.12928835 -3.31182586] Label: 1
# Coordinates: [-1.37137529 14.2485097  -6.65176705 -2.12421324 -2.92940612] Label: 2
# Coordinates: [-0.69600219 -3.91943874 -0.04438437 -2.86686597 -0.0582065 ] Label: 1
# Coordinates: [-0.84007559  0.84329844  1.01073932  1.81450508 -1.47212821] Label: 1
# Coordinates: [-0.99505099 -2.94383504 -5.52508376  3.75156735 -0.10876272] Label: 1
# Coordinates: [-5.44067951 -2.79322667  6.16238157 -2.70407773  1.90151954] Label: 1
# Coordinates: [ 3.66754084 -2.62020895  0.5173105  -2.77502724 -0.11440967] Label: 0
# Coordinates: [5.33602976 1.6112879  3.71596101 0.90176808 2.5233553 ] Label: 0
# Coordinates: [ 1.87806824 -0.929166   -5.36671727  2.96084228 -0.25528812] Label: 1
# Coordinates: [ 5.4370671  -1.5921345  -1.42227032 -0.77449263  2.57241831] Label: 0
# Coordinates: [-5.09870486  2.05785704  4.10567668  2.43927335 -0.28405052] Label: 1
# Coordinates: [-4.14766036 -2.67037003  3.70941852 -1.68905417 -0.85540245] Label: 1
# Coordinates: [ 2.83642867 -1.10392738 -2.69501137  2.45845587  1.3225218 ] Label: 0
# Coordinates: [-1.16428201 -2.326738    2.81668414 -3.10986883 -0.04135618] Label: 1
# Coordinates: [-1.90423405 -3.92294236 -3.21690631  0.20797833  0.39454698] Label: 1
# Coordinates: [ 5.87403962  2.77075173  6.51260304 -1.78947601 -0.23285855] Label: 0
# Coordinates: [-0.69043699 -2.89676945 -4.6919908   1.64744018  1.33132687] Label: 1
# Coordinates: [ 1.46735081 -3.07714434  0.58318321 -2.40163518 -1.31936401] Label: 1
# Coordinates: [-10.78436372  13.78283469   0.29096532  -3.02425915   0.94244424] Label: 2
# Coordinates: [ 3.30928021 -1.71923805 -4.04652569  0.04245119  6.69351738] Label: 0
# Coordinates: [-2.06288627  0.69342343  0.49672676  6.85234196  0.7378458 ] Label: 1
# Coordinates: [-1.44549852 -2.84650096 -1.31236868 -0.88732855  3.05485117] Label: 1
# Coordinates: [-2.98554221 -1.60263768  2.15031795  1.46896177  0.63605529] Label: 1
# Coordinates: [-3.95812305 -1.19162327 -0.5180399  -0.36748897  2.71553536] Label: 1
# Coordinates: [-1.29372102  1.09726409  4.25365778  3.84988168 -0.12332159] Label: 1
# Coordinates: [ 2.8460322  -1.48648898  4.62997762 -2.69894442  0.58596474] Label: 0
# Coordinates: [ 9.08136142 -0.1378393  -2.47489661 -0.74751588  1.09272172] Label: 0
# Coordinates: [ 0.61822415 -1.56450847 -4.54868559 -1.61018708  2.65840668] Label: 1
# Coordinates: [-7.13845139 -3.49400094  0.31213402 -1.96251992 -2.23762046] Label: 1
# Coordinates: [-4.30465609 -0.46988703  1.71383319  4.64371299 -0.76696997] Label: 1
# Coordinates: [ 0.298179    0.98897997 -2.83200208  2.25097348  3.2302628 ] Label: 1
# Coordinates: [-0.98035582 -0.18791664  4.04273768 -1.36158055  0.59238993] Label: 1
# Coordinates: [ 2.51687788 -2.14300842 -1.90008887  0.56863337 -0.26315924] Label: 0
# Coordinates: [-7.43224358 15.77820063 -0.07481243 -5.5987581   0.31507318] Label: 2
# Coordinates: [-0.25897887  3.07915249 -2.37940339 -2.73941323 -1.75390048] Label: 1
# Coordinates: [-6.30165736  6.43697866  2.9765123   6.15122504  0.12024391] Label: 2
# Coordinates: [ 2.67805822  1.68486816 -0.18810686  0.57330248  0.87903835] Label: 0
# Coordinates: [ 6.93321659 -0.5298602   5.23604175 -4.6860932   0.04751282] Label: 0
# Coordinates: [ 2.20064898  3.67444991  3.33991566  2.13591961 -0.16889023] Label: 0
# Coordinates: [ 0.80016725  8.02233903 -5.90424037  2.58201414 -1.34869381] Label: 2
# Coordinates: [ 1.1197631  -1.65914764  5.00098977 -1.59739445  2.36842547] Label: 1
# Coordinates: [-3.8860845  -4.01495745 -3.04525266  1.4787762   0.78053302] Label: 1
# Coordinates: [9.48018314 1.46783102 2.36803359 1.91232728 1.06824167] Label: 0
# Coordinates: [-2.71827018  5.29532838  2.45157186 -0.09526308 -1.49175634] Label: 1
# Coordinates: [-4.86741582 -5.13546061 -0.61974363 -4.42078417 -2.32945841] Label: 1
# Coordinates: [-1.80683984 -1.13599809  4.18812873 -0.17695278  0.87071515] Label: 1
# Coordinates: [-2.62819935  0.27544596 -0.09032937  2.34892665  0.45712691] Label: 1
# Coordinates: [-0.93679864 -3.38909397 -4.11138551  0.1678538   3.97224895] Label: 1
# Coordinates: [-4.71212647 -3.38702292 -3.04245012  0.24288746 -1.3320309 ] Label: 1
# Coordinates: [-5.78057587  0.69707071  6.47555424  4.05873565 -0.31666709] Label: 1
# Coordinates: [-7.36037936 14.04336684  1.77098927 -3.48854234  0.92530596] Label: 2
# Coordinates: [-4.69074933 -4.32549099 -0.07329383  0.56017436 -1.87387787] Label: 1
# Coordinates: [ 6.65168811  0.15930426  0.39300504  1.55127751 -0.99464446] Label: 0
# Coordinates: [-10.55007846  13.65611504  -0.97202245  -2.86761063   0.75856226] Label: 2
# Coordinates: [ 7.9542866  -0.99580488 -2.40859233  1.12310822 -1.50314439] Label: 0
# Coordinates: [ 2.6310398  -0.5286628  -3.16707708  3.4205461  -5.03925315] Label: 0
# Coordinates: [-4.08491226 -1.38834863  5.63538604  0.71402931 -0.52281446] Label: 1
# Coordinates: [10.90646391  0.10156541 -2.87044967 -1.60055581  4.0526888 ] Label: 0
# Coordinates: [ 5.36801695 -2.15722534  1.29057329 -4.00490033  0.20836285] Label: 0
# Coordinates: [ 5.85246359  0.05294647  4.85004344  0.30649482 -3.33920849] Label: 0
# Coordinates: [ 1.04627047 -3.24596271 -3.15014125 -0.55411661  2.9600689 ] Label: 1
# Coordinates: [-1.16409868 -0.35087402  2.5441407  -0.43092406  1.57547902] Label: 1
# Coordinates: [11.90710693 -0.64185759 -2.73069031  0.02041118  9.15148232] Label: 0
# Coordinates: [ 7.64196793 -0.86132088 -3.95681453  1.00863647 -3.26969374] Label: 0
# Coordinates: [-4.0990499  -4.12289853 -2.62754397 -0.55066232  0.14260058] Label: 1
# Coordinates: [ 2.45814129 -1.93973025 -3.78019137  0.91005578 -0.50610111] Label: 0
# Coordinates: [-0.62654821 -2.87426332 -4.19449421 -2.16552477  1.69381407] Label: 1
# Coordinates: [ 5.06223521 -2.02249079  1.36545153 -3.97538909 -4.09862801] Label: 0
# Coordinates: [-3.32170729  3.664504   -0.34025224  3.58845586 -1.13937872] Label: 1
# Coordinates: [ 6.53267496  2.4433451   4.89994922  4.48786696 -2.06254562] Label: 0
# Coordinates: [-1.22204524 -2.57493115  0.51018774 -0.09014908 -1.31515609] Label: 1
# Coordinates: [ 4.77986249  0.78399084  1.86196436  1.43024811 -2.37032931] Label: 0
# Coordinates: [ 2.04936255 -1.0590037   0.32458362  0.26171729 -3.41998033] Label: 0
# Coordinates: [ 0.55741703 -1.00029767 -5.92092172  1.73575366 -1.27461451] Label: 1
# Coordinates: [ 1.57107379 -0.21972296  2.76329039  1.68109333  0.36958622] Label: 1
# Coordinates: [ 0.20305577 -3.34187246  0.49604043 -5.60409643 -0.80320705] Label: 1
# Coordinates: [-2.24282084 12.69233636  4.26345187 -1.2162473  -0.65953762] Label: 2
# Coordinates: [-2.08690889 -2.54475409 -3.07351752  0.0363757  -0.77306406] Label: 1
# Coordinates: [ 0.46082932 -3.23416511 -0.69896519 -2.20542501 -1.88882413] Label: 1
# Coordinates: [ 1.43840216 -2.62405554  1.23715188 -2.6597298   0.10957888] Label: 1
# Coordinates: [ 1.16568341 -2.83543276 -0.68541663 -2.56660228  1.29473673] Label: 1
# Coordinates: [ 1.7773071  -2.49431522 -4.29230727  0.95344667  2.59422507] Label: 1
# Coordinates: [-0.24127877 -2.726349   -2.21742434 -0.04463962  1.79620614] Label: 1
# Coordinates: [ 0.09662503  0.77547848  3.52770254  3.49654899 -2.36120488] Label: 1
# Coordinates: [-1.3606052  -1.54349339  4.49083805 -0.54628864 -2.03426413] Label: 1
# Coordinates: [-1.59972083 -1.68994317 -3.93640943  3.71344904 -1.47639751] Label: 1
# Coordinates: [ 14.654373     1.53430577   1.75806632  -1.24354269 -10.41740045] Label: 0
# Coordinates: [-0.13272492 -1.93312321  2.62352906 -1.63040051 -0.7176677 ] Label: 1
# Coordinates: [ 3.13325435 -3.29745518 -1.72453141 -4.292871   -1.92929389] Label: 0
# Coordinates: [ 5.91630898 -0.99770355 -4.19502512  2.49728298 -3.16989868] Label: 0
# Coordinates: [ 1.02947571  8.03600798 -3.4267501   1.82221097  3.3358576 ] Label: 2
# Coordinates: [11.4756368   0.80394549 -4.42743644  1.10227436 -3.72589062] Label: 0
# Coordinates: [ 4.4398784  -1.85832469 -2.34021576 -1.74610365  3.58442005] Label: 0
# Coordinates: [ 4.76386032 -0.70299938 -1.73013247  2.07276871  1.48771673] Label: 0
# Coordinates: [-1.36222588 -2.17409754 -0.18493881  2.05364483  0.37442724] Label: 1
# Coordinates: [ 3.45161354 -0.39909812  0.88096169  2.16187276  0.89020817] Label: 0
# Coordinates: [-4.40513072 -2.89547049 -2.46756997  1.00489159  1.0028521 ] Label: 1
# Coordinates: [-1.44486969 -2.98794951  2.70939922 -3.82406307 -1.00818012] Label: 1
# Coordinates: [ 1.43848075  0.48129438 -0.97861864  0.12814708  1.14928496] Label: 1
# Coordinates: [ 6.26909824  5.1200078  -1.77799164  0.72560291 -0.23663781] Label: 0
# Coordinates: [-4.18848999 -2.95015533  5.86805875 -2.22680196  0.64863728] Label: 1
# Coordinates: [-5.83702946 -2.59654176  6.32127805 -2.40348558  1.6122442 ] Label: 1
# Coordinates: [-1.70727156 -2.34789231 -4.43654316  1.90960059 -3.39208326] Label: 1
# Coordinates: [ 4.49872455  2.95092795  2.56702555  3.9682178  -1.66922734] Label: 0
# Coordinates: [-0.46353415  2.06111853  1.46314167  1.38617177 -2.52278005] Label: 1
# Coordinates: [-6.42961225  0.13274841  2.38279865  4.53890517  1.72707082] Label: 1
# Coordinates: [ 0.03539393 -1.78264986 -1.22919543  3.87274602 -0.07725058] Label: 1
# Coordinates: [-2.78392976 -3.30989724 -0.5811227  -0.31070861 -0.88459669] Label: 1
# Coordinates: [-1.31788412 -1.96583198 -3.44810336 -2.45488744 -0.2496292 ] Label: 1
# Coordinates: [2.10349507 0.73653524 3.22067307 4.49154168 1.50064769] Label: 0
# Coordinates: [ 7.73810648  2.40151262  3.8687643  -1.23724315 -3.88500597] Label: 0
# Coordinates: [ 0.10559294 -1.36696919 -3.44944842  1.6050504  -1.58567529] Label: 1
# Coordinates: [ 1.08915638  0.25453253 -2.82392821  0.4317883   1.01765618] Label: 1
# Coordinates: [ 3.3794497  -2.72154217 -3.35253187 -1.41442038  1.78517842] Label: 0
# Coordinates: [ 9.18822856 -0.82077507 -2.19431593  0.72438636 -0.32255563] Label: 0
# Coordinates: [-4.64309713  2.27184961 -3.29257399  2.90977557  0.18000806] Label: 1
# Coordinates: [-0.15213044 -4.31053755 -0.96519085 -3.8717374   0.38213041] Label: 1
# Coordinates: [-3.66026655 11.82096762 -0.74595003 -5.02836166  0.13493155] Label: 2
# Coordinates: [ 8.00218356 -0.72677918 -3.65517117  0.37418885  0.38500755] Label: 0
# Coordinates: [ 4.47831217 -0.57455629  3.01624529 -1.18607454 -5.6901428 ] Label: 0
# Coordinates: [-2.62444457  1.17529253  3.24721448  2.72003684  1.01542633] Label: 1
# Coordinates: [-3.53884274 -4.41570348 -2.34903448 -1.97677822 -1.07243363] Label: 1
# Coordinates: [-1.44688731 -2.5874095  -1.84217986  0.20750415  0.44295766] Label: 1
# Coordinates: [-0.70720108 -1.82328173 -4.73064158  1.12331784  0.8179776 ] Label: 1
# Coordinates: [-0.49975699 -2.71941877 -2.00989862  2.80353343  0.08082318] Label: 1
# Coordinates: [4.21862667 0.41748245 0.33961008 0.51618162 2.9692476 ] Label: 0
# Coordinates: [-1.5999693  -3.73446568  1.44994734 -2.49816037 -1.47047624] Label: 1
# Coordinates: [-1.51518129 -1.36779231  0.312846    5.4470045   0.2161193 ] Label: 1
# Coordinates: [ 0.93465342  2.60200211 -4.33668011  2.89157145 -0.31804281] Label: 1
# Coordinates: [-5.41957842 -3.7707383   1.93311496 -2.58835106 -0.7452279 ] Label: 1
# Coordinates: [-2.78334817 -1.71385742  2.86817403  1.08203708 -0.0633447 ] Label: 1
# Coordinates: [3.02496989 3.44996235 1.42624509 4.37440517 1.01925593] Label: 0
# Coordinates: [-4.44347892 -3.72721991  3.13545794 -5.55731185 -0.09810783] Label: 1
# Coordinates: [ 5.95487839 -1.80280461 -2.65006923 -0.82712304 -0.16583815] Label: 0
# Coordinates: [ 1.52398671 -1.12146683 -1.37227729  4.26678962  2.09152459] Label: 1
# Coordinates: [ 9.00936551 -0.72704666 -1.89657785 -1.28580738 -3.25261521] Label: 0
# Coordinates: [13.1068161   0.53601144 -1.38488107 -2.75671741  4.77394796] Label: 0
# Coordinates: [ 6.09144442  0.05290491 -2.64545661  1.48796401  0.43292805] Label: 0
# Coordinates: [-2.19827653 -0.84043628  3.52557599  3.74260036 -0.86131245] Label: 1
# Coordinates: [-0.35701187 -2.9088166  -0.11652857 -3.44337648 -0.29408705] Label: 1
# Coordinates: [ 0.49491086 -1.04808805 -3.97004909 -0.58743397 -1.08421013] Label: 1
# Coordinates: [-2.94352243 -3.7689995  -1.57173682 -2.29449504  1.09595523] Label: 1
# Coordinates: [ 5.47459951 -1.1623492  -1.20820205 -0.39227031 -0.89461086] Label: 0
# Coordinates: [0.38288775 0.77500287 4.80931075 3.17447511 0.38654089] Label: 1
# Coordinates: [ 3.70634019 -0.78983859 -1.11123474 -2.24758493  1.55060922] Label: 0
# Coordinates: [-2.16457204 -1.29248056 -4.86115345  1.02170806  0.74286457] Label: 1
# Coordinates: [-2.50231806 -2.62700435 -3.38430101  2.13493301  0.76770563] Label: 1
# Coordinates: [-3.25561675 -1.62490915  0.66678391  4.93888769 -0.40629524] Label: 1
# Coordinates: [ 8.24562228  1.95839361 -2.4143489  -0.90854263 -2.04022807] Label: 0
# Coordinates: [-2.07398137  9.27592365 -1.69391695 -3.79597817 -1.20614207] Label: 2
# Coordinates: [ 0.15064054 -1.45529789  2.43513427 -0.94662573  0.94205206] Label: 1
# Coordinates: [ 5.55785263 11.79950584 -3.58784877 -5.3357433   3.6528491 ] Label: 2
# Coordinates: [-2.07519407 -2.66690053 -2.61474881  2.24984572 -1.34568886] Label: 1
# Coordinates: [ 6.13552963 -0.29237022  3.97314456 -1.22967301 -0.77525956] Label: 0
# Coordinates: [-3.06645487 -2.15091243 -3.94710476  1.29842252 -1.86765926] Label: 1
# Coordinates: [-0.33079398  2.91421458 -0.75934854  5.94323945  3.80042728] Label: 1
# Coordinates: [-4.23943493  0.67663349 -3.20778585  0.13648605  0.09129569] Label: 1
# Coordinates: [-1.59100236 -1.06931284  6.849367   -0.99221876  4.49825697] Label: 1
# Coordinates: [1.58048178 2.95896867 0.7939553  3.36503925 0.08097523] Label: 0
# Coordinates: [ 0.46178835 -0.16917262 -0.41906441  3.482588   -0.73498795] Label: 1
# Coordinates: [-6.53051243 -3.60279317  3.56731535 -1.1114533   0.2906981 ] Label: 1
# Coordinates: [ 0.71488521 -0.51260725 -1.17791303  0.36035531 -3.59415424] Label: 1
# Coordinates: [ 6.48940458 -1.60356206 -0.71641236 -2.38913373  0.82254205] Label: 0
# Coordinates: [-6.44740502 -2.89971877 -1.64760819  4.54696876 -1.27324296] Label: 1
# Coordinates: [-2.47404925 -2.29554959  4.06458272 -1.03418133 -0.63225839] Label: 1
# Coordinates: [-5.92743524 -2.83346078  4.02520723 -0.99924241  0.54565644] Label: 1
# Coordinates: [ 8.97378007  0.40859572  0.44811439  1.07885287 -2.87840854] Label: 0
# Coordinates: [ 2.00496108  0.32758118 -2.34340644 -0.47918157 -3.69351905] Label: 0
# Coordinates: [-2.56850607 -2.61802652  2.93744544 -1.13395768 -1.80324816] Label: 1
# Coordinates: [ 3.23308039 -0.61736007  3.76251595 -0.03723629  1.21127781] Label: 0
# Coordinates: [ 4.09487804 -0.89721571  5.32784109 -4.6000786   0.93655688] Label: 0
# Coordinates: [-5.11247798 -0.98000777  5.64797954 -3.79071493  1.01506145] Label: 1
# Coordinates: [-3.51769236 -2.14204331 -4.59405307  0.30459339 -0.85648808] Label: 1
# Coordinates: [-3.31855187 -2.08387815  5.55404229 -0.46472474 -1.12005275] Label: 1
# Coordinates: [-4.50092253 15.99323526  2.36217536 -5.28984771 -0.09905424] Label: 2
# Coordinates: [ 4.01178797 -0.34810265 -3.76031178 -1.18176067  0.05231696] Label: 0
# Coordinates: [ 3.09868545 -2.79160639 -1.4740447  -2.08258438 -0.47782623] Label: 0
# Coordinates: [-2.95902961 -3.83847003 -2.99463675 -0.05231216  2.93695665] Label: 1
# Coordinates: [ 0.42723242 -2.27856331 -5.37033485  1.57728349 -0.57163305] Label: 1
# Coordinates: [-2.3878969  -4.15491453 -1.37816713 -1.63882669  1.15446172] Label: 1
# Coordinates: [-1.97561683 -3.26552999 -2.95084048  0.40977281 -1.26983385] Label: 1
# Coordinates: [ 0.27972875  3.75409075 -4.15662212  0.06692465 -1.4219554 ] Label: 1
# Coordinates: [-3.94303636 -1.10781675  6.5438128   0.41173572 -1.47364909] Label: 1
# Coordinates: [ 4.71519334  0.10690037  3.21327608 -1.41350693  0.43914319] Label: 0
# Coordinates: [-3.35267598 -1.67629109 -0.90211286 -0.7494268   0.18036239] Label: 1
# Coordinates: [ 2.32231766  1.32743092  5.78907304 -0.0728812  -0.15848713] Label: 0
# Coordinates: [-7.96289556  0.92277651 -1.11672931 -0.17619906 -0.19979309] Label: 1
# Coordinates: [-2.30638954 -3.43272891 -3.07691438 -0.48196332 -2.08297709] Label: 1
# Coordinates: [-1.03665476 -1.66334104 -0.90312503  0.44183681  1.56612681] Label: 1
# Coordinates: [ 0.05401931 -1.40338301  3.55785053 -2.35101359  3.3836222 ] Label: 1
# Coordinates: [-0.75689906  1.82347331 -2.71793739  0.46506598  1.63151011] Label: 1
# Coordinates: [10.04014614  0.07594137  2.55559581 -4.9390467   0.13935001] Label: 0
# Coordinates: [ 6.94034327 -0.36093417  1.4297502  -0.65737339 -0.23012909] Label: 0
# Coordinates: [-0.14011332  0.04990935 -0.49684446  1.60683179  1.51106421] Label: 1
# Coordinates: [ 2.56244061 -2.59430309 -2.46481245 -1.20576406 -0.81511152] Label: 0
# Coordinates: [-4.30355395 -2.78014155  1.46909694  0.88838443 -0.64692772] Label: 1
# Coordinates: [ 1.96464716  0.17930045 -1.89396933  2.00447114  4.99397623] Label: 1
# Coordinates: [-3.83603971 -3.5179389   0.05264531 -1.60809808 -1.26253443] Label: 1
# Coordinates: [-8.84274637 13.25179716  0.35528349 -4.93168056  0.61905257] Label: 2
# ...
# Coordinates: [-5.04453598  0.11189176  0.81723713  0.68459361 -0.45983933] Label: 1
# Coordinates: [ 0.55457018 -3.49254482 -1.25476528 -3.0493703  -2.80395379] Label: 1
# Coordinates: [ 0.0211596  -0.94185267 -4.86926271  2.47315956  0.73344227] Label: 1
# Coordinates: [ 5.28488226 -0.37968906 -3.19360411  2.93630954 -1.54202353] Label: 0
# Coordinates: [ 0.24951791 -0.91025675 -0.69366449  3.23010168  0.10623132] Label: 1
# Coordinates: [ 6.65722051 -2.48218602 -0.00698735 -3.71650561 -1.42517033] Label: 0
# Coordinates: [5.77820446 4.28806839 4.29554176 0.54250111 0.5991626 ] Label: 0
# Coordinates: [ 0.70556272 -2.51261966  0.95573958 -1.6182073  -0.2697437 ] Label: 1
# Coordinates: [ 3.01330427 -0.84194325 -4.10772831 -0.62808706 -0.73891037] Label: 0
# Coordinates: [-2.96283271 -3.32953408  2.93579227 -5.83008192  3.1307441 ] Label: 1
# Coordinates: [ 2.47648503  0.99944146 -3.9629761   1.15904703  1.70686564] Label: 0
# Coordinates: [ 3.91739932  2.05833482 -2.25626249  7.10695841 -4.83841064] Label: 0
# Coordinates: [-3.53993414 -2.98349716  0.21845669 -3.49937559 -1.83525144] Label: 1
# Coordinates: [-3.51802576  5.40603191  1.92784183 -1.14408639  5.06187824] Label: 2
# Coordinates: [6.51014833 2.92380408 0.88426749 6.48940971 0.47670835] Label: 0
# Coordinates: [ 1.79220257  0.68043956 -3.92936486 -0.25579898  1.80419747] Label: 1
# Coordinates: [-3.33622647 -3.17892522 -2.56589862  2.46832822 -0.04749406] Label: 1
# Coordinates: [ 2.08185272 -2.9120531  -4.61366617 -0.42905088  4.58350293] Label: 1
# Coordinates: [-3.76581467 -2.26049454  7.72190855 -4.30542572  0.5742455 ] Label: 1
# Coordinates: [-5.90375107  7.29630791 -2.97852465  0.58891182  0.87544336] Label: 2
# Coordinates: [ 0.91888853 -2.91494943 -0.95072075 -1.47137096 -0.99891073] Label: 1
# Coordinates: [-3.98560976 -2.94070782  1.66156492 -0.91836499  0.84556901] Label: 1
# Coordinates: [10.59711942 18.13766362 -3.0110914  -3.96338658 -5.79327141] Label: 2
# Coordinates: [-2.8606336  -1.87093658 -3.17321996  0.20886794 -1.87096875] Label: 1
# Coordinates: [ 2.98571183 -3.90085734 -0.9171186  -5.43991847  2.13360723] Label: 0
# Coordinates: [ 7.50651179  0.03105655 -3.27507884  1.53507204 -2.4023603 ] Label: 0
# Coordinates: [ 2.44477211 -2.62257501 -1.54567891  0.6522925  -0.21197253] Label: 1
# Coordinates: [ 3.64114474  5.36223376 -1.34509574  1.3153656   0.54697861] Label: 0
# Coordinates: [-6.1904286   8.64540782 -2.34675259 -4.72010686  5.19212156] Label: 2
# Coordinates: [-4.67700607 15.82660821 -1.17030904 -1.79705457 -0.24239365] Label: 2
# Coordinates: [-2.75606963 -5.49849355 -4.30673333 -3.3518852   1.32873128] Label: 1
# Coordinates: [-1.09175793  4.28275417  2.4421159   0.7554727   0.4780829 ] Label: 1
# Coordinates: [ 7.07765092 -0.82742696 -1.96022068 -0.80391142  1.42042084] Label: 0
# Coordinates: [ 2.18111227 -0.9595348   2.09965041 -0.43859811 -2.79430027] Label: 0
# Coordinates: [-0.69808128 -3.36543431 -3.55351553  2.25808828  0.73515064] Label: 1
# Coordinates: [1.69140476 0.87511741 0.94125891 1.37729978 0.80185449] Label: 1
# Coordinates: [-0.24163022 -2.7009131   3.13496406 -2.7312727   0.32218181] Label: 1
# Coordinates: [20.76298816  2.38585904 -2.69385411 -1.68644866 -7.69068193] Label: 0
# Coordinates: [ 1.45253702 14.0328868  -5.83662913 -6.86397366 -4.12867128] Label: 2
# Coordinates: [-1.59979427  2.59469275 -1.40010739  3.04073723 -1.43336149] Label: 1
# Coordinates: [-2.94886004 -2.04121358 -1.7903414   0.8267076  -0.47437681] Label: 1
# Coordinates: [-2.34280316 -3.40519768 -1.79405062 -3.55322028  3.28455088] Label: 1
# Coordinates: [ 2.31662142 -3.01161936 -0.62515619 -4.24862311 -0.59940216] Label: 1
# Coordinates: [-6.62722656 -2.8149797   5.71371736 -2.31767967  1.50178981] Label: 1
# Coordinates: [-4.642204   -3.25701861  5.00981169 -4.61097907  2.59639107] Label: 1
# Coordinates: [-4.21696471  3.96371332 -4.3611021   1.71548883 -3.47174809] Label: 1
# Coordinates: [ 3.19232158 -0.76512009  0.25142049  0.75315124  2.84235501] Label: 0
# Coordinates: [-0.31796717 -1.11933094  3.88318907  0.86581258  0.54828296] Label: 1
# Coordinates: [-2.62623757 -1.86297059 -0.28418323  0.58904726  2.11114947] Label: 1
# Coordinates: [ 0.98272295 -2.03670998 -2.48828038  0.24212501  2.75043159] Label: 1
# Coordinates: [-3.6820212  -4.11167817 -2.39399603 -1.22984667 -1.38496628] Label: 1
# Coordinates: [-3.81490887 -3.89563109  1.60672203 -3.81451806  0.15337355] Label: 1
# Coordinates: [ 0.9157792   0.01691063  5.16042392 -0.2995204   1.77322228] Label: 1
# Coordinates: [-4.40444199  4.5952577   3.00242965  3.56555069  1.40394868] Label: 1
# Coordinates: [-1.61173447 -2.03304395  4.73724795 -1.60808781  3.51074124] Label: 1
# Coordinates: [ 4.18422347 -3.01235294  0.83334928 -6.19502715 -3.35020681] Label: 0
# Coordinates: [-7.96619182 -4.47880815  1.53553839 -0.23099283 -1.11840906] Label: 1
# Coordinates: [ 2.82341873  3.05182383 -0.31633016 -0.08868333  2.28835789] Label: 0
# Coordinates: [-0.18251846 -4.42095046 -0.54337555 -3.88333253  1.24394058] Label: 1
# Coordinates: [-3.64913189 -1.45010556  3.19997343 -1.06274608 -0.31621668] Label: 1
# Coordinates: [ 1.93928002  5.44926008  0.52622941  2.04119752 -5.09425896] Label: 0
# Coordinates: [ 0.85536924 -0.84667066  0.7937927   0.72972552  5.00254535] Label: 1
# Coordinates: [-2.01753811 -3.95699253  0.06282596 -4.60902993 -2.17314455] Label: 1
# Coordinates: [-2.42345246 -0.98420203 -2.78186121  2.05734235  2.14396675] Label: 1
# Coordinates: [-1.18288642 -0.97036753 -1.80137463  3.12983243  0.81401623] Label: 1
# Coordinates: [ 3.85931487 -1.51499726 -2.07108652 -1.28541851 -3.05598189] Label: 0
# Coordinates: [-3.1050875  -3.68495825 -2.85012495  0.97478258  0.33837516] Label: 1
# Coordinates: [ 7.39442219  1.5376295  -3.44628038 -2.78610834  3.62376292] Label: 0
# Coordinates: [ 8.06058968 -0.72845342 -2.67196215  0.78091857 -2.64502606] Label: 0
# Coordinates: [7.01961826 4.25244649 1.01064972 6.07874301 6.2108408 ] Label: 0
# Coordinates: [11.56970785  0.01748727 -0.49238587  0.87736442  2.29698856] Label: 0
# Coordinates: [ 2.05742986 -2.67566107 -1.43769956 -1.63762603  0.6841459 ] Label: 1
# Coordinates: [-1.8660399   0.30796273 -0.28103903  2.07474568 -1.10711217] Label: 1
# Coordinates: [-1.80358894  9.22722332 -1.52337267 -4.7684921   0.92990884] Label: 2
# Coordinates: [-1.15257741 -1.78202316  3.8095039  -0.23872961 -0.85599772] Label: 1
# Coordinates: [-5.7114153  -5.40357636  0.21419096 -4.96786609  2.01018748] Label: 1
# Coordinates: [ 0.18556693 -3.591119   -1.77459804 -2.44873815 -1.56700221] Label: 1
# Coordinates: [ 5.17048981 -1.41203796 -0.93162254 -3.44783378 -3.20175856] Label: 0
# Coordinates: [ 5.07484059 -1.19698719 -0.86804623  1.69327298  7.27538203] Label: 0
# Coordinates: [ 4.48406772 -0.35630575  2.74830669 -1.66054955 -1.11064256] Label: 0
# Coordinates: [ 5.40775102 -1.78504873 -1.29735468 -2.47154864  0.07575762] Label: 0
# Coordinates: [-4.96369531 -1.17091639 -2.0389087   1.46080799 -1.79752744] Label: 1
# Coordinates: [ 3.35953536 -2.16486507 -1.02810114 -3.64920064  4.85681544] Label: 0
# Coordinates: [ 7.03534533 -0.10833134 -3.93750166 -1.72560415  0.7626344 ] Label: 0
# Coordinates: [13.54183499  0.72565456 -0.71703942 -0.76702221  4.93357976] Label: 0
# Coordinates: [-1.62662197 -1.56615883 -2.90186193  0.20161281  0.71472711] Label: 1
# Coordinates: [-1.84099166 -4.45502161 -3.10165851 -2.31269329 -0.13899646] Label: 1
# Coordinates: [ 0.26373963 -3.44331962 -1.87840396 -1.82615132 -3.09502277] Label: 1
# Coordinates: [-4.01365697 -4.17944464  0.1786378  -2.40528247 -1.83987674] Label: 1
# Coordinates: [-0.76896237 -3.20372499 -3.06144914  0.28158224 -1.76535168] Label: 1
# Coordinates: [ 1.78432551 -2.33347607  1.72150543 -2.3638811   0.43291971] Label: 1
# Coordinates: [ 3.91493961 -1.41266545 -0.93902562 -1.48923004  4.01506259] Label: 0
# Coordinates: [ 1.09433268  2.24772068  5.2453046   2.2378087  -4.62118185] Label: 1
# Coordinates: [16.34230933  5.49605088  1.48929515  0.42832545  0.12948462] Label: 0
# Coordinates: [-3.9387001   0.08556315  6.21175498  3.92458892  0.23304297] Label: 1
# Coordinates: [-1.25277608 -1.59947041 -3.55070138 -1.62756367  1.1106716 ] Label: 1
# Coordinates: [ 7.80148523  1.26861805  4.40659801 -3.73363441 -0.90844837] Label: 0
# Coordinates: [-2.65343015 -2.47478842  0.49762075  1.69373871  3.67944437] Label: 1
# Coordinates: [ 0.60845529 -4.39743544 -0.86713691 -4.90222717  1.28904349] Label: 1
# Coordinates: [-2.18618988 -1.32640157 -0.79733925  1.44826183  2.92936584] Label: 1
# Coordinates: [-1.49508482 -1.53603647 -3.530364    4.05932302  0.98788634] Label: 1
# Coordinates: [-5.1958747  -1.73371666  3.80287386  1.82970353  0.07659931] Label: 1
# Coordinates: [-5.46118353 -2.61315102  4.73165819 -0.75980398  0.48162961] Label: 1
# Coordinates: [-5.01281955  8.29439346  1.13176275  2.16532407  6.23431156] Label: 2
# Coordinates: [-6.50690741 -3.47552651  1.97217502 -3.8162312  -0.90803818] Label: 1
# Coordinates: [-6.09261425 -2.07409349  0.77437332  0.09902114  0.01202063] Label: 1
# Coordinates: [-0.27270306  0.90587831  4.39020922 -0.74587139  0.20352574] Label: 1
# Coordinates: [-1.10411459 -1.65210534  7.48819093 -4.73191375  1.28230143] Label: 1
# Coordinates: [-2.66774582  4.58723238 -6.3358879   2.70787088 -0.60892368] Label: 1
# Coordinates: [-1.85505797 -1.01178636  4.15331493 -2.12022479 -0.61560532] Label: 1
# Coordinates: [-0.70716068 -2.049376    3.02951975  0.12220897  0.03892608] Label: 1
# Coordinates: [ 0.44510568 15.44423229 -6.43365335 -2.02240114 -0.36484648] Label: 2
# Coordinates: [ 0.51293414 -3.86879496 -0.10788235 -4.18459776 -1.57779946] Label: 1
# Coordinates: [-3.0163014   0.11537724  4.91257412  2.00062812 -1.56358122] Label: 1
# Coordinates: [ 1.29642807 -0.93810696  0.18198851  2.72853101 -0.66989862] Label: 1
# Coordinates: [-1.42993318 -2.27386123  0.8957977  -1.05549335  4.07232889] Label: 1
# Coordinates: [-8.23266963  1.58909945 -0.31152307 -0.71128819  1.56436666] Label: 1
# Coordinates: [ 3.54129625 -1.35763912  1.37690967 -1.60427259 -4.02687625] Label: 0
# Coordinates: [-3.4173683  -1.9854819   3.90517801  0.64007056 -0.00921104] Label: 1
# Coordinates: [-6.66115231 -3.79546967  3.53003486 -1.45511957 -0.14021563] Label: 1
# Coordinates: [-4.99375010e+00 -9.78124737e-01  5.42381138e-02  6.43739344e+00
#  -2.37091266e-03] Label: 1
# Coordinates: [ 0.24933789 10.87836193 -0.41621083 -0.89918714  0.24361461] Label: 2
# Coordinates: [ 1.62988568 -2.46855938 -4.47706618  1.22665534 -1.26979319] Label: 1
# Coordinates: [-1.80438242  4.5251045   2.99643366  0.26562364  1.01751481] Label: 1
# Coordinates: [-2.86671513 -3.14773261 -3.54202195  2.12134828 -1.20997161] Label: 1
# Coordinates: [ 6.49819125 -0.76105981  8.04490146 -2.88157643 -0.40647232] Label: 0
# Coordinates: [-2.7140024  -4.41529295 -3.74231961 -2.06226937  3.14726005] Label: 1
# Coordinates: [ 0.57421768 -0.59841159 -3.39587286  3.74837566 -1.83038717] Label: 1
# Coordinates: [-2.27090337 -1.36001441 -0.2332161  -0.37203578 -0.42453789] Label: 1
# Coordinates: [-5.9357851  12.98828919 -2.34134333 -4.56083899  5.12189323] Label: 2
# Coordinates: [-3.64902911  4.37149196  0.59857759  5.72461584  3.14900927] Label: 1
# Coordinates: [ 3.817898   -1.00761484 -1.39406731 -0.90564024 -2.57632416] Label: 0
# Coordinates: [-0.7003993  -2.71237994  1.4359586  -2.79903121  2.29593211] Label: 1
# Coordinates: [-1.38610584 -1.2140801   1.88709519  2.75890624 -1.00396297] Label: 1
# Coordinates: [ 6.46532826 -1.04836366 -0.46215706 -3.92540746  1.20674548] Label: 0
# Coordinates: [ 1.29528979 -3.0012945  -4.80027009 -0.36090167  1.11355548] Label: 1
# Coordinates: [-5.43573247 -3.56657862  2.37184889 -4.23196455 -1.10624825] Label: 1
# Coordinates: [-1.74311887  0.53938714  4.21849491  1.6770601   1.24628352] Label: 1
# Coordinates: [ 7.19734863 -1.03546561  1.91919828 -3.00368388 -2.26555389] Label: 0
# Coordinates: [-2.17860036 -1.72349214  6.87724715 -1.17507396 -0.57831639] Label: 1
# Coordinates: [-6.65901499 -4.38841112 -0.58813066  0.13768953  0.03311194] Label: 1
# Coordinates: [ 2.67553899 -0.58135067  0.5180429   0.7342888   1.21248901] Label: 0
# Coordinates: [-4.12625556  1.19706804  2.56011577  4.47076794 -0.49217734] Label: 1
# Coordinates: [ 0.10194195 -1.88310644 -1.69003704  1.06943751  2.91025102] Label: 1
# Coordinates: [-1.17112041 -1.21061434  2.55006506 -0.62319469  1.6447988 ] Label: 1
# Coordinates: [ 0.12581745 -3.92329619 -2.46532239 -2.67639194 -0.83143525] Label: 1
# Coordinates: [-2.36802051 -3.56347649 -4.11204066 -1.5770722   2.11769781] Label: 1
# Coordinates: [ 0.27831421 -1.43266152 -1.10187263  2.82428758 -4.36504084] Label: 1
# Coordinates: [-2.15591027 -0.48534674  2.0304747   1.55087873  1.63103679] Label: 1
# Coordinates: [3.31428226 1.81482217 5.99899814 2.87715689 2.59663703] Label: 0
# Coordinates: [ 2.26134265  0.47813819  2.05661295  2.54380387 -1.9713949 ] Label: 0
# Coordinates: [0.37027213 0.2237644  4.89051605 5.18926094 0.46964807] Label: 1
# Coordinates: [ 2.0014145  -2.24771739 -5.41988447  1.48192542 -0.5558241 ] Label: 1
# Coordinates: [13.34095559  0.35574612 -0.60672172 -0.16703989 -4.14155382] Label: 0
# Coordinates: [ 0.81114346 -0.49661297  7.41133874 -2.31168396 -1.67498513] Label: 1
# Coordinates: [ 1.17329794 -1.48412272  1.16509587  0.25617581  0.90606953] Label: 1
# Coordinates: [-0.63609908 -0.67729251 -0.48023723  1.59473302 -0.51394927] Label: 1
# Coordinates: [-5.47171084  8.04235815 -3.3065908  -1.94140943 -1.90916923] Label: 2
# Coordinates: [ 2.10075711  9.24639269  2.73481533  2.00714895 -1.79185571] Label: 2
# Coordinates: [-4.6930965  -1.31724519  2.30357011  4.66628297 -1.05272125] Label: 1
# Coordinates: [-3.96281561  6.5452731   1.80153602  0.57151473  0.09267121] Label: 2
# Coordinates: [-4.38104202 -1.72770105  0.46408381  2.44909321  0.82528408] Label: 1
# Coordinates: [ 2.56346654 -0.72993825 -4.70369796  0.59294929 -2.6323113 ] Label: 0
# Coordinates: [ 3.39291476  0.92336131 -4.51664083  0.22242315 -3.63405741] Label: 0
# Coordinates: [4.91891826 0.55225883 3.90202802 1.03779638 2.22773838] Label: 0
# Coordinates: [ 1.98941865 -1.32566206 -1.69657656  2.15691677 -2.08147134] Label: 1
# Coordinates: [ 4.86274575 -1.95172565 -2.99741637 -0.72252179 -1.82277653] Label: 0
# Coordinates: [ 0.72608629 -0.36457305 -1.55597837 -1.46483672  3.45959385] Label: 1
# Coordinates: [-2.98297127  7.67520056 -3.01117536 -1.35746733 -3.57493165] Label: 2
# Coordinates: [-3.8786115  -1.9623213   2.11311157  0.20131419 -0.61177319] Label: 1
# Coordinates: [ 0.6474294  -1.90026288 -2.7141782   1.44654035 -2.84558711] Label: 1
# Coordinates: [ 4.47476679  0.47924348 -1.38172972  6.79305914  3.68337611] Label: 0
# Coordinates: [-4.11952202 -0.82807434  2.09736033  0.7329628   0.54893883] Label: 1
# Coordinates: [7.81242977 2.2024769  4.30924369 3.40314846 1.97911622] Label: 0
# Coordinates: [ 3.40906479  0.31763565 -2.79812855 -0.35453862 -1.51475384] Label: 0
# Coordinates: [ 3.62609035  0.90831709  6.6197247   0.26932224 -0.30566839] Label: 0
# Coordinates: [ 4.35463934 -2.20205756 -2.91721939 -2.07557932  2.63453747] Label: 0
# Coordinates: [ 3.7280816  -1.96319711 -3.86701828  2.52428452 -0.38047099] Label: 0
# Coordinates: [ 1.4334809   1.35045783  5.87663947  1.58526581 -0.39452367] Label: 1
# Coordinates: [ 0.34739799 -1.78198887  2.71014293 -1.69924854  3.17752105] Label: 1
# Coordinates: [-1.91342881 -4.49835938 -0.52470958 -4.07811142 -0.57695644] Label: 1
# Coordinates: [13.58881917  2.79716214  7.95791821 -1.23957265 -1.88000414] Label: 0
# Coordinates: [ 1.00722122 -2.28337733  3.42734352 -1.08440996 -0.46001144] Label: 1
# Coordinates: [ 6.72480184  0.02832795  7.51582893 -4.70100184 -9.39912975] Label: 0
# Coordinates: [-4.31991141 -3.48502642  0.36116325 -0.57107297 -0.76708361] Label: 1
# Coordinates: [ 2.64331886 -1.68935669 -0.70262472 -0.53798179 -1.02195653] Label: 0
# Coordinates: [ 1.03790607 -0.11806558  5.55646835  1.63017453  0.96524407] Label: 1
# Coordinates: [ 1.13025346 -0.97043109  3.4153805   1.20748204 -3.63223458] Label: 1
# Coordinates: [ 7.14509264 -0.37675362  1.75344418 -0.93960256 -4.66707758] Label: 0
# Coordinates: [ 0.05086926 -0.9672966  -4.44769277 -0.5040448   4.46985502] Label: 1

# %%
# Store the cluster labels
pcalabels = kmeanspca.labels_
pcacenters = kmeanspca.cluster_centers_

# Add pcalabels to the merged_df DataFrame for hue mapping
merged_df['pcalabels'] = pcalabels

# figure settings
plt.figure(figsize=(10, 10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1', fontsize=20)
plt.ylabel('Principal Component - 2', fontsize=20)
plt.title("PCA Clusters Mapped onto First Two Principal Components", fontsize=20)

# Plot the scatterplot with K-means clusters as hue
sns.scatterplot(data=merged_df, 
                x='principal component 1', 
                y='principal component 2', 
                hue='pcalabels',  # Using the labels from the merged_df
                palette='Set2',  # Color palette
                s=100,  # Size of the points
                edgecolor='black',  # Black edges for better visibility
                alpha=0.7)  # Slight transparency

# Plot the cluster centers 
plt.scatter(pcacenters[:, 0], pcacenters[:, 1], s=100, c='black', marker='+', label='Cluster Centers')

# Show the legend
plt.legend(title="Clusters", prop={'size': 15})

# Show the plot
plt.show()

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
# !pip install tensorflow
# !pip install keras
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# Sklearn libraries
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix

# Keras libraries
from tensorflow import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import RMSprop
# Out:
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.0)
# Requirement already satisfied: keras in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (3.7.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.3.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)

# %%
# Convert HSD010_binary back to numeric, mapping 'good' to 0 and 'poor' to 1
NNnhanes_target=nhanestarget
NNnhanes_target['HSD010_binary'] = NNnhanes_target['HSD010_binary'].map({'good': 0, 'poor': 1})
X=NNnhanes_target.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %%
NNnhanes_target.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ845   PAAQUEX    SMQ860  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.646584 -0.484200  1.125008
# 73576 -0.057306  0.128246  0.080373  ... -1.539259 -0.484200  1.125008
# 73579 -0.057306  0.128246 -0.189513  ... -1.539259  2.065262 -0.888883
# 73581 -0.057306  0.128246  0.080373  ... -0.646584 -0.484200  1.125008
# 73584 -0.057306  0.128246  0.080373  ...  0.246091  2.065262  1.125008
#
#        SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x     HSD010  \
# SEQN
# 73568     0.0 -2.081666  1.087115  1.463404   0.612440  excellent
# 73576     0.0 -2.081666  1.087115 -0.683338  -1.632812  excellent
# 73579     0.0  0.480384 -0.919866 -0.683338  -1.632812  very good
# 73581     0.0  0.480384 -0.919866 -0.683338   0.612440  very good
# 73584     0.0  0.480384 -0.919866  1.463404  -1.632812       good
#
#        HSD010_binary
# SEQN
# 73568              0
# 73576              0
# 73579              0
# 73581              0
# 73584              0
#
# [5 rows x 243 columns]

# %%
# partition data
# -----------
y = NNnhanes_target['HSD010_binary'] # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X = X # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 2
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)
num_classes = y_test.shape[1]

# %%
print(y_train[0])
# Out:
# [1. 0.]

# %%
# create neural network model
# -----------
model = Sequential()

num_pixels = X_train.shape[1] 

#input layer
model.add(Dense(num_pixels, input_dim= num_pixels, kernel_initializer= 'normal', activation= 'relu'))

#output layer
model.add(Dense(num_classes, kernel_initializer= 'normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss= 'categorical_crossentropy', optimizer= 'adam', metrics=['accuracy'])

#fit model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Out:
# /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 8/8 - 1s - 171ms/step - accuracy: 0.7526 - loss: 0.5322 - val_accuracy: 0.8527 - val_loss: 0.3851
# Epoch 2/10
# 8/8 - 0s - 14ms/step - accuracy: 0.8702 - loss: 0.3392 - val_accuracy: 0.8643 - val_loss: 0.3500
# Epoch 3/10
# 8/8 - 0s - 14ms/step - accuracy: 0.8779 - loss: 0.3015 - val_accuracy: 0.8721 - val_loss: 0.3428
# Epoch 4/10
# 8/8 - 0s - 14ms/step - accuracy: 0.8979 - loss: 0.2618 - val_accuracy: 0.8721 - val_loss: 0.3371
# Epoch 5/10
# 8/8 - 0s - 14ms/step - accuracy: 0.9102 - loss: 0.2359 - val_accuracy: 0.8721 - val_loss: 0.3314
# Epoch 6/10
# 8/8 - 0s - 14ms/step - accuracy: 0.9244 - loss: 0.2127 - val_accuracy: 0.8682 - val_loss: 0.3313
# Epoch 7/10
# 8/8 - 0s - 14ms/step - accuracy: 0.9289 - loss: 0.1948 - val_accuracy: 0.8702 - val_loss: 0.3301
# Epoch 8/10
# 8/8 - 0s - 14ms/step - accuracy: 0.9341 - loss: 0.1758 - val_accuracy: 0.8663 - val_loss: 0.3356
# Epoch 9/10
# 8/8 - 0s - 14ms/step - accuracy: 0.9490 - loss: 0.1591 - val_accuracy: 0.8682 - val_loss: 0.3377
# Epoch 10/10
# 8/8 - 0s - 15ms/step - accuracy: 0.9561 - loss: 0.1438 - val_accuracy: 0.8643 - val_loss: 0.3440

# %% [markdown]
# ### Neural Network on Principal Components

# %%
# Convert the PCA result to a DataFrame 
pca5_df = pd.DataFrame(data = pca5_result, 
                      columns = ['principal component 1', 
                                 'principal component 2',
                                'principal component 3',
                                'principal component 4',
                                'principal component 5'])

# %%
# partition data
# -----------
y = NNnhanes_target['HSD010_binary'] 
X = pca5_df # using our 5 component PCA as the features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 2
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)
num_classes = y_test.shape[1]

# %%
# create neural network model
# -----------
model = Sequential()

num_pixels = X_train.shape[1] 

#input layer
model.add(Dense(num_pixels, input_dim= num_pixels, kernel_initializer= 'normal', activation= 'relu'))

#output layer
model.add(Dense(num_classes, kernel_initializer= 'normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss= 'categorical_crossentropy', optimizer= 'adam', metrics=['accuracy'])

#fit model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Out:
# Epoch 1/10
# /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 - 1s - 163ms/step - accuracy: 0.6098 - loss: 0.6885 - val_accuracy: 0.8217 - val_loss: 0.6803
# Epoch 2/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8295 - loss: 0.6765 - val_accuracy: 0.8488 - val_loss: 0.6681
# Epoch 3/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6646 - val_accuracy: 0.8488 - val_loss: 0.6556
# Epoch 4/10
# 8/8 - 0s - 14ms/step - accuracy: 0.8359 - loss: 0.6521 - val_accuracy: 0.8488 - val_loss: 0.6425
# Epoch 5/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6392 - val_accuracy: 0.8488 - val_loss: 0.6286
# Epoch 6/10
# 8/8 - 0s - 12ms/step - accuracy: 0.8359 - loss: 0.6253 - val_accuracy: 0.8488 - val_loss: 0.6139
# Epoch 7/10
# 8/8 - 0s - 12ms/step - accuracy: 0.8359 - loss: 0.6107 - val_accuracy: 0.8488 - val_loss: 0.5981
# Epoch 8/10
# 8/8 - 0s - 12ms/step - accuracy: 0.8359 - loss: 0.5945 - val_accuracy: 0.8488 - val_loss: 0.5818
# Epoch 9/10
# 8/8 - 0s - 12ms/step - accuracy: 0.8359 - loss: 0.5780 - val_accuracy: 0.8488 - val_loss: 0.5645
# Epoch 10/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.5603 - val_accuracy: 0.8488 - val_loss: 0.5468

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
# Add cluster labels to the PCA DataFrame (as an additional feature)
pca5_df['cluster_label'] = pcalabels
print(pca5_df.head())
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               9.527811              -0.816224              -1.867041
# 1              -5.838339              -3.692572               3.805748
# 2              -0.719454              -2.573200               0.907925
# 3               3.533627              -2.576982              -3.249140
# 4              -6.872094              -4.194241               0.886832
#
#    principal component 4  principal component 5  cluster_label
# 0              -2.110221              -3.929922              0
# 1              -1.029610               0.388748              1
# 2              -4.756373              -1.802520              1
# 3              -0.405851               3.998230              0
# 4              -0.849225              -0.527403              1

# %%
# partition data
# -----------
y = NNnhanes_target['HSD010_binary'] 
X = pca5_df # using our 5 component PCA and cluster membership as the features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 2
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)
num_classes = y_test.shape[1]

# %%
# create neural network model
# -----------
model = Sequential()

num_pixels = X_train.shape[1] 

#input layer
model.add(Dense(num_pixels, input_dim= num_pixels, kernel_initializer= 'normal', activation= 'relu'))

#output layer
model.add(Dense(num_classes, kernel_initializer= 'normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss= 'categorical_crossentropy', optimizer= 'adam', metrics=['accuracy'])

#fit model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Out:
# Epoch 1/10
# /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 - 1s - 140ms/step - accuracy: 0.2804 - loss: 0.6995 - val_accuracy: 0.5310 - val_loss: 0.6933
# Epoch 2/10
# 8/8 - 0s - 12ms/step - accuracy: 0.7235 - loss: 0.6893 - val_accuracy: 0.8411 - val_loss: 0.6833
# Epoch 3/10
# 8/8 - 0s - 12ms/step - accuracy: 0.8359 - loss: 0.6799 - val_accuracy: 0.8488 - val_loss: 0.6736
# Epoch 4/10
# 8/8 - 0s - 12ms/step - accuracy: 0.8359 - loss: 0.6704 - val_accuracy: 0.8488 - val_loss: 0.6638
# Epoch 5/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6605 - val_accuracy: 0.8488 - val_loss: 0.6533
# Epoch 6/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6497 - val_accuracy: 0.8488 - val_loss: 0.6418
# Epoch 7/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6376 - val_accuracy: 0.8488 - val_loss: 0.6291
# Epoch 8/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6242 - val_accuracy: 0.8488 - val_loss: 0.6153
# Epoch 9/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.6098 - val_accuracy: 0.8488 - val_loss: 0.6004
# Epoch 10/10
# 8/8 - 0s - 13ms/step - accuracy: 0.8359 - loss: 0.5941 - val_accuracy: 0.8488 - val_loss: 0.5846

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"
